# %%
import pandas as pd

# %%
import numpy as np

# %% [markdown]
# # 2.Pandas

# %% [markdown]
# ## 2.1 Series
#
# Numpy와 유사하나 index를 가지고 있음

# %% [markdown]
# ### 생성
#
# ```python
# series = pd.Series(
#   [90, 85, 80, 75, 70]
#   ) # 인덱스를 지정하지 않으면 0부터 시작
#
# series = pd.Series(
#   [90, 85, 80, 75, 70],
#   index=['국', '영', '수', '사', '과']
#   )
# ```

# %%
series = pd.Series(
    [90, 85, 80, 75, 70],
    index=['국', '영', '수', '사', '과']
)

series
# Out:
# 국    90
# 영    85
# 수    80
# 사    75
# 과    70
# dtype: int64

# %% [markdown]
# ### 추가, 변경, 삭제
# 기존 딕셔너리의 추가, 변경, 삭제와 동일 <br>
# <br>
#
# 추가
# ```python
# series['한국사'] = 100
# ```
# <br>
#
# 변경
# ```python
# series['국'] = 100
# series.국 = 100
# ```
# <br>
#
# 삭제
# ```python
# del series['국']
# ```

# %%
series['코딩'] = 100
series
# Out:
# 국      90
# 영      85
# 수      80
# 사      75
# 과      70
# 코딩    100
# dtype: int64

# %%
series['코딩'] = 90
series

series.코딩 = 85
series
# Out:
# 국     90
# 영     85
# 수     80
# 사     75
# 과     70
# 코딩    85
# dtype: int64

# %%
del series['코딩']
series
# Out:
# 국    90
# 영    85
# 수    80
# 사    75
# 과    70
# dtype: int64

# %% [markdown]
# ### name
# name 속성을 이용하여 series와 index에 이름 부여 가능
#
# ```python
# series.name = '성적'
# series.index.name = '과목'
# ```

# %%
series.name = '성적'
series.index.name = '과목'

series
# Out:
# 과목
# 국    90
# 영    85
# 수    80
# 사    75
# 과    70
# Name: 성적, dtype: int64

# %% [markdown]
# ### indexing
#
# ```python
# series[0], series['국']    # 특정 인덱스 번호 혹은 이름 지정
# series.국
#
# series[[0, 2, 1]]         # 인덱스 순서를 원하는 순서대로 변경하여 출력
# series[['국', '수', '영']]  # 인덱스 순서를 원하는 순서대로 변경하여 출력
#
# series[0:3]            # 슬라이싱
# series['국어':'수학']    # 슬라이싱, 끝 점 포함
# ```

# %%
print(series[0])
print(series['국'])
print(series.국)
print()

print(series[[0, 2, 1]])
print(series[['과', '국', '영', '수']])
print()

print(series[0:3])
print(series['국':'수'])
# Out:
# 90
# 90
# 90
#
# 과목
# 국    90
# 수    80
# 영    85
# Name: 성적, dtype: int64
# 과목
# 과    70
# 국    90
# 영    85
# 수    80
# Name: 성적, dtype: int64
#
# 과목
# 국    90
# 영    85
# 수    80
# Name: 성적, dtype: int64
# 과목
# 국    90
# 영    85
# 수    80
# Name: 성적, dtype: int64

# %% [markdown]
# ### series 연산
#
# series끼리 연산 진행 가능 <br>
# 다만, series 연산은 동일 index끼리 연산이므로 index 정보가 다르면 연산 불가 <br>
# <br>
#
# ```python
# series1 = pd.Series(
#   [90, 85, 80, 75, 70],
#   index=['국', '영', '수', '사', '과']
#   )
#
# series2 = pd.Series(
#   [95, 80, 70, 80, 95],
#   index=['국', '영', '수', '사', '과']
#   )
# ```

# %%
series1 = pd.Series(
  [90, 85, 80, 75, 70],
  index=['국', '영', '수', '사', '과']
  )

series2 = pd.Series(
  [95, 80, 70, 80, 95],
  index=['국', '영', '수', '사', '과']
  )

series1 + series2
# Out:
# 국    185
# 영    165
# 수    150
# 사    155
# 과    165
# dtype: int64

# %%
series1 = pd.Series(
  [90, 85, 80, 75, 70],
  index=['국', '영', '수', '사', '과']
  )

series2 = pd.Series(
  [95, 80, 70, 80, 95, 100],
  index=['영', '수', '사', '과', '국', '코딩']
  )

series1 + series2
# Out:
# 과     150.0
# 국     185.0
# 사     145.0
# 수     160.0
# 영     180.0
# 코딩      NaN
# dtype: float64

# %% [markdown]
# ## 2.2 DataFrame
#
# Series가 1d 행렬에 index를 추가한 것과 같이 <br>
# DataFrame은 2d 행렬에 index와 column을 추가한 것 <br>
# 혹은 여러 Series의 합 <br>

# %% [markdown]
# ### 2.2.1 판다스 기초

# %% [markdown]
# #### 생성
#
# 딕셔너리 기반
# ```python
# data = {
#     '학생1': [90, 85, 80, 75, 70],
#     '학생2': [95, 80, 70, 80, 95],
#     '학생3': [85, 95, 90, 70, 85],
# }
# index = ['국', '영', '수', '사', '과']
# df = pd.DataFrame(data, index=index)
# df
# ```
# <br>
# <br>
#
# 배열 기반
# ```python
# data = [
#   [90, 95, 85],
#   [85, 80, 95],
#   [80, 70, 90],
#   [75, 80, 70],
#   [70, 95, 85]
# ]
#
# index = ['국', '영', '수', '사', '과']
# columns = ['학생1', '학생2', '학생3']
# df = pd.DataFrame(data, index=index, columns=columns)
# ```

# %%
data = {
    '학생1': [90, 85, 80, 75, 70],
    '학생2': [95, 80, 70, 80, 95],
    '학생3': [85, 95, 90, 70, 85],
}
index = ['국', '영', '수', '사', '과']
df = pd.DataFrame(data, index=index)
df
# Out:
#    학생1  학생2  학생3
# 국   90   95   85
# 영   85   80   95
# 수   80   70   90
# 사   75   80   70
# 과   70   95   85

# %%
print(df.학생1)
print(df.학생1.국)
# Out:
# 국    90
# 영    85
# 수    80
# 사    75
# 과    70
# Name: 학생1, dtype: int64
# 90

# %%
data = [
  [90, 95, 85],
  [85, 80, 95],
  [80, 70, 90],
  [75, 80, 70],
  [70, 95, 85]
]

index = ['국', '영', '수', '사', '과']
columns = ['학생1', '학생2', '학생3']
df = pd.DataFrame(data, index=index, columns=columns)
df
# Out:
#    학생1  학생2  학생3
# 국   90   95   85
# 영   85   80   95
# 수   80   70   90
# 사   75   80   70
# 과   70   95   85

# %% [markdown]
# #### 추가, 변경, 삭제
# **추가** <br>
# DataFrame의 추가는 기본적으로 열 단위 추가
#
# ```python
# # 현재 row는 국, 영, 수, 사, 과의 5개 정보인데 1개 정보만 추가하게 되면, 이 값을 전체에 복사
# # 즉, 모든 row 값을 90으로 채움
# df['학생4'] = 90
#
# # 만약 2개 이상의 값을 넣고 싶으면 배열을 이용하여 넣어야 함
# # 이 경우 row수와 일치하지 않으면 에러 발생
# df['학생4'] = [90, 80]     # 에러
# df['학생4'] = [90, 80, 70, 60, 50]
# ```
# <br>
#
# **변경** <br>
# 데이터프레임.컬럼.인덱스 = 변경값 <br>
# 기존 컬럼이 존재하면 생성과 유사하게 동작
# ```python
# df.학생3.국 = 100
# df['학생3'] = 100    # df.학생3 = 100
# df['학생3'] = [100, 99, 98, 97, 96]    # df.학생3 = [100, 99, 98, 97, 96]
# ```
#
#
#
# **삭제**
# ```python
# del df['학생4']
# df.drop(columns='학생4')
# ```

# %%
df['학생4'] = 90
print(df)
df['학생4'] = [10, 20, 50, 90, 70]
print(df)
df.학생4.국 = 80
print(df)
# Out:
#    학생1  학생2  학생3  학생4
# 국   90   95   85   90
# 영   85   80   95   90
# 수   80   70   90   90
# 사   75   80   70   90
# 과   70   95   85   90
#    학생1  학생2  학생3  학생4
# 국   90   95   85   10
# 영   85   80   95   20
# 수   80   70   90   50
# 사   75   80   70   90
# 과   70   95   85   70
#    학생1  학생2  학생3  학생4
# 국   90   95   85   80
# 영   85   80   95   20
# 수   80   70   90   50
# 사   75   80   70   90
# 과   70   95   85   70

# %%
del df['학생4']
df
# Out:
#    학생1  학생2  학생3
# 국   90   95   85
# 영   85   80   95
# 수   80   70   90
# 사   75   80   70
# 과   70   95   85

# %% [markdown]
# #### name
#
# Series에서와 마찬가지로 이름을 지정할 수 있음 <br>
# 다만, DataFrame은 2차원이므로 index와 column 모두에 이름 지정 가능 <br>
#
# ```python
# df.index.name = '과목'
# df.columns.name = '학생'
# ```

# %%
df.index.name = '과목'
df.columns.name = '학생'

df
# Out:
# 학생  학생1  학생2  학생3
# 과목
# 국    90   95   85
# 영    85   80   95
# 수    80   70   90
# 사    75   80   70
# 과    70   95   85

# %% [markdown]
# #### column 이름 변경
# dataframe의 column 정보는 df.columns에 저장 <br>
# 여기에 저장된 값을 다른 값으로 입력하면 변경 가능 <br>
# 단, 열 전체 정보를 입력해야 함 (열 개수와 입력 값이 일치하지 않으면 에러) <br>
# 개별 column 이름을 변경하고 싶으면 rename 사용
# <br>
#
# ```python
# df.columns
# df.columns = '학생4'    # 에러
# df.columns = ['학생4']  # 에러
# df.rename(columns={'학생1': '학생4'})
# df.columns = ['학생4', '학생5', '학생6']
# ```

# %%
df.columns = ['학생4', '학생2', '학생3']
df.columns.name = '학생'
df
# Out:
# 학생  학생4  학생2  학생3
# 과목
# 국    90   95   85
# 영    85   80   95
# 수    80   70   90
# 사    75   80   70
# 과    70   95   85

# %%
df.rename(columns={'학생1': '학생4'})
# Out:
# 학생  학생4  학생2  학생3
# 과목
# 국    90   95   85
# 영    85   80   95
# 수    80   70   90
# 사    75   80   70
# 과    70   95   85

# %% [markdown]
# #### indexing
# **column** <br>
# ```python
# df['학생1']           # Series 반환
# df[['학생1']]         # DataFrame 반환
# df[['학생1', '학생2']] # 다수의 컬럼 선택
# ```
# <br>
#
# **row** <br>
# 항상 슬라이싱(:) 사용
# ```python
# df[:1]
# df[1:3]
# df['국':'수']
# ```

# %%
print(df['학생2'])
print(df[['학생2']])
print(df[['학생3', '학생2']])
# Out:
# 과목
# 국    95
# 영    80
# 수    70
# 사    80
# 과    95
# Name: 학생2, dtype: int64
# 학생  학생2
# 과목
# 국    95
# 영    80
# 수    70
# 사    80
# 과    95
# 학생  학생3  학생2
# 과목
# 국    85   95
# 영    95   80
# 수    90   70
# 사    70   80
# 과    85   95

# %%
print(df[1:3])
print(df['영':'사'])
# Out:
# 학생  학생4  학생2  학생3
# 과목
# 영    85   80   95
# 수    80   70   90
# 학생  학생4  학생2  학생3
# 과목
# 영    85   80   95
# 수    80   70   90
# 사    75   80   70

# %% [markdown]
# ##### iloc, loc
#
# 판다스 데이터프레임에는 위의 인덱싱을 보다 효과적으로 수행할 수 있는 특별한 방법이 존재 <br>
# <br>
#
# > **loc** <br>
# 행 인덱싱은 정수 또는 행 인덱스 데이터, 열 인덱스는 문자열 <br>
# ```python
# dataframe.loc[행 인덱싱]
# dataframe.loc[행 인덱싱, 열 인덱싱]
# ```
#
# <br>
# <br>
#
# > **iloc** <br>
# 사용법은 loc와 큰 차이가 없으나 iloc 내부에는 반드시 정수 인덱싱만 허용 <br>
# ```python
# dataframe.iloc[행 인덱싱]
# dataframe.iloc[행 인덱싱, 열 인덱싱]
# ```

# %%
df[['학생1', '학생2']]
# Out:
#    학생1  학생2
# 국   90   95
# 영   85   80
# 수   80   70
# 사   75   80
# 과   70   95

# %%
df.loc['학생1', '학생2']  # 열 인덱싱 자리에 '학생2'를 넣었으니 에러
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3628             try:
# -> 3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
#
# c:\ProgramData\Anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# c:\ProgramData\Anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '학생1'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_2908\861509692.py in <module>
# ----> 1 df.loc['학생1', '학생2']  # 열 인덱싱 자리에 '학생2'를 넣었으니 에러
#
# c:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#     958             key = tuple(com.apply_if_callable(x, self.obj) for x in key)
#     959             if self._is_scalar_access(key):
# --> 960                 return self.obj._get_value(*key, takeable=self._takeable)
#     961             return self._getitem_tuple(key)
#     962         else:
#
# c:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in _get_value(self, index, col, takeable)
#    3620             #  results if our categories are integers that dont match our codes
#    3621             # IntervalIndex: IntervalTree has no get_loc
# -> 3622             row = self.index.get_loc(index)
#    3623             return series._values[row]
#    3624
#
# c:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
# -> 3631                 raise KeyError(key) from err
#    3632             except TypeError:
#    3633                 # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: '학생1'

# %%
df.loc[, '학생1']
# Out:
#   File "C:\Users\user\AppData\Local\Temp\ipykernel_2908\2716382534.py", line 1
#     df.loc[, '학생1']
#            ^
# SyntaxError: invalid syntax

# %%
df.loc[:, '학생1']
# Out:
# 국    90
# 영    85
# 수    80
# 사    75
# 과    70
# Name: 학생1, dtype: int64

# %%
df.loc[:, ['학생1', '학생2']]
# Out:
#    학생1  학생2
# 국   90   95
# 영   85   80
# 수   80   70
# 사   75   80
# 과   70   95

# %%
df.loc['국':'수']  # df['국':'수']
# Out:
#    학생1  학생2  학생3
# 국   90   95   85
# 영   85   80   95
# 수   80   70   90

# %%
df.iloc[:3]
# Out:
#    학생1  학생2  학생3
# 국   90   95   85
# 영   85   80   95
# 수   80   70   90

# %%
df.iloc[:, :2]
# Out:
#    학생1  학생2
# 국   90   95
# 영   85   80
# 수   80   70
# 사   75   80
# 과   70   95

# %%
df.iloc[:, [0, 1]]
# Out:
#    학생1  학생2
# 국   90   95
# 영   85   80
# 수   80   70
# 사   75   80
# 과   70   95

# %% [markdown]
# #### describe
# 데이터 프레임의 기술통계량 산출 <br>

# %%
df.describe()
# Out:
#              학생1        학생2        학생3
# count   5.000000   5.000000   5.000000
# mean   80.000000  84.000000  85.000000
# std     7.905694  10.839742   9.354143
# min    70.000000  70.000000  70.000000
# 25%    75.000000  80.000000  85.000000
# 50%    80.000000  80.000000  85.000000
# 75%    85.000000  95.000000  90.000000
# max    90.000000  95.000000  95.000000

# %% [markdown]
# #### values
# 데이터 프레임 값을 numpy로 반환
#
# ```python
# data = {
#     '학생1': [90, 85, 80, 75, 70],
#     '학생2': [95, 80, 70, 80, 95],
#     '학생3': [85, 95, 90, 70, 85],
#     '재수': [80, 100, 99, 95, 90],
# }
# index = ['국', '영', '수', '사', '과']
# df = pd.DataFrame(data, index=index)
#
# df.values
# ```

# %%
df.values
# Out:
# array([[90, 95, 85],
#        [85, 80, 95],
#        [80, 70, 90],
#        [75, 80, 70],
#        [70, 95, 85]], dtype=int64)

# %% [markdown]
# #### shape
# 데이터 프레임의 행,열을 반환
#
# ```python
# data = {
#     '학생1': [90, 85, 80, 75, 70],
#     '학생2': [95, 80, 70, 80, 95],
#     '학생3': [85, 95, 90, 70, 85],
#     '재수': [80, 100, 99, 95, 90],
# }
# index = ['국', '영', '수', '사', '과']
# df = pd.DataFrame(data, index=index)
#
# df.shape
# ```

# %%
df.shape

# regression
# Out:
# (5, 3)

# %%
columns = ['국','영','수','사','과']
df = pd.DataFrame(data, columns=columns)
df.shape
# Out:
# (0, 5)

# %%
if not df.shape[0]:
    pass

# %% [markdown]
# #### unique
# 중복값을 제거한 데이터 반환
#
# ```python
# data = {
#     '학생1': [90, 85, 80, 75, 70],
#     '학생2': [95, 80, 70, 80, 95],
#     '학생3': [85, 95, 90, 70, 85],
#     '재수': [80, 100, 99, 95, 90],
# }
# index = ['국', '영', '수', '사', '과']
# df = pd.DataFrame(data, index=index)
#
# df.학생2.unique()
# ```

# %%
data = {
    '학생1': [90, 85, 80, 75, 70],
    '학생2': [95, 80, 70, 80, 95],
    '학생3': [85, 95, 90, 70, 85],
    '재수': [80, 100, 99, 95, 90],
}
index = ['국', '영', '수', '사', '과']
df = pd.DataFrame(data, index=index)

df.학생2.unique()
# Out:
# array([95, 80, 70], dtype=int64)

# %% [markdown]
# #### count
# 행별 개수, 열별 개수 반환
#
# ```python
# data = {
#     '학생1': [90, 85, 80, 75, 70],
#     '학생2': [95, 80, 70, 80, 95],
#     '학생3': [85, 95, 90, 70, 85],
#     '재수': [80, 100, 99, 95, 90],
# }
# index = ['국', '영', '수', '사', '과']
# df = pd.DataFrame(data, index=index)
#
# df.count()        # 행별 원소 개수
# df.count(axis=1)  # 열별 원소 개수
# ```

# %%
print(df.count())
print(df.count(axis=1))
# Out:
# 학생1    5
# 학생2    5
# 학생3    5
# 재수     5
# dtype: int64
# 국    4
# 영    4
# 수    4
# 사    4
# 과    4
# dtype: int64

# %% [markdown]
# #### sort_index
# 인덱스 정렬 <br>
#
# ```python
# data = {
#     '학생1': [90, 85, 80, 75, 70],
#     '학생2': [95, 80, 70, 80, 95],
#     '학생3': [85, 95, 90, 70, 85],
#     '재수': [80, 100, 99, 95, 90],
# }
# index = [3, 1, 4, 2, 5]
# df = pd.DataFrame(data, index=index)
#
# df.sort_index()                   # 오름차순으로 정렬된 데이터 프레임 반환
# df.sort_index(inplace=True)       # 데이터 프레임 자체를 변환
# df.sort_index(ascending=False)    # 내림차순으로 정렬된 데이터 프레임 반환
# ```

# %%
data = {
    '학생1': [90, 85, 80, 75, 70],
    '학생2': [95, 80, 70, 80, 95],
    '학생3': [85, 95, 90, 70, 85],
    '재수': [80, 100, 99, 95, 90],
}
index = ['국', '영', '수', '사', '과']
df = pd.DataFrame(data, index=index)
df
# Out:
#    학생1  학생2  학생3   재수
# 국   90   95   85   80
# 영   85   80   95  100
# 수   80   70   90   99
# 사   75   80   70   95
# 과   70   95   85   90

# %%
a = [2,1,3,4,]

# %%
data = {
    '학생1': [90, 85, 80, 75, 70],
    '학생2': [95, 80, 70, 80, 95],
    '학생3': [85, 95, 90, 70, 85],
    '재수': [80, 100, 99, 95, 90],
}
index = [3,1,4,5,2]
df = pd.DataFrame(data, index=index)
df.sort_index(inplace = True, ascending = False)
df
# Out:
#    학생1  학생2  학생3   재수
# 5   75   80   70   95
# 4   80   70   90   99
# 3   90   95   85   80
# 2   70   95   85   90
# 1   85   80   95  100

# %% [markdown]
# #### sort_values
# 특정 컬럼 값을 기준으로 정렬 <br>
#
# ```python
# data = {
#     '학생1': [90, 85, 80, 75, 70],
#     '학생2': [95, 80, 70, 80, 95],
#     '학생3': [85, 95, 90, 70, 85],
#     '재수': [80, 100, 99, 95, 90],
# }
# index = ['국', '영', '수', '사', '과']
# df = pd.DataFrame(data, index=index)
#
# df.sort_values(by=['학생1'])                      # 학생1의 점수를 기준으로 오름차순 정렬된 데이터 프레임 반환
# df.sort_values(by=['학생1'], ascending=False)     # 학생1의 점수를 기준으로 내림차순 정렬된 데이터 프레임 반환
# df.sort_values(by=['학생1'], inplace=True)        # 데이터 프레임을 학생1의 점수를 기준으로 오름차순 정렬
# df.sort_values(by=['학생1', '학생2'])              # 학생1, 학생2의 점수를 기준으로 (학생1 우선) 오름차순 정렬된 데이터프레임 반환
# ```

# %%
data = {
    '학생1': [90, 85, 80, 75, 70],
    '학생2': [95, 80, 70, 80, 95],
    '학생3': [85, 95, 90, 70, 85],
    '재수': [80, 100, 99, 95, 90],
}
index = [3,1,4,5,2]
df = pd.DataFrame(data, index=index)
df.sort_index(inplace = True, ascending = False)
df

# %%
data = {
    '학생1': [90, 85, 80, 75, 70],
    '학생2': [95, 80, 70, 80, 95],
    '학생3': [85, 95, 90, 70, 85],
    '재수': [80, 100, 99, 95, 90],
}
index = ['국','영','수','사','과'] 
pd.DataFrame(data, index=index)
df.sort_values(by='학생2')
# Out:
#    학생1  학생2  학생3   재수
# 4   80   70   90   99
# 5   75   80   70   95
# 1   85   80   95  100
# 3   90   95   85   80
# 2   70   95   85   90

# %%
df.sort_values(by=['학생2', '학생1'])
# Out:
#    학생1  학생2  학생3   재수
# 4   80   70   90   99
# 5   75   80   70   95
# 1   85   80   95  100
# 2   70   95   85   90
# 3   90   95   85   80

# %% [markdown]
# #### apply
# 열 또는 축을 기준으로 함수 적용
#
# ```python
# data = {
#     '학생1': [90, 85, 80, 75, 70],
#     '학생2': [95, 80, 70, 80, 95],
#     '학생3': [85, 95, 90, 70, 85],
#     '재수': [80, 100, 99, 95, 90],
# }
# index = ['국', '영', '수', '사', '과']
# df = pd.DataFrame(data, index=index)
#
# df.apply(lambda x: x + 10, axis=1)
# ```

# %%
data = {
    '학생1': [90, 85, 80, 75, 70],
    '학생2': [95, 80, 70, 80, 95],
    '학생3': [85, 95, 90, 70, 85],
    '재수': [80, 100, 99, 95, 90],
}
index = ['국','영', '수', '사', '과']
df = pd.DataFrame(data, index=index)
df
# Out:
#    학생1  학생2  학생3   재수
# 국   90   95   85   80
# 영   85   80   95  100
# 수   80   70   90   99
# 사   75   80   70   95
# 과   70   95   85   90

# %%
df.count(axis=0)
# Out:
# 학생1    5
# 학생2    5
# 학생3    5
# 재수     5
# dtype: int64

# %%
df.apply(lambda x: x + 10, axis=1)
# Out:
#    학생1  학생2  학생3   재수
# 국  100  105   95   90
# 영   95   90  105  110
# 수   90   80  100  109
# 사   85   90   80  105
# 과   80  105   95  100

# %%
df.apply(lambda x: len(x), axis=1)
# Out:
# 국    4
# 영    4
# 수    4
# 사    4
# 과    4
# dtype: int64

# %% [markdown]
# #### value_counts
# 특정 열을 기준으로 값의 개수 산출
#
# ```python
# data = {
#     '학생1': [90, 85, 80, 75, 70],
#     '학생2': [95, 80, 70, 80, 95],
#     '학생3': [85, 95, 90, 70, 85],
#     '재수': [80, 100, 99, 95, 90],
# }
# index = ['국', '영', '수', '사', '과']
# df = pd.DataFrame(data, index=index)
#
# df.value_counts()
# ```

# %%
data = {
    '학생1': [90, 85, 80, 75, 70],
    '학생2': [95, 80, 70, 80, 95],
    '학생3': [85, 95, 90, 70, 85],
    '재수': [80, 100, 99, 95, 90],
}
index = ['국','영', '수', '사', '과']
df = pd.DataFrame(data, index=index)

df.value_counts(subset=['학생1'])
# Out:
# 학생1
# 70     1
# 75     1
# 80     1
# 85     1
# 90     1
# dtype: int64

# %%
data = {
    '학생1': [90, 85, 80, 75, 70],
    '학생2': [95, 80, 70, 80, 95],
    '학생3': [85, 95, 90, 70, 85],
    '재수': [80, 100, 99, 95, 90],
}
index = ['국','영', '수', '사', '과']
df = pd.DataFrame(data, index=index)

df.value_counts()
# Out:
# 학생1  학생2  학생3  재수
# 70   95   85   90     1
# 75   80   70   95     1
# 80   70   90   99     1
# 85   80   95   100    1
# 90   95   85   80     1
# dtype: int64

# %%
data = {
    '학생1': [90, 90, 90],
    '학생2': [95, 80, 95],
    '학생3': [90, 90, 90],
    '재수': [80, 100, 80],
}
index = ['국','영', '수']
df = pd.DataFrame(data, index=index)

df.value_counts()
# Out:
# 학생1  학생2  학생3  재수
# 90   95   90   80     2
#      80   90   100    1
# dtype: int64

# %% [markdown]
# #### set_index
# 특정 열을 index로 설정
#
# ```python
# data = {
#     '학생1': [90, 85, 80, 75, 70],
#     '학생2': [95, 80, 70, 80, 95],
#     '학생3': [85, 95, 90, 70, 85],
#     '재수': [80, 100, 99, 95, 90],
# }
# index = ['국', '영', '수', '사', '과']
# df = pd.DataFrame(data, index=index)
#
# df.set_index('학생1')
# ```

# %%
data = {
    '학생1': [90, 85, 80, 75, 70],
    '학생2': [95, 80, 70, 80, 95],
    '학생3': [85, 95, 90, 70, 85],
    '재수': [80, 100, 99, 95, 90],
}
index = ['국','영', '수', '사', '과']
df = pd.DataFrame(data, index=index)
df.reset_index()
# Out:
#   index  학생1  학생2  학생3   재수
# 0     국   90   95   85   80
# 1     영   85   80   95  100
# 2     수   80   70   90   99
# 3     사   75   80   70   95
# 4     과   70   95   85   90

# %%
df = df.reset_index()
df.set_index('index')
# Out:
#        학생1  학생2  학생3   재수
# index
# 국       90   95   85   80
# 영       85   80   95  100
# 수       80   70   90   99
# 사       75   80   70   95
# 과       70   95   85   90

# %% [markdown]
# ### 2.2.2 데이터 입출력

# %% [markdown]
# #### 입력
# pd.read_csv를 통하여 csv 데이터를 읽음
#
# ```python
# pd.read_csv(파일경로)
# ```
# <br>
#
# read_csv 내에는 다양한 옵션 존재
# - use_cols: csv 컬럼에서 특정 컬럼만을 읽음
# - names: 읽어 들인 데이터의 열 이름 변경 가능
# - index_col: 입력하는 파일 내의 특정 column을 index로 설정 가능
# - sep: csv의 데이터 구분은 ",", 하지만 데이터 구분자가 다른 경우 (\t) 이러한 구분자를 sep을 통해 지정할 수 있음
# - skiprows: 읽어들인 데이터 중 필요 없는 row를 제거할 수 있음
# - na_values: 값 중 na_values에 지정한 값은 읽을 때 na 처리

# %% [markdown]
# #### 출력
# pd.to_csv를 통하여 csv 데이터를 출력
#
# ```python
# pd.to_csv(파일경로)
# ```
# <br>
#
# to_csv 내에는 다양한 옵션 존재
#
# - encoding: encoding을 지정하지 않고 출력 시 excel에서 한글이 깨지는 경우가 존재. 이 경우 utf-8-sig를 사용하면 해결 가능. <br> cp949, euc-kr등의 옵션도 존재
# - sep: 입력 때와 마찬가지로 구분자를 지정해줄 수 있음
# - na_rep: 입력 때와 마찬가지로 특정 값을 na로 처리하여 저장할 수 있음
# - index: index를 출력할지 유무. True, False
# - headers: column을 출력할지 유무. True, False

# %% [markdown]
# ### 2.2.3 데이터 전처리

# %%
data = {
    '학생1': [90, 85, 80, 75, 70],
    '학생2': [95, 80, 70, 80, 95],
    '학생3': [85, 95, 90, 70, 85],
    '재수': [80, 100, 99, 95, 90],
}

# %%
data = {
    '학생1': [90, 85, 80, 75, 70],
    '학생2': [95, 80, 70, 80, 95],
    '학생3': [85, 95, 90, 70, 85],
    '재수': [80, 100, 99, 95, 90],
}
index = ['국','영', '수', '사', '과']
df = pd.DataFrame(data, index=index)

# %%
df.value_counts()
# Out:
# 학생1  학생2  학생3  재수
# 70   95   85   90     1
# 75   80   70   95     1
# 80   70   90   99     1
# 85   80   95   100    1
# 90   95   85   80     1
# dtype: int64

# %%
df.drop_duplicates()
# Out:
#    학생1  학생2  학생3   재수
# 국   90   95   85   80
# 영   85   80   95  100
# 수   80   70   90   99
# 사   75   80   70   95
# 과   70   95   85   90

# %%
df.drop_duplicates()
# Out:
#    학생1  학생2  학생3   재수
# 국   90   95   85   80
# 영   85   80   95  100
# 수   80   70   90   99
# 사   75   80   70   95
# 과   70   95   85   90

# %%
df.drop_duplicates(subset='학생2')
# Out:
#    학생1  학생2  학생3   재수
# 국   90   95   85   80
# 영   85   80   95  100
# 수   80   70   90   99

# %%
df.drop_duplicates(subset='학생2', keep='last')
# Out:
#    학생1  학생2  학생3  재수
# 수   80   70   90  99
# 사   75   80   70  95
# 과   70   95   85  90

# %% [markdown]
# #### drop_duplicates

# %% [markdown]
# #### duplicated
# 데이터프레임 내 중복값 확인

# %%
df.duplicated()
# Out:
# 국    False
# 영    False
# 수    False
# 사    False
# 과    False
# dtype: bool

# %%
df.duplicated(subset=['학생2'])
# Out:
# 국    False
# 영    False
# 수    False
# 사     True
# 과     True
# dtype: bool

# %%
df.duplicated(subset=['학생2','학생3'])
# Out:
# 국    False
# 영    False
# 수    False
# 사    False
# 과     True
# dtype: bool

# %%
df.loc[df.duplicated(subset=['학생2', '학생3'])]
# Out:
#    학생1  학생2  학생3  재수
# 과   70   95   85  90

# %%
df.loc[~df.duplicated(subset=['학생2', '학생3'])]
# Out:
#    학생1  학생2  학생3   재수
# 국   90   95   85   80
# 영   85   80   95  100
# 수   80   70   90   99
# 사   75   80   70   95

# %% [markdown]
# #### isna
# 결측값 확인
#
# ```python
# data = {
#     '학생1': [np.NaN, 85, 80, 75, 70],
#     '학생2': [95, 80, np.NaN, 80, 95],
#     '학생3': [85, 95, 90, np.NaN, 85],
#     '재수': [80, np.NaN, 99, 95, 90],
# }
# df = pd.DataFrame(data)
#
# df.isna()
# ```

# %%
data = {
    '학생1': [np.NaN, 85, 80, 75, 70],
    '학생2': [95, 80, np.NaN, 80, 95],
    '학생3': [85, 95, 90, np.NaN, 85],
    '재수': [80, np.NaN, 99, 95, 90],
}
df = pd.DataFrame(data)

# %%
df
# Out:
#     학생1   학생2   학생3    재수
# 0   NaN  95.0  85.0  80.0
# 1  85.0  80.0  95.0   NaN
# 2  80.0   NaN  90.0  99.0
# 3  75.0  80.0   NaN  95.0
# 4  70.0  95.0  85.0  90.0

# %%
df.isna()
# Out:
#      학생1    학생2    학생3     재수
# 0   True  False  False  False
# 1  False  False  False   True
# 2  False   True  False  False
# 3  False  False   True  False
# 4  False  False  False  False

# %%
df.isna().sum(1)
# Out:
# 0    1
# 1    1
# 2    1
# 3    1
# 4    0
# dtype: int64

# %% [markdown]
# #### dropna
# na가 포함된 row drop

# %%
df.dropna()
# Out:
#     학생1   학생2   학생3    재수
# 4  70.0  95.0  85.0  90.0

# %%
df.dropna(subset='학생1')
# Out:
#     학생1   학생2   학생3    재수
# 1  85.0  80.0  95.0   NaN
# 2  80.0   NaN  90.0  99.0
# 3  75.0  80.0   NaN  95.0
# 4  70.0  95.0  85.0  90.0

# %% [markdown]
# #### fillna
# 결측값을 특정 값으로 대체
#
# ```python
# data = {
#     '학생1': [np.NaN, 85, 80, 75, 70],
#     '학생2': [95, 80, np.NaN, 80, 95],
#     '학생3': [85, 95, 90, np.NaN, 85],
#     '재수': [80, np.NaN, 99, 95, 90],
# }
# df = pd.DataFrame(data)
#
# df.fillna(0)                   # 특정 값으로 대체
# df.fillna(method='ffill')      # 결측값을 앞의 값으로 대체
# df.fillna(method='bfill')      # 결측값을 뒤의 값으로 대체
# ```

# %%
data = {
    '학생1': [np.NaN, 85, 80, 75, 70],
    '학생2': [95, 80, np.NaN, 80, 95],
    '학생3': [85, 95, 90, np.NaN, 85],
    '재수': [80, np.NaN, 99, 95, 90],
}
df = pd.DataFrame(data)

# %%
df
# Out:
#     학생1   학생2   학생3    재수
# 0   NaN  95.0  85.0  80.0
# 1  85.0  80.0  95.0   NaN
# 2  80.0   NaN  90.0  99.0
# 3  75.0  80.0   NaN  95.0
# 4  70.0  95.0  85.0  90.0

# %%
df.fillna(method='bfill')
# Out:
#     학생1   학생2   학생3    재수
# 0  85.0  95.0  85.0  80.0
# 1  85.0  80.0  95.0  99.0
# 2  80.0  80.0  90.0  99.0
# 3  75.0  80.0  85.0  95.0
# 4  70.0  95.0  85.0  90.0

# %%
df.fillna(method='ffill')
# Out:
#     학생1   학생2   학생3    재수
# 0   NaN  95.0  85.0  80.0
# 1  85.0  80.0  95.0  80.0
# 2  80.0  80.0  90.0  99.0
# 3  75.0  80.0  90.0  95.0
# 4  70.0  95.0  85.0  90.0

# %% [markdown]
# ### 2.2.4 데이터 조회

# %% [markdown]
# #### isin
# 주어진 값이 데이터프레임 내에 존재하는지 확인
#
# ```python
# data = {
#     '학생1': [90, 85, 80, 75, 70],
#     '학생2': [95, 80, 70, 80, 95],
#     '학생3': [85, 95, 90, 70, 85],
#     '재수': [80, 100, 99, 95, 90],
# }
# index = ['국', '영', '수', '사', '과']
# df = pd.DataFrame(data, index=index)
#
# df.isin([80])
# ```

# %%
data = {
    '학생1': [90, 85, 80, 75, 70],
    '학생2': [95, 80, 70, 80, 95],
    '학생3': [85, 95, 90, 70, 85],
    '재수': [80, 100, 99, 95, 90],
}
index = ['국', '영', '수', '사', '과']
df = pd.DataFrame(data, index=index)

# %%
df.isin([80, 90])
# Out:
#      학생1    학생2    학생3     재수
# 국   True  False  False   True
# 영  False   True  False  False
# 수   True  False   True  False
# 사  False   True  False  False
# 과  False  False  False   True

# %% [markdown]
# #### where
# 특정 조건을 만족하는지 검사 <br>
# 조건을 만족하는 경우 값 변경 가능 <br>
#
# ```python
# data = {
#     '학생1': [90, 85, 80, 75, 70],
#     '학생2': [95, 80, 70, 80, 95],
#     '학생3': [85, 95, 90, 70, 85],
#     '재수': [80, 100, 99, 95, 90],
# }
# index = ['국', '영', '수', '사', '과']
# df = pd.DataFrame(data, index=index)
#
# df.where(df%2==0, -df)
# ```

# %%
df%2
# Out:
#    학생1  학생2  학생3  재수
# 국    0    1    1   0
# 영    1    0    1   0
# 수    0    0    0   1
# 사    1    0    0   1
# 과    0    1    1   0

# %%
df%2 == 0
# Out:
#      학생1    학생2    학생3     재수
# 국   True  False  False   True
# 영  False   True  False   True
# 수   True   True   True  False
# 사  False   True   True  False
# 과   True  False  False   True

# %%
df.where(df%2 == 0)
# Out:
#     학생1   학생2   학생3     재수
# 국  90.0   NaN   NaN   80.0
# 영   NaN  80.0   NaN  100.0
# 수  80.0  70.0  90.0    NaN
# 사   NaN  80.0  70.0    NaN
# 과  70.0   NaN   NaN   90.0

# %%
df.where(df%2 == 0, -99)  # NaN값 대신 -99를 넣어줌
# Out:
#    학생1  학생2  학생3   재수
# 국   90  -99  -99   80
# 영  -99   80  -99  100
# 수   80   70   90  -99
# 사  -99   80   70  -99
# 과   70  -99  -99   90

# %% [markdown]
# #### query
# column의 boolean 결과를 쿼리하는 표현 <br>
# 위의 loc를 활용한 방법보다 간단 <br>
# <br>
#
# ```python
# df = pd.DataFrame({
#     'A': range(1, 6),
#     'B': range(10, 0, -2),
#     'C C': range(10, 5, -1)
#     })
#
# df.query('A > B')        # df.loc[df.A > df.B]
# df.query('`C C` < 8')    # df.loc[df['C C'] < 8]
# ```

# %%
df = pd.DataFrame({
    'A': range(1, 6),
    'B': range(10, 0, -2),
    'C C': range(10, 5, -1)
    })

# %%
df
# Out:
#    A   B  C C
# 0  1  10   10
# 1  2   8    9
# 2  3   6    8
# 3  4   4    7
# 4  5   2    6

# %%
df.loc[df.B >= 6]
# Out:
#    A   B  C C
# 0  1  10   10
# 1  2   8    9
# 2  3   6    8

# %%
df.query('B >= 6')
# Out:
#    A   B  C C
# 0  1  10   10
# 1  2   8    9
# 2  3   6    8

# %%
df = pd.DataFrame({
    'A': range(1, 6),
    'B': range(10, 0, -2),
    'C C': range(10, 5, -1),
    'D' : ['apple', 'banana', 'kiwi', 'orange', 'cherry']
    })

# %%
df.query('D == "kiwi"')
# Out:
#    A  B  C C     D
# 2  3  6    8  kiwi

# %%
df.query('A <= 3 and B <= 6')
# Out:
#    A  B  C C     D
# 2  3  6    8  kiwi

# %%
df.A
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# Name: A, dtype: int64

# %%
df.C C
# Out:
#   File "C:\Users\user\AppData\Local\Temp\ipykernel_2908\4012700300.py", line 1
#     df.C C
#          ^
# SyntaxError: invalid syntax

# %%
df.query('`C C` >= 8')  # 공백자 처리
# Out:
#    A   B  C C       D
# 0  1  10   10   apple
# 1  2   8    9  banana
# 2  3   6    8    kiwi

# %%
df.query('A in [1, 3, 5]')
# Out:
#    A   B  C C       D
# 0  1  10   10   apple
# 2  3   6    8    kiwi
# 4  5   2    6  cherry

# %%
option_4_slicing = [1, 3, 5]
df.query('A in @option_4_slicing')
# Out:
#    A   B  C C       D
# 0  1  10   10   apple
# 2  3   6    8    kiwi
# 4  5   2    6  cherry

# %% [markdown]
# ### 2.2.5 컬럼 조작

# %% [markdown]
# #### filter
# 특정 조건에 맞는 열이나 행을 추출
#
# ```python
# data = {
#     '학생1': [90, 85, 80, 75, 70],
#     '학생2': [95, 80, 70, 80, 95],
#     '학생3': [85, 95, 90, 70, 85],
#     '재수': [80, 100, 99, 95, 90],
# }
# index = ['국', '영', '수', '사', '과']
# df = pd.DataFrame(data, index=index)
#
# df.filter(items=['학생1', '학생2'])    # 주어진 열을 선택
# df.filter(like='학생',  axis=1)       # 학생이라는 단어를 포함하는 열 선택
# df.filter(regex='\d', axis=1)        # 숫자를 포함하는 열 선택
# ```

# %%
data = {
    '학생1': [90, 85, 80, 75, 70],
    '학생2': [95, 80, 70, 80, 95],
    '학생3': [85, 95, 90, 70, 85],
    '재수': [80, 100, 99, 95, 90],
}
index = ['국', '영', '수', '사', '과']
df = pd.DataFrame(data, index=index)
df
# Out:
#    학생1  학생2  학생3   재수
# 국   90   95   85   80
# 영   85   80   95  100
# 수   80   70   90   99
# 사   75   80   70   95
# 과   70   95   85   90

# %%
df.loc[:, ['학생2', '재수']]
# Out:
#    학생2   재수
# 국   95   80
# 영   80  100
# 수   70   99
# 사   80   95
# 과   95   90

# %%
df.filter(items=['학생2', '재수'])
# Out:
#    학생2   재수
# 국   95   80
# 영   80  100
# 수   70   99
# 사   80   95
# 과   95   90

# %%
df.filter(items=['학생1', '학생2', '학생3'])
# Out:
#    학생1  학생2  학생3
# 국   90   95   85
# 영   85   80   95
# 수   80   70   90
# 사   75   80   70
# 과   70   95   85

# %%
df.filter(like='학생')
# Out:
#    학생1  학생2  학생3
# 국   90   95   85
# 영   85   80   95
# 수   80   70   90
# 사   75   80   70
# 과   70   95   85

# %%
df.filter(regex='\d')
# Out:
#    학생1  학생2  학생3
# 국   90   95   85
# 영   85   80   95
# 수   80   70   90
# 사   75   80   70
# 과   70   95   85

# %%
df.filter(regex='\D$')
# Out:
#     재수
# 국   80
# 영  100
# 수   99
# 사   95
# 과   90

# %% [markdown]
# #### drop
# column이나 row를 제거
#
# ```python
# data = {
#     '학생1': [90, 85, 80, 75, 70],
#     '학생2': [95, 80, 70, 80, 95],
#     '학생3': [85, 95, 90, 70, 85],
# }
# index = ['국', '영', '수', '사', '과']
# df = pd.DataFrame(data, index=index)
#
# df.drop(columns='학생1')               # 1개 컬럼 drop
# df.drop(columns=['학생1', '학생2'])     # 복수개 컬럼 drop
#
# df.drop('국')             # 1개 row drop
# df.drop(['국', '영'])      # 복수개 row drop
# ```

# %%
df.drop(columns=['학생1', '학생2'], inplace=True)
df
# Out:
#    학생3   재수
# 국   85   80
# 영   95  100
# 수   90   99
# 사   70   95
# 과   85   90

# %% [markdown]
# ### 2.2.6 통계

# %% [markdown]
# #### sum
# 데이터프레임의 행 또는 열 기준 합을 반환
#
# ```python
# data = {
#     '학생1': [90, 85, 80, 75, 70],
#     '학생2': [95, 80, 70, 80, 95],
#     '학생3': [85, 95, 90, 70, 85],
# }
# index = ['국', '영', '수', '사', '과']
# df = pd.DataFrame(data, index=index)
#
# df.sum()         # default 0: 학생별 합
# df.sum(axis=1)   # 1: 과목별 합
# ```

# %%
data = {
    '학생1': [90, 85, 80, 75, 70],
    '학생2': [95, 80, 70, 80, 95],
    '학생3': [85, 95, 90, 70, 85],
}
index = ['국', '영', '수', '사', '과']
df = pd.DataFrame(data, index=index)

# %%
df
# Out:
#    학생1  학생2  학생3
# 국   90   95   85
# 영   85   80   95
# 수   80   70   90
# 사   75   80   70
# 과   70   95   85

# %%
df.sum()
# Out:
# 학생1    400
# 학생2    420
# 학생3    425
# dtype: int64

# %%
df.sum(axis=1)
# Out:
# 국    270
# 영    260
# 수    240
# 사    225
# 과    250
# dtype: int64

# %% [markdown]
# #### mean
# 데이터프레임의 행 또는 열 기준 평균 반환
#
# ```python
# data = {
#     '학생1': [90, 85, 80, 75, 70],
#     '학생2': [95, 80, 70, 80, 95],
#     '학생3': [85, 95, 90, 70, 85],
# }
# index = ['국', '영', '수', '사', '과']
# df = pd.DataFrame(data, index=index)
#
# df.mean()         # default 0: 학생별 평균
# df.mean(axis=1)   # 1: 과목별 평균
# ```

# %%
df.mean(axis=1)
# Out:
# 국    90.000000
# 영    86.666667
# 수    80.000000
# 사    75.000000
# 과    83.333333
# dtype: float64

# %%
df.mean(axis=0)
# Out:
# 학생1    80.0
# 학생2    84.0
# 학생3    85.0
# dtype: float64

# %% [markdown]
# #### median
# 데이터프레임의 행 또는 열 기준 중앙값 반환
#
# ```python
# data = {
#     '학생1': [90, 85, 80, 75, 70],
#     '학생2': [95, 80, 70, 80, 95],
#     '학생3': [85, 95, 90, 70, 85],
# }
# index = ['국', '영', '수', '사', '과']
# df = pd.DataFrame(data, index=index)
#
# df.median()         # default 0: 학생별 중앙값
# df.median(axis=1)   # 1: 과목별 중앙값
# ```

# %%
df.median(axis=0)
# Out:
# 학생1    80.0
# 학생2    80.0
# 학생3    85.0
# dtype: float64

# %%
df.sort_values(by='학생1')
# Out:
#    학생1  학생2  학생3
# 과   70   95   85
# 사   75   80   70
# 수   80   70   90
# 영   85   80   95
# 국   90   95   85

# %% [markdown]
# #### mode
# 데이터프레임의 행 또는 열 기준 최빈값 반환
#
# ```python
# data = {
#     '학생1': [90, 85, 80, 75, 70],
#     '학생2': [95, 80, 70, 80, 95],
#     '학생3': [85, 95, 90, 70, 85],
# }
# index = ['국', '영', '수', '사', '과']
# df = pd.DataFrame(data, index=index)
#
# df.mode()         # default 0: 학생별 합
# df.mode(axis=1)   # 1: 과목별 합
# ```

# %%
df.mode(axis=0)
# Out:
#    학생1   학생2   학생3
# 0   70  80.0  85.0
# 1   75  95.0   NaN
# 2   80   NaN   NaN
# 3   85   NaN   NaN
# 4   90   NaN   NaN

# %%
df.mode(axis=1)
# Out:
#     0   1   2
# 국  85  90  95
# 영  80  85  95
# 수  70  80  90
# 사  70  75  80
# 과  70  85  95

# %% [markdown]
# #### max
# 데이터프레임의 행 또는 열 기준 최댓값 반환
#
# ```python
# data = {
#     '학생1': [90, 85, 80, 75, 70],
#     '학생2': [95, 80, 70, 80, 95],
#     '학생3': [85, 95, 90, 70, 85],
# }
# index = ['국', '영', '수', '사', '과']
# df = pd.DataFrame(data, index=index)
#
# df.max()         # default 0: 학생별 최댓값
# df.max(axis=1)   # 1: 과목별 최댓값
# ```

# %%
df.max()
# Out:
# 학생1    90
# 학생2    95
# 학생3    95
# dtype: int64

# %% [markdown]
# #### min
# 데이터프레임의 행 또는 열 기준 최솟값 반환
#
# ```python
# data = {
#     '학생1': [90, 85, 80, 75, 70],
#     '학생2': [95, 80, 70, 80, 95],
#     '학생3': [85, 95, 90, 70, 85],
# }
# index = ['국', '영', '수', '사', '과']
# df = pd.DataFrame(data, index=index)
#
# df.min()         # default 0: 학생별 최솟값
# df.min(axis=1)   # 1: 과목별 최솟값
# ```

# %%
df.min()
# Out:
# 학생1    70
# 학생2    70
# 학생3    70
# dtype: int64

# %%
df.describe()
# Out:
#              학생1        학생2        학생3
# count   5.000000   5.000000   5.000000
# mean   80.000000  84.000000  85.000000
# std     7.905694  10.839742   9.354143
# min    70.000000  70.000000  70.000000
# 25%    75.000000  80.000000  85.000000
# 50%    80.000000  80.000000  85.000000
# 75%    85.000000  95.000000  90.000000
# max    90.000000  95.000000  95.000000

# %% [markdown]
# #### cumsum
#
# 데이터프레임의 행 또는 열 기준 누적합 반환
#
# ```python
# data = {
#     '자산1': [0.01, 0.02, 0.03],
#     '자산2': [0.06, 0.09, 0.07],
#     '자산3': [0.04, 0.09, 0.01],
# }
# index = [2018, 2019, 2020]
# df = pd.DataFrame(data, index=index)
#
# df.cumsum()         # default 0: 자산별 누적합
# df.cumsum(axis=1)   # 1: 연도별 누적합
# ```

# %%
data = {
    '자산1': [0.01, 0.02, 0.03],
    '자산2': [0.06, 0.09, 0.07],
    '자산3': [0.04, 0.09, 0.01],
}
index = [2018, 2019, 2020]
df = pd.DataFrame(data, index=index)

# %%
df
# Out:
#        자산1   자산2   자산3
# 2018  0.01  0.06  0.04
# 2019  0.02  0.09  0.09
# 2020  0.03  0.07  0.01

# %%
df.cumsum()
# Out:
#        자산1   자산2   자산3
# 2018  0.01  0.06  0.04
# 2019  0.03  0.15  0.13
# 2020  0.06  0.22  0.14

# %%
df.cumsum(axis=0)
# Out:
#        자산1   자산2   자산3
# 2018  0.01  0.06  0.04
# 2019  0.03  0.15  0.13
# 2020  0.06  0.22  0.14

# %%
df.cumsum(axis=1)
# Out:
#        자산1   자산2   자산3
# 2018  0.01  0.07  0.11
# 2019  0.02  0.11  0.20
# 2020  0.03  0.10  0.11

# %% [markdown]
# #### cumprod
# 데이터프레임의 행 또는 열 기준 누적곱 반환
#
# ```python
# data = {
#     '자산1': [0.01, 0.02, 0.03],
#     '자산2': [0.06, 0.09, 0.07],
#     '자산3': [0.04, 0.09, 0.01],
# }
# index = [2018, 2019, 2020]
# df = pd.DataFrame(data, index=index)
#
# df.cumprod()         # default 0: 자산별 누적곱
# df.cumprod(axis=1)   # 1: 연도별 누적곱
# ```

# %%
df
# Out:
#        자산1   자산2   자산3
# 2018  0.01  0.06  0.04
# 2019  0.02  0.09  0.09
# 2020  0.03  0.07  0.01

# %%
df.cumprod()
# Out:
#            자산1       자산2       자산3
# 2018  0.010000  0.060000  0.040000
# 2019  0.000200  0.005400  0.003600
# 2020  0.000006  0.000378  0.000036

# %% [markdown]
# #### rank
# 데이터프레임의 행 또는 열 기준 순위 반환
#
# ```python
# data = {
#     '학생1': [90, 85, 80, 75, 70],
#     '학생2': [95, 80, 70, 80, 95],
#     '학생3': [85, 95, 90, 70, 85],
# }
# index = ['국', '영', '수', '사', '과']
# df = pd.DataFrame(data, index=index)
#
# df.rank()         # default 0: 학생별 최솟값
# df.rank(axis=1)   # 1: 과목별 최솟값
# ```

# %%
data = {
    '학생1': [90, 85, 80, 75, 70],
    '학생2': [95, 80, 70, 80, 95],
    '학생3': [85, 95, 90, 70, 85],
}
index = ['국', '영', '수', '사', '과']
df = pd.DataFrame(data, index=index)

# %%
df.rank()
# Out:
#    학생1  학생2  학생3
# 국  5.0  4.5  2.5
# 영  4.0  2.5  5.0
# 수  3.0  1.0  4.0
# 사  2.0  2.5  1.0
# 과  1.0  4.5  2.5

# %%
df.rank(method='min')
# Out:
#    학생1  학생2  학생3
# 국  5.0  4.0  2.0
# 영  4.0  2.0  5.0
# 수  3.0  1.0  4.0
# 사  2.0  2.0  1.0
# 과  1.0  4.0  2.0

# %%
df.rank(method='max')
# Out:
#    학생1  학생2  학생3
# 국  5.0  5.0  3.0
# 영  4.0  3.0  5.0
# 수  3.0  1.0  4.0
# 사  2.0  3.0  1.0
# 과  1.0  5.0  3.0

# %% [markdown]
# #### quantile
# 데이터프레임의 행 또는 열 기준 분위수 반환
#
# ```python
# data = {
#     '학생1': [90, 85, 80, 75, 70],
#     '학생2': [95, 80, 70, 80, 95],
#     '학생3': [85, 95, 90, 70, 85],
# }
# index = ['국', '영', '수', '사', '과']
# df = pd.DataFrame(data, index=index)
#
# df.quantile()         # default 0: 학생별 중앙값
# df.quantile(q=0.8)    # default 0: 학생별 80%값 반환
# df.quantile(axis=1)   # 1: 과목별 학생별 중앙값
# ```

# %%
df.quantile()
# Out:
# 학생1    80.0
# 학생2    80.0
# 학생3    85.0
# Name: 0.5, dtype: float64

# %%
df.sort_values(by='학생3')
# Out:
#    학생1  학생2  학생3
# 사   75   80   70
# 국   90   95   85
# 과   70   95   85
# 수   80   70   90
# 영   85   80   95

# %%
df.quantile(q=0.25)
# Out:
# 학생1    75.0
# 학생2    80.0
# 학생3    85.0
# Name: 0.25, dtype: float64

# %% [markdown]
# #### var
# 데이터프레임의 행 또는 열 기준 분산 반환
#
# ```python
# data = {
#     '학생1': [90, 85, 80, 75, 70],
#     '학생2': [95, 80, 70, 80, 95],
#     '학생3': [85, 95, 90, 70, 85],
# }
# index = ['국', '영', '수', '사', '과']
# df = pd.DataFrame(data, index=index)
#
# df.var()         # default 0: 학생별 분산
# df.var(axis=1)   # 1: 과목별 분산
# ```

# %%
df.var(axis=1)
# Out:
# 국     25.000000
# 영     58.333333
# 수    100.000000
# 사     25.000000
# 과    158.333333
# dtype: float64

# %% [markdown]
# #### std
# 데이터프레임의 행 또는 열 기준 표준편차 반환
#
# ```python
# data = {
#     '학생1': [90, 85, 80, 75, 70],
#     '학생2': [95, 80, 70, 80, 95],
#     '학생3': [85, 95, 90, 70, 85],
# }
# index = ['국', '영', '수', '사', '과']
# df = pd.DataFrame(data, index=index)
#
# df.std()         # default 0: 학생별 표준편차
# df.std(axis=1)   # 1: 과목별 표준편차
# ```

# %%
df.std(axis=1)
# Out:
# 국     5.000000
# 영     7.637626
# 수    10.000000
# 사     5.000000
# 과    12.583057
# dtype: float64

# %%
df.std(axis=0)
# Out:
# 학생1     7.905694
# 학생2    10.839742
# 학생3     9.354143
# dtype: float64

# %% [markdown]
# #### corr
# 데이터프레임 내 상관관계 행렬 반환 <br>
# 상관관계는 pearson, kendall, spearman 방법 가능
#
# ```python
# data = {
#     '학생1': [90, 85, 80, 75, 70],
#     '학생2': [95, 80, 70, 80, 95],
#     '학생3': [85, 95, 90, 70, 85],
# }
# index = ['국', '영', '수', '사', '과']
# df = pd.DataFrame(data, index=index)
#
# df.corr()                     # pearson
# df.corr(method='kendall')     # kendall
# df.corr(method='spearman')    # spearman
# ```

# %%
df.corr()
# Out:
#               학생1           학생2       학생3
# 학생1  1.000000e+00  8.291465e-17  0.422577
# 학생2  8.291465e-17  1.000000e+00 -0.123278
# 학생3  4.225771e-01 -1.232784e-01  1.000000

# %% [markdown]
# #### cov
# 데이터프레임 내 공분산 행렬 반환
#
# ```python
# data = {
#     '학생1': [90, 85, 80, 75, 70],
#     '학생2': [95, 80, 70, 80, 95],
#     '학생3': [85, 95, 90, 70, 85],
# }
# index = ['국', '영', '수', '사', '과']
# df = pd.DataFrame(data, index=index)
#
# df.cov()
# ```

# %%
df.cov()
# Out:
#        학생1    학생2    학생3
# 학생1  62.50    0.0  31.25
# 학생2   0.00  117.5 -12.50
# 학생3  31.25  -12.5  87.50

# %% [markdown]
# ### 2.2.7 집계

# %% [markdown]
# #### groupby
# 그룹별 집계
#
# ```python
# data = {
#     '점수': [90, 85, 80, 75, 70, 95, 80, 70, 80, 95, 85, 95, 90, 70, 85, 85, 95, 90, 95, 85, 95, 95, 95, 100, 85],
#     '구분': ['현역']*5 + ['현역']*5 + ['현역']*5 + ['재수']*5 + ['재수']*5
# }
# df = pd.DataFrame(data)
#
# df.groupby('구분').mean()
# ```

# %%
data = {
    '점수': [90, 85, 80, 75, 70, 95, 80, 70, 80, 95, 85, 95, 90, 70, 85, 85, 95, 90, 95, 85, 95, 95, 95, 100, 85],
    '구분': ['현역']*5 + ['현역']*5 + ['현역']*5 + ['재수']*5 + ['재수']*5
}
df = pd.DataFrame(data)
df
# Out:
#      점수  구분
# 0    90  현역
# 1    85  현역
# 2    80  현역
# 3    75  현역
# 4    70  현역
# 5    95  현역
# 6    80  현역
# 7    70  현역
# 8    80  현역
# 9    95  현역
# 10   85  현역
# 11   95  현역
# 12   90  현역
# 13   70  현역
# 14   85  현역
# 15   85  재수
# 16   95  재수
# 17   90  재수
# 18   95  재수
# 19   85  재수
# 20   95  재수
# 21   95  재수
# 22   95  재수
# 23  100  재수
# 24   85  재수

# %%
df.query('구분 == "현역"').mean()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_2908\4063107975.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.query('구분 == "현역"').mean()
# 점수    83.0
# dtype: float64

# %%
df.query('구분 == "재수"').mean()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_2908\3707166362.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.query('구분 == "재수"').mean()
# 점수    92.0
# dtype: float64

# %%
df.groupby('구분').mean()
# Out:
#       점수
# 구분
# 재수  92.0
# 현역  83.0

# %%
data = {
    '점수': [90, 85, 80, 75, 70, 95, 80, 70, 80, 95, 85, 95, 90, 70, 85, 85, 95, 90, 95, 85, 95, 95, 95, 100, 85],
    '구분': ['현역']*5 + ['현역']*5 + ['현역']*5 + ['재수']*5 + ['재수']*5,
    '지역': ['서울']*15 + ['경기']*5 + ['경남']*5
}
df = pd.DataFrame(data)
df
# Out:
#      점수  구분  지역
# 0    90  현역  서울
# 1    85  현역  서울
# 2    80  현역  서울
# 3    75  현역  서울
# 4    70  현역  서울
# 5    95  현역  서울
# 6    80  현역  서울
# 7    70  현역  서울
# 8    80  현역  서울
# 9    95  현역  서울
# 10   85  현역  서울
# 11   95  현역  서울
# 12   90  현역  서울
# 13   70  현역  서울
# 14   85  현역  서울
# 15   85  재수  경기
# 16   95  재수  경기
# 17   90  재수  경기
# 18   95  재수  경기
# 19   85  재수  경기
# 20   95  재수  경남
# 21   95  재수  경남
# 22   95  재수  경남
# 23  100  재수  경남
# 24   85  재수  경남

# %%
df.groupby(['지역', '구분']).mean()
# Out:
#          점수
# 지역 구분
# 경기 재수  90.0
# 경남 재수  94.0
# 서울 현역  83.0

# %%
df.groupby(['구분', '지역']).mean()
# Out:
#          점수
# 구분 지역
# 재수 경기  90.0
#    경남  94.0
# 현역 서울  83.0

# %% [markdown]
# #### agg
# 다양한 집계함수 사용 가능
#
# ```python
# data = {
#     '점수': [90, 85, 80, 75, 70, 95, 80, 70, 80, 95, 85, 95, 90, 70, 85, 85, 95, 90, 95, 85, 95, 95, 95, 100, 85],
#     '구분': ['현역']*5 + ['현역']*5 + ['현역']*5 + ['재수']*5 + ['재수']*5
# }
# df = pd.DataFrame(data)
#
# df.groupby('구분').agg(['min', 'max', 'mean'])
# ```

# %%
data = {
    '점수': [90, 85, 80, 75, 70, 95, 80, 70, 80, 95, 85, 95, 90, 70, 85, 85, 95, 90, 95, 85, 95, 95, 95, 100, 85],
    '구분': ['현역']*5 + ['현역']*5 + ['현역']*5 + ['재수']*5 + ['재수']*5
}
df = pd.DataFrame(data)

df.groupby('구분').agg(['min', 'max', 'mean'])
# Out:
#     점수
#    min  max  mean
# 구분
# 재수  85  100  92.0
# 현역  70   95  83.0

# %% [markdown]
# ### 2.2.8 결합

# %% [markdown]
# #### merge
# 두 데이터프레임 병합 <br>
#
# on: 결합 대상 key 컬럼 <br>
# how <br>
# - left: 왼쪽 데이터 프레임의 키를 중심으로 결합
# - right: 오른쪽 데이터 프레임의 키를 중심으로 결합
# - outer: 두 데이터 프레임의 키를 중심으로 결합
# - inner: 두 데이터 프레임에서 공통으로 존재하는 값만 결합
# - cross: 모든 경우의 수를 구하여 결합
#
# ```python
# df1 = pd.DataFrame({'a': ['foo', 'bar'], 'b': [1, 2]})
# df2 = pd.DataFrame({'a': ['foo', 'baz'], 'c': [3, 4]})
#
# df1.merge(df2, how='inner', on='a')
# df1.merge(df2, how='left', on='a')
# df1.merge(df2, how='cross')
#
#
# df1 = pd.DataFrame({'lkey': ['foo', 'bar', 'baz', 'foo'],
#                     'value': [1, 2, 3, 5]})
# df2 = pd.DataFrame({'rkey': ['foo', 'bar', 'baz', 'foo'],
#                     'value': [5, 6, 7, 8]})
#
# df1.merge(df2, left_on='lkey', right_on='rkey')
# df1.merge(df2, left_on='lkey', right_on='rkey', suffixes=('_left', '_right'))
# ```

# %%
df1 = pd.DataFrame({'a': ['foo', 'bar'], 'b': [1, 2]})
df2 = pd.DataFrame({'a': ['foo', 'baz'], 'c': [3, 4]})

# %%
df1.merge(df2, how='right', on='a')
# Out:
#      a    b  c
# 0  foo  1.0  3
# 1  baz  NaN  4

# %%
df1.merge(df2, left_on='lkey'. right_on='rkey'. suffixes=('_left'))
# Out:
#   File "C:\Users\user\AppData\Local\Temp\ipykernel_2908\4283217609.py", line 1
#     df1.merge(df2, left_on='lkey'. right_on='rkey')
#                                            ^
# SyntaxError: invalid syntax

# %% [markdown]
# #### concat
# 두 데이터프레임 결합 <br>
# 리스트 내의 데이터프레임 결합에도 사용 <br>
#
# ```python
# df1 = pd.DataFrame([['a', 1], ['b', 2]],
#                    columns=['letter', 'number'])
# df2 = pd.DataFrame([['c', 3], ['d', 4]],
#                    columns=['letter', 'number'])
#
# pd.concat([df1, df2])            # 아래로 결합
# pd.concat([df1, df2], axis=1)    # 옆으로 결합
#
#
# dataframe_list = [df1, df2]
# pd.concat(dataframe_list)
# ```

# %%
df1 = pd.DataFrame([['a', 1], ['b', 2]],
                   columns=['letter', 'number'])
df2 = pd.DataFrame([['c', 3], ['d', 4]],
                   columns=['letter', 'number'])

pd.concat([df1, df2])            # 아래로 결합
pd.concat([df1, df2], axis=1)    # 옆으로 결합
# Out:
#   letter  number letter  number
# 0      a       1      c       3
# 1      b       2      d       4

# %% [markdown]
# ### 2.2.9 데이터프레임 조작

# %% [markdown]
# #### explode
# 리스트 내의 값을 row로 분해
#
# ```python
# data = {
#     '학생1': [[90, 85, 80, 75, 70]],
#     '학생2': [[95, 80, 70, 80, 95]],
#     '학생3': [[85, 95, 90, 70, 85]],
# }
# df = pd.DataFrame(data)
#
# df.explode('학생1')
# df.explode('학생2')
# df.explode('학생3')
# ```

# %%
data = {
    '학생1': [[90, 85, 80, 75, 70]],
    '학생2': [[95, 80, 70, 80, 95]],
    '학생3': [[85, 95, 90, 70, 85]],
}
df = pd.DataFrame(data)

# %%
df
# Out:
#                     학생1                   학생2                   학생3
# 0  [90, 85, 80, 75, 70]  [95, 80, 70, 80, 95]  [85, 95, 90, 70, 85]

# %%
df.explode('학생1')
# Out:
#   학생1                   학생2                   학생3
# 0  90  [95, 80, 70, 80, 95]  [85, 95, 90, 70, 85]
# 0  85  [95, 80, 70, 80, 95]  [85, 95, 90, 70, 85]
# 0  80  [95, 80, 70, 80, 95]  [85, 95, 90, 70, 85]
# 0  75  [95, 80, 70, 80, 95]  [85, 95, 90, 70, 85]
# 0  70  [95, 80, 70, 80, 95]  [85, 95, 90, 70, 85]

# %%
df.explode(column='학생1')
# Out:
#   학생1                   학생2                   학생3
# 0  90  [95, 80, 70, 80, 95]  [85, 95, 90, 70, 85]
# 0  85  [95, 80, 70, 80, 95]  [85, 95, 90, 70, 85]
# 0  80  [95, 80, 70, 80, 95]  [85, 95, 90, 70, 85]
# 0  75  [95, 80, 70, 80, 95]  [85, 95, 90, 70, 85]
# 0  70  [95, 80, 70, 80, 95]  [85, 95, 90, 70, 85]

# %%
df.explode(column=['학생1','학생2','학생3'])
# Out:
#   학생1 학생2 학생3
# 0  90  95  85
# 0  85  80  95
# 0  80  70  90
# 0  75  80  70
# 0  70  95  85

# %% [markdown]
# #### pivot
# 인덱스, 컬럼 값으로 데이터 재정렬
#
# ```python
# df = pd.DataFrame({'foo': ['one', 'one', 'one', 'two', 'two',
#                            'two'],
#                    'bar': ['A', 'B', 'C', 'A', 'B', 'C'],
#                    'baz': [1, 2, 3, 4, 5, 6],
#                    'zoo': ['x', 'y', 'z', 'q', 'w', 't']})
#
# df.pivot(index='foo', columns='bar', values='baz')
# df.pivot(index='foo', columns='bar')['baz']
# df.pivot(index='foo', columns='bar', values=['baz', 'zoo'])
# ```

# %%
df = pd.DataFrame({'foo': ['one', 'one', 'one', 'two', 'two',
                           'two'],
                   'bar': ['A', 'B', 'C', 'A', 'B', 'C'],
                   'baz': [1, 2, 3, 4, 5, 6],
                   'zoo': ['x', 'y', 'z', 'q', 'w', 't']})

# %%
df
# Out:
#    foo bar  baz zoo
# 0  one   A    1   x
# 1  one   B    2   y
# 2  one   C    3   z
# 3  two   A    4   q
# 4  two   B    5   w
# 5  two   C    6   t

# %%
df.pivot(index='foo', columns='bar', values='baz')
# Out:
# bar  A  B  C
# foo
# one  1  2  3
# two  4  5  6

# %%
df.pivot(index='foo', columns='bar', values='zoo')
# Out:
# bar  A  B  C
# foo
# one  x  y  z
# two  q  w  t

# %% [markdown]
# #### melt
# uppivot, 데이터 프레임 재정렬
#
# ```python
# data = {
#   'A': {0: 'a', 1: 'b', 2: 'c'},
#   'B': {0: 1, 1: 3, 2: 5},
#   'C': {0: 2, 1: 4, 2: 6}
#   }
# df = pd.DataFrame(data)
#
#
# df.melt(id_vars=['A'], value_vars=['B'])
# df.melt(id_vars=['A'], value_vars=['B', 'C'])
# df.melt(id_vars=['A'], value_vars=['B', 'C'], var_name='new_var_name', value_name='new_value_name')
# ```

# %%
data = {
  'A': {0: 'a', 1: 'b', 2: 'c'},
  'B': {0: 1, 1: 3, 2: 5},
  'C': {0: 2, 1: 4, 2: 6}
  }
df = pd.DataFrame(data)

# %%
df
# Out:
#    A  B  C
# 0  a  1  2
# 1  b  3  4
# 2  c  5  6

# %%
df.melt(id_vars=['A'], value_vars=['B', 'C'])
# Out:
#    A variable  value
# 0  a        B      1
# 1  b        B      3
# 2  c        B      5
# 3  a        C      2
# 4  b        C      4
# 5  c        C      6

# %% [markdown]
# #### stack
# 데이터를 아래로 이어붙임
#
# ```python
# data = {
#     '학생1': [90, 85, 80, 75, 70],
#     '학생2': [95, 80, 70, 80, 95],
#     '학생3': [85, 95, 90, 70, 85],
# }
# index = ['국', '영', '수', '사', '과']
# df = pd.DataFrame(data, index=index)
#
# df.stack()
# ```

# %%
data = {
    '학생1': [90, 85, 80, 75, 70],
    '학생2': [95, 80, 70, 80, 95],
    '학생3': [85, 95, 90, 70, 85],
}
index = ['국', '영', '수', '사', '과']
df = pd.DataFrame(data, index=index)

# %%
df.reset_index().melt(id_vars='index', value_vars=['학생1', '학생2', '학생3'])
# Out:
#    index variable  value
# 0      국      학생1     90
# 1      영      학생1     85
# 2      수      학생1     80
# 3      사      학생1     75
# 4      과      학생1     70
# 5      국      학생2     95
# 6      영      학생2     80
# 7      수      학생2     70
# 8      사      학생2     80
# 9      과      학생2     95
# 10     국      학생3     85
# 11     영      학생3     95
# 12     수      학생3     90
# 13     사      학생3     70
# 14     과      학생3     85

# %%
df.melt(id_vars='index', value_vars=df.columns[1:])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3628             try:
# -> 3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
#
# c:\ProgramData\Anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# c:\ProgramData\Anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# c:\ProgramData\Anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine._get_loc_duplicates()
#
# c:\ProgramData\Anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine._maybe_get_bool_indexer()
#
# c:\ProgramData\Anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index._unpack_bool_indexer()
#
# KeyError: 'index'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_2908\3267495079.py in <module>
# ----> 1 df.melt(id_vars='index', value_vars=df.columns[1:])
#
# c:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in melt(self, id_vars, value_vars, var_name, value_name, col_level, ignore_index)
#    8441     ) -> DataFrame:
#    8442
# -> 8443         return melt(
#    8444             self,
#    8445             id_vars=id_vars,
#
# c:\ProgramData\Anaconda3\lib\site-packages\pandas\core\reshape\melt.py in melt(frame, id_vars, value_vars, var_name, value_name, col_level, ignore_index)
#     130     mdata = {}
#     131     for col in id_vars:
# --> 132         id_data = frame.pop(col)
#     133         if is_extension_array_dtype(id_data):
#     134             id_data = concat([id_data] * K, ignore_index=True)
#
# c:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in pop(self, item)
#    5271         3  monkey        NaN
#    5272         """
# -> 5273         return super().pop(item=item)
#    5274
#    5275     @doc(NDFrame.replace, **_shared_doc_kwargs)
#
# c:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in pop(self, item)
#     863
#     864     def pop(self, item: Hashable) -> Series | Any:
# --> 865         result = self[item]
#     866         del self[item]
#     867
#
# c:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3503             if self.columns.nlevels > 1:
#    3504                 return self._getitem_multilevel(key)
# -> 3505             indexer = self.columns.get_loc(key)
#    3506             if is_integer(indexer):
#    3507                 indexer = [indexer]
#
# c:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
# -> 3631                 raise KeyError(key) from err
#    3632             except TypeError:
#    3633                 # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 'index'

# %% [markdown]
# #### unstack
#
# 멀티 인덱스 데이터프레임을 컬럼으로 분할
#
#
# ```python
# scores = [90, 95, 85, 85, 80, 95, 80, 70, 90, 75, 80, 70, 70, 95, 85]
# index = pd.MultiIndex.from_tuples(
#     [('국', '학생1'),
#      ('국', '학생2'),
#      ('국', '학생3'),
#      ('영', '학생1'),
#      ('영', '학생2'),
#      ('영', '학생3'),
#      ('수', '학생1'),
#      ('수', '학생2'),
#      ('수', '학생3'),
#      ('사', '학생1'),
#      ('사', '학생2'),
#      ('사', '학생3'),
#      ('과', '학생1'),
#      ('과', '학생2'),
#      ('과', '학생3')],
# )
# df = pd.Series(scores, index=index)
#
# df.unstack()
# ```

# %%
df
# Out:
#    학생1  학생2  학생3
# 국   90   95   85
# 영   85   80   95
# 수   80   70   90
# 사   75   80   70
# 과   70   95   85

# %%
df.stack().to_frame().reset_index()
# Out:
#    level_0 level_1   0
# 0        국     학생1  90
# 1        국     학생2  95
# 2        국     학생3  85
# 3        영     학생1  85
# 4        영     학생2  80
# 5        영     학생3  95
# 6        수     학생1  80
# 7        수     학생2  70
# 8        수     학생3  90
# 9        사     학생1  75
# 10       사     학생2  80
# 11       사     학생3  70
# 12       과     학생1  70
# 13       과     학생2  95
# 14       과     학생3  85

# %%
scores = [90, 95, 85, 85, 80, 95, 80, 70, 90, 75, 80, 70, 70, 95, 85]
index = pd.MultiIndex.from_tuples(
    [('국', '학생1'),
     ('국', '학생2'),
     ('국', '학생3'),
     ('영', '학생1'),
     ('영', '학생2'),
     ('영', '학생3'),
     ('수', '학생1'),
     ('수', '학생2'),
     ('수', '학생3'),
     ('사', '학생1'),
     ('사', '학생2'),
     ('사', '학생3'),
     ('과', '학생1'),
     ('과', '학생2'),
     ('과', '학생3')],
)

df = pd.Series(scores, index=index)

# %%
df.unstack()
# Out:
#    학생1  학생2  학생3
# 과   70   95   85
# 국   90   95   85
# 사   75   80   70
# 수   80   70   90
# 영   85   80   95

# %% [markdown]
# ## 2.3. 시계열 데이터

# %% [markdown]
# #### date_range
# 주어진 범위에 해당하는 date 리스트 반환
#
# ```python
# pd.date_range(start='9/1/2022', end='9/30/2022')
# pd.date_range(start='2022-09-01', end='2022-09-30')
# pd.date_range(start='2022-09-01', end='2022-09-30', freq='1W')    # 1주 단위로 date 생성
# pd.date_range(start='2022-09-01', periods=8)                      # 시작일 기준 8개의 날 생성
# pd.date_range(end='2022-09-01', periods=8)                        # 종료일 기준 8개의 날 생성
# ```

# %%
pd.date_range('20221101', '20221201', freq='D')
# Out:
# DatetimeIndex(['2022-11-01', '2022-11-02', '2022-11-03', '2022-11-04',
#                '2022-11-05', '2022-11-06', '2022-11-07', '2022-11-08',
#                '2022-11-09', '2022-11-10', '2022-11-11', '2022-11-12',
#                '2022-11-13', '2022-11-14', '2022-11-15', '2022-11-16',
#                '2022-11-17', '2022-11-18', '2022-11-19', '2022-11-20',
#                '2022-11-21', '2022-11-22', '2022-11-23', '2022-11-24',
#                '2022-11-25', '2022-11-26', '2022-11-27', '2022-11-28',
#                '2022-11-29', '2022-11-30', '2022-12-01'],
#               dtype='datetime64[ns]', freq='D')

# %%
pd.date_range('20221101', '20221201', freq='W')
# Out:
# DatetimeIndex(['2022-11-06', '2022-11-13', '2022-11-20', '2022-11-27'], dtype='datetime64[ns]', freq='W-SUN')

# %%
pd.date_range('20221101', '20221201', freq='M')
# Out:
# DatetimeIndex(['2022-11-30'], dtype='datetime64[ns]', freq='M')

# %%
pd.date_range('20221101', '20221201', freq='B')  # 외국 기준 영업일
# Out:
# DatetimeIndex(['2022-11-01', '2022-11-02', '2022-11-03', '2022-11-04',
#                '2022-11-07', '2022-11-08', '2022-11-09', '2022-11-10',
#                '2022-11-11', '2022-11-14', '2022-11-15', '2022-11-16',
#                '2022-11-17', '2022-11-18', '2022-11-21', '2022-11-22',
#                '2022-11-23', '2022-11-24', '2022-11-25', '2022-11-28',
#                '2022-11-29', '2022-11-30', '2022-12-01'],
#               dtype='datetime64[ns]', freq='B')

# %% [markdown]
# #### shift
#
# 데이터 프레임의 인덱스 또는 컬럼을 주어진 숫자 만큼 옮김
#
# ```python
# df = pd.DataFrame({"Col1": [10, 20, 15, 30, 45],
#                    "Col2": [13, 23, 18, 33, 48],
#                    "Col3": [17, 27, 22, 37, 52]},
#                   index=pd.date_range("2020-01-01", "2020-01-05"))
#
# df.shift(periods=1)                 # 아래로 한 칸 이동
# df.shift(periods=1, axis='columns') # 컬럼 한 칸 이동
# df.shift(periods=3, fill_value=0)   # 아래로 세 칸 이동 후 nan값을 0으로 채움
# df.shift(periods=3, freq='D')       # 3일 이동
# ```

# %%
df = pd.DataFrame({"Col1": [10, 20, 15, 30, 45],
                   "Col2": [13, 23, 18, 33, 48],
                   "Col3": [17, 27, 22, 37, 52]},
                  index=pd.date_range("2020-01-01", "2020-01-05"))

# %%
df.shift(2)
# Out:
#             Col1  Col2  Col3
# 2020-01-01   NaN   NaN   NaN
# 2020-01-02   NaN   NaN   NaN
# 2020-01-03  10.0  13.0  17.0
# 2020-01-04  20.0  23.0  27.0
# 2020-01-05  15.0  18.0  22.0

# %%
df.shift(-1)
# Out:
#             Col1  Col2  Col3
# 2020-01-01  20.0  23.0  27.0
# 2020-01-02  15.0  18.0  22.0
# 2020-01-03  30.0  33.0  37.0
# 2020-01-04  45.0  48.0  52.0
# 2020-01-05   NaN   NaN   NaN

# %%
df
# Out:
#             Col1  Col2  Col3
# 2020-01-01    10    13    17
# 2020-01-02    20    23    27
# 2020-01-03    15    18    22
# 2020-01-04    30    33    37
# 2020-01-05    45    48    52

# %%
df.diff(2)
# Out:
#             Col1  Col2  Col3
# 2020-01-01   NaN   NaN   NaN
# 2020-01-02   NaN   NaN   NaN
# 2020-01-03   5.0   5.0   5.0
# 2020-01-04  10.0  10.0  10.0
# 2020-01-05  30.0  30.0  30.0

# %% [markdown]
# #### diff
# 주어진 숫자 만큼의 인덱스 혹은 컬럼 차를 계산
#
# ```python
# df = pd.DataFrame({"Col1": [10, 20, 15, 30, 45],
#                    "Col2": [13, 23, 18, 33, 48],
#                    "Col3": [17, 27, 22, 37, 52]},
#                   index=pd.date_range("2020-01-01", "2020-01-05"))
#
# df.diff()
# df.diff(periods=3)     # 3칸 간격의 차를 계산
# ```

# %% [markdown]
# #### pct_change
# 주어진 숫자 만큼의 인덱스 혹은 컬럼 변화율 계산
#
# ```python
# df = pd.DataFrame({"Col1": [10, 20, 15, 30, 45],
#                    "Col2": [13, 23, 18, 33, 48],
#                    "Col3": [17, 27, 22, 37, 52]},
#                   index=pd.date_range("2020-01-01", "2020-01-05"))
#
# df.pct_change()
# df.pct_change(periods=3)     # 3칸 간격의 변화율 계산
# ```

# %%
df.pct_change()
# Out:
#             Col1      Col2      Col3
# 2020-01-01   NaN       NaN       NaN
# 2020-01-02  1.00  0.769231  0.588235
# 2020-01-03 -0.25 -0.217391 -0.185185
# 2020-01-04  1.00  0.833333  0.681818
# 2020-01-05  0.50  0.454545  0.405405

# %%
df.pct_change(2)
# Out:
#             Col1      Col2      Col3
# 2020-01-01   NaN       NaN       NaN
# 2020-01-02   NaN       NaN       NaN
# 2020-01-03   0.5  0.384615  0.294118
# 2020-01-04   0.5  0.434783  0.370370
# 2020-01-05   2.0  1.666667  1.363636

# %% [markdown]
# #### rolling
# 주어진 숫자 만큼의 윈도우 생성 <br>
# 생성된 윈도우 내에서 집계 함수 사용 가능 <br>
#
# ```python
# df = pd.DataFrame({"Col1": [10, 20, 15, 30, 45],
#                    "Col2": [13, 23, 18, 33, 48],
#                    "Col3": [17, 27, 22, 37, 52]},
#                   index=pd.date_range("2020-01-01", "2020-01-05"))
#
# df.rolling(2).sum()
# ```

# %%
df = pd.DataFrame({"Col1": [10, 20, 15, 30, 45],
                   "Col2": [13, 23, 18, 33, 48],
                   "Col3": [17, 27, 22, 37, 52]},
                  index=pd.date_range("2020-01-01", "2020-01-05"))

# %%
df.rolling(2)
# Out:
# Rolling [window=2,center=False,axis=0,method=single]

# %%
df.rolling(2).sum()
# Out:
#             Col1  Col2  Col3
# 2020-01-01   NaN   NaN   NaN
# 2020-01-02  30.0  36.0  44.0
# 2020-01-03  35.0  41.0  49.0
# 2020-01-04  45.0  51.0  59.0
# 2020-01-05  75.0  81.0  89.0

# %%
df.rolling(5).mean()
# Out:
#             Col1  Col2  Col3
# 2020-01-01   NaN   NaN   NaN
# 2020-01-02   NaN   NaN   NaN
# 2020-01-03   NaN   NaN   NaN
# 2020-01-04   NaN   NaN   NaN
# 2020-01-05  24.0  27.0  31.0

# %% [markdown]
# ## 2.4 시각화
# 데이터프레임 값을 시각화
#
# ```python
# df = pd.DataFrame({"Col1": [10, 20, 15, 30, 45],
#                    "Col2": [13, 23, 18, 33, 48],
#                    "Col3": [17, 27, 22, 37, 52]},
#                   index=pd.date_range("2020-01-01", "2020-01-05"))
#
# df.plot()                            # 모든 컬럼에 대한 line 그래프
# df.plot(legend=False)                # 범주를 출력하지 않음
# df.plot(kind='box')                  # 열 별 box plot
# df.plot(kind='density')              # 열 별 밀도함수
# df.plot(kind='pie', subplots=True)   # pie 그래프
# ```

# %%
df.plot()
# Out:
# <AxesSubplot:>

# %%
df
# Out:
#             Col1  Col2  Col3
# 2020-01-01    10    13    17
# 2020-01-02    20    23    27
# 2020-01-03    15    18    22
# 2020-01-04    30    33    37
# 2020-01-05    45    48    52

# %%
df.plot(legend=False)
# Out:
# <AxesSubplot:>

# %%
df.plot(kind='box')
# Out:
# <AxesSubplot:>

# %%
df.plot(kind='density')
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
df.plot(kind='pie', subplots=True, legend=False)
# Out:
# array([<AxesSubplot:ylabel='Col1'>, <AxesSubplot:ylabel='Col2'>,
#        <AxesSubplot:ylabel='Col3'>], dtype=object)
