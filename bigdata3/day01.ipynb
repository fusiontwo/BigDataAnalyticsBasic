# %% [markdown]
# # 7\. Visualization

# %% [markdown]
# ## 7.1 matplotlib
#
# reference: https://matplotlib.org/stable/plot_types/index.html

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# #### Scatter Plots
# 데이터가 어떻게 분포하고 있는지 확인할 때 사용
#
# ```python
# import matplotlib.pyplot as plt
# import numpy as np
#
# # make the data
# x = 4 + np.random.normal(0, 2, 24)
# y = 4 + np.random.normal(0, 2, len(x))
#
# # size and color:
# sizes = np.random.uniform(15, 80, len(x))
# colors = np.random.uniform(15, 80, len(x))
#
# # plot
# fig, ax = plt.subplots()
# ax.scatter(x, y, s=sizes, c=colors, vmin=0, vmax=100)
#
# ax.set(
#   xlim=(0, 8), xticks=np.arange(1, 8),
#   ylim=(0, 8), yticks=np.arange(1, 8)
#   )
#
# plt.show()
# ```

# %%
plt.scatter(x, y)

# %%
x = 4 + np.random.normal(0, 2, 24)
y = 4 + np.random.normal(0, 2, (len(x)))

sizes = np.random.uniform(15, 80, len(x))
colors = np.random.uniform(15, 80, len(x))

# %%
x
# Out:
# array([ 3.52920557,  4.33777888,  3.53851877,  6.22806729,  4.80725508,
#         0.92827384,  6.68396016,  3.52045586,  4.89409025,  4.23284233,
#         6.38725919,  6.21208921,  4.15888336,  4.98736681,  4.73809996,
#         5.95535616,  5.01216672,  3.14880741,  4.12444004,  5.19972449,
#         3.84249976,  5.25242286, 10.40668574,  4.67392027])

# %%
y
# Out:
# array([5.78212225, 5.70246031, 8.50807801, 1.5048892 , 6.09977225,
#        4.99609857, 4.75987808, 2.49597022, 2.15778466, 4.50422358,
#        7.32343665, 7.11854928, 6.00009546, 5.63147366, 4.2998895 ,
#        5.8893605 , 2.96681962, 4.95108255, 3.95086026, 1.80207486,
#        1.71237039, 4.18386579, 4.84102035, 6.14639717])

# %%
fig, ax = plt.subplots()
ax.scatter(x, y, s=sizes, c=colors)

plt.show()

# %%
fig = plt.figure()
ax1 = fig.add_subplot(2, 1, 1)
ax1.scatter(x, y, s=sizes, c=colors)

ax2 = fig.add_subplot(2, 1, 2)
ax2.scatter(x, y, s=sizes, c=colors)

plt.show()

# %%
fig = plt.figure()
ax1 = fig.add_subplot(2, 1, 1)
ax1.scatter(x, y)

ax2 = fig.add_subplot(2, 1, 2)
ax2.scatter(x, y)

plt.show()

# %%
plt.scatter(x, y, s=sizes, c=colors)

# %% [markdown]
# #### Bar Charts
# 범주별 빈도를 확인할 때 사용
#
# ```python
# import matplotlib.pyplot as plt
# import numpy as np
#
# # make data:
# x = 0.5 + np.arange(8)
# y = np.random.uniform(2, 7, len(x))
#
# # plot
# fig, ax = plt.subplots()
#
# ax.bar(x, y, width=1, edgecolor="white", linewidth=0.7)
#
# ax.set(
#   xlim=(0, 8), xticks=np.arange(1, 8),
#   ylim=(0, 8), yticks=np.arange(1, 8)
#   )
#
# plt.show()
# ```

# %%
x = 0.5 * np.arange(8)
y = np.random.uniform(2, 10, len(x))

# %%
x
# Out:
# array([0. , 0.5, 1. , 1.5, 2. , 2.5, 3. , 3.5])

# %%
y
# Out:
# array([7.92477553, 5.25543296, 7.19977385, 5.15761787, 8.03057589,
#        5.00406182, 3.49367621, 9.43491897])

# %%
plt.bar(x, y)
# Out:
# <BarContainer object of 8 artists>

# %% [markdown]
# #### Line Chart
# 시간의 흐름에 따른 변화를 보고자할 때 사용
#
# ```python
# import matplotlib.pyplot as plt
# import numpy as np
#
# # make data
# x = np.linspace(0, 10, 100)
# y = 4 + 2 * np.sin(2 * x)
#
# # plot
# fig, ax = plt.subplots()
#
# ax.plot(x, y, linewidth=2.0)
#
# ax.set(
#   xlim=(0, 8), xticks=np.arange(1, 8),
#   ylim=(0, 8), yticks=np.arange(1, 8)
#   )
#
# plt.show()
# ```

# %%
x
# Out:
# array([ 0.        ,  0.1010101 ,  0.2020202 ,  0.3030303 ,  0.4040404 ,
#         0.50505051,  0.60606061,  0.70707071,  0.80808081,  0.90909091,
#         1.01010101,  1.11111111,  1.21212121,  1.31313131,  1.41414141,
#         1.51515152,  1.61616162,  1.71717172,  1.81818182,  1.91919192,
#         2.02020202,  2.12121212,  2.22222222,  2.32323232,  2.42424242,
#         2.52525253,  2.62626263,  2.72727273,  2.82828283,  2.92929293,
#         3.03030303,  3.13131313,  3.23232323,  3.33333333,  3.43434343,
#         3.53535354,  3.63636364,  3.73737374,  3.83838384,  3.93939394,
#         4.04040404,  4.14141414,  4.24242424,  4.34343434,  4.44444444,
#         4.54545455,  4.64646465,  4.74747475,  4.84848485,  4.94949495,
#         5.05050505,  5.15151515,  5.25252525,  5.35353535,  5.45454545,
#         5.55555556,  5.65656566,  5.75757576,  5.85858586,  5.95959596,
#         6.06060606,  6.16161616,  6.26262626,  6.36363636,  6.46464646,
#         6.56565657,  6.66666667,  6.76767677,  6.86868687,  6.96969697,
#         7.07070707,  7.17171717,  7.27272727,  7.37373737,  7.47474747,
#         7.57575758,  7.67676768,  7.77777778,  7.87878788,  7.97979798,
#         8.08080808,  8.18181818,  8.28282828,  8.38383838,  8.48484848,
#         8.58585859,  8.68686869,  8.78787879,  8.88888889,  8.98989899,
#         9.09090909,  9.19191919,  9.29292929,  9.39393939,  9.49494949,
#         9.5959596 ,  9.6969697 ,  9.7979798 ,  9.8989899 , 10.        ])

# %%
x = np.linspace(0, 10, 100)
y = 4 + 2*np.sin(2*x)

plt.plot(x, y)

# %%
x = np.linspace(0, 10, 100)
y = 4 + 2*np.sin(2*x)

plt.scatter(x, y)

# %% [markdown]
# #### Box Plots
# 변수의 이상치 및 특징을 파악하기 위해 사용
#
# ```python
# import matplotlib.pyplot as plt
# import numpy as np
#
# plt.style.use('_mpl-gallery')
#
# # make data:
# data = np.random.normal((3, 5, 4), (1.25, 1.00, 1.25), (100, 3))
#
# # plot
# fig, ax = plt.subplots()
# box_plot = ax.boxplot(
#   data,
#   positions=[2, 4, 6],
#   widths=1.5, patch_artist=True,
#   showmeans=False, showfliers=False,
#   medianprops={"color": "white", "linewidth": 0.5},
#   boxprops={
#     "facecolor": "C0", "edgecolor": "white", "linewidth": 0.5},
#   whiskerprops={"color": "C0", "linewidth": 1.5},
#   capprops={"color": "C0", "linewidth": 1.5}
#   )
#
# plt.show()
# ```

# %%
data = np.random.normal((3, 5, 4), (1.25, 1.00, 1.25), (100, 3))

# %%
data.shape
# Out:
# (100, 3)

# %%
plt.boxplot(data)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x24d4b2d58b0>,
#   <matplotlib.lines.Line2D at 0x24d4b2d5b80>,
#   <matplotlib.lines.Line2D at 0x24d4b2e5cd0>,
#   <matplotlib.lines.Line2D at 0x24d4b2e5fa0>,
#   <matplotlib.lines.Line2D at 0x24d4b2ff130>,
#   <matplotlib.lines.Line2D at 0x24d4b2ff400>],
#  'caps': [<matplotlib.lines.Line2D at 0x24d4b2d5e50>,
#   <matplotlib.lines.Line2D at 0x24d4b2e5160>,
#   <matplotlib.lines.Line2D at 0x24d4b2f22b0>,
#   <matplotlib.lines.Line2D at 0x24d4b2f25b0>,
#   <matplotlib.lines.Line2D at 0x24d4b2ff6d0>,
#   <matplotlib.lines.Line2D at 0x24d4b2ff9a0>],
#  'boxes': [<matplotlib.lines.Line2D at 0x24d4b2d55e0>,
#   <matplotlib.lines.Line2D at 0x24d4b2e59d0>,
#   <matplotlib.lines.Line2D at 0x24d4b2f2e20>],
#  'medians': [<matplotlib.lines.Line2D at 0x24d4b2e5430>,
#   <matplotlib.lines.Line2D at 0x24d4b2f2880>,
#   <matplotlib.lines.Line2D at 0x24d4b2ffc70>],
#  'fliers': [<matplotlib.lines.Line2D at 0x24d4b2e5700>,
#   <matplotlib.lines.Line2D at 0x24d4b2f2b50>,
#   <matplotlib.lines.Line2D at 0x24d4b2fff40>],
#  'means': []}

# %% [markdown]
# #### Pie Charts
# 카테고리별 비율을 시각화하기 위해 사용
#
# ```python
# import matplotlib.pyplot as plt
#
# # Pie chart, where the slices will be ordered and plotted counter-clockwise:
# labels = 'Frogs', 'Hogs', 'Dogs', 'Logs'
# sizes = [15, 30, 45, 10]
# explode = (0, 0.1, 0, 0)  # only "explode" the 2nd slice
#
# fig1, ax1 = plt.subplots()
# ax1.pie(
#   sizes,
#   explode=explode,
#   labels=labels,
#   autopct='%1.1f%%',
#   shadow=True,
#   startangle=90
#   )
# ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
#
# plt.show()
# ```

# %%
labels = 'Frogs', 'Hogs', 'Dogs', 'Logs'
counts = [15, 30, 45, 10]
explode = (0, 0.1, 0, 0)

plt.pie(counts, labels=labels, explode=explode, startangle=90, autopct='%1.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x24d49fdab80>,
#   <matplotlib.patches.Wedge at 0x24d49e80ac0>,
#   <matplotlib.patches.Wedge at 0x24d49e80eb0>,
#   <matplotlib.patches.Wedge at 0x24d49e86190>],
#  [Text(-0.4993895680663527, 0.9801071672559598, 'Frogs'),
#   Text(-1.1412677917792124, -0.3708204787324995, 'Hogs'),
#   Text(0.9801072140121813, -0.4993894763020948, 'Dogs'),
#   Text(0.33991864973549485, 1.0461621822461364, 'Logs')],
#  [Text(-0.2723943098543742, 0.5346039094123416, '15.0%'),
#   Text(-0.6657395452045406, -0.2163119459272914, '30.0%'),
#   Text(0.5346039349157352, -0.27239425980114257, '45.0%'),
#   Text(0.1854101725829972, 0.5706339175888016, '10.0%')])

# %% [markdown]
# #### Histograms
# 데이터의 분포를 확인하기 위해 사용
#
# ```python
# import matplotlib.pyplot as plt
# import numpy as np
#
# # make data
# x = 4 + np.random.normal(0, 1.5, 200)
#
# # plot:
# fig, ax = plt.subplots()
#
# ax.hist(x, bins=8, linewidth=0.5, edgecolor="white")
#
# ax.set(
#   xlim=(0, 8), xticks=np.arange(1, 8),
#   ylim=(0, 56), yticks=np.linspace(0, 56, 9))
#
# plt.show()
# ```

# %%
x = 4+ np.random.normal(0, 2, 1000)

plt.hist(x, bins=20)
# Out:
# (array([  3.,   4.,  10.,  25.,  30.,  60.,  93., 118., 138., 130., 129.,
#          84.,  83.,  33.,  31.,  14.,   6.,   3.,   3.,   3.]),
#  array([-2.10065249, -1.4317546 , -0.76285672, -0.09395883,  0.57493905,
#          1.24383694,  1.91273483,  2.58163271,  3.2505306 ,  3.91942848,
#          4.58832637,  5.25722426,  5.92612214,  6.59502003,  7.26391791,
#          7.9328158 ,  8.60171369,  9.27061157,  9.93950946, 10.60840734,
#         11.27730523]),
#  <BarContainer object of 20 artists>)

# %% [markdown]
# ## 7.2 seaborn
#
# reference: https://seaborn.pydata.org

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_theme(style='whitegrid')

# %% [markdown]
# ### Scatter Plots
# x가 continous한 값이라면 산점도 <br>
# x가 categorical 값이라면 jitter <br>
# <br>
# args
#   - hue: 그룹 별 다른 색상으로 plot
#   - style: 카테고리별 다른 그림으로 plot
#   - col: 해당 컬럼의 값을 기준으로 분할하여 plot
#   - row: 해당 컬럼의 값을 기준으로 분할하여 plot
#
# ```python
# tips = sns.load_dataset("tips")
#
# sns.relplot(
#     data=tips,
#     x="total_bill", y="tip", hue="smoker", style="time",
# )
# ```

# %%
tips = sns.load_dataset('tips')

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
tips.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
tips.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.4 KB

# %%
sns.relplot(
    data=tips,
    x='total_bill',
    y='tip',
    style='sex',
    hue='smoker'
)

# %%
sns.relplot(
    data=tips,
    x='sex',
    y='tip'
)

# %% [markdown]
# ### Bar Charts
# args
#   - hue: 그룹 별 다른 색상으로 plot
#   - x: x를 쓰면 일반적인 수직 그래프
#   - y: y를 쓰면 수평 그래프
#   - kind='count': 빈도 계산
#   - palette='pastel': 다양한 색상을 입힘
#   - col: 해당 컬럼의 값을 기준으로 분할하여 plot
#   - row: 해당 컬럼의 값을 기준으로 분할하여 plot
#
# ```python
# titanic = sns.load_dataset("titanic")
#
# sns.catplot(
#     data=titanic,
#     x="deck", hue="class", kind="count",
#     palette="pastel",
# )
# ```

# %%
titanic = sns.load_dataset('titanic')

# %%
sns.catplot(
    data=titanic,
    x='deck',
    kind='count',
    hue='class'
)

# %%
sns.catplot(
    data=titanic,
    x='deck',
    kind='count',
    hue='sex'
)

# %% [markdown]
# ### Line Charts
#
# >
# x가 continous한 값이라면 일반적 시계열 모양 <br>
# x가 중복된 값을 가지고 있으면 95% 신뢰구간을 표현 <br>
# <br>
# args
#   - errorbar
#     - None: 신뢰구간 제거
#     - sd: 표준편차 신뢰구간
#   - hue: 그룹 별 다른 색상으로 plot
#   - style: 카테고리별 다른 그림으로 plot
#   - col: 해당 컬럼의 값을 기준으로 분할하여 plot
#   - row: 해당 컬럼의 값을 기준으로 분할하여 plot
#
# ```python
# dowjones = sns.load_dataset("dowjones")
# sns.relplot(data=dowjones, x="Date", y="Price", kind="line")
#
# fmri = sns.load_dataset("fmri")
# sns.relplot(data=fmri, x="timepoint", y="signal", kind="line")
# ```

# %%
dowjones = sns.load_dataset('dowjones')

# %%
sns.relplot(
    data=dowjones,
    x='Date',
    y='Price',
    kind='line'
)

# %% [markdown]
# ### Box Plots
# >
# args
#   - hue: 그룹 별 다른 색상으로 plot
#   - col: 해당 컬럼의 값을 기준으로 분할하여 plot
#   - row: 해당 컬럼의 값을 기준으로 분할하여 plot
#
# ```python
# tips = sns.load_dataset("tips")
# sns.catplot(data=tips, x="day", y="total_bill")                           # 점도표
# sns.catplot(data=tips, x="day", y="total_bill", kind="box")               # boxplot
# sns.catplot(
#   data=tips, x="total_bill", y="day", hue="sex",
#   kind="violin", split=True
#   ) # violin
# ```

# %%
tips = sns.load_dataset('tips')

# %%
sns.catplot(
    data=tips,
    x='day',
    y='total_bill'
)

# %%
sns.catplot(
    data=tips,
    x='day',
    y='tip',
    kind='box'
)

# %%
sns.catplot(
    data=tips,
    x='day',
    y='tip',
    hue='sex',
    kind='box'
)

# %%
sns.catplot(
    data=tips,
    x='day',
    y='total_bill',
    hue='sex',
    kind='box'
)

# %% [markdown]
# ### Histograms
# >
# args
#   - binwidth: 구간 범위 설정
#   - hue: 그룹 별 다른 색상으로 plot
#   - multiple: 다른 그룹을 어떻게 표현할지 설정
#     - stack: 합하여 출력
#     - dodge: 분리하여 출력
#   - col: 해당 컬럼의 값을 기준으로 분할하여 plot
#   - row: 해당 컬럼의 값을 기준으로 분할하여 plot
#   - stats: 어떤 통계지표로 출력할지 출력
#     - density: 밀도 출력
#     - probability: 확률 출력
#
# ```python
# penguins = sns.load_dataset("penguins")
# sns.displot(penguins, x="flipper_length_mm", binwidth=3, hue='species', multiple='dodge', stat='density')
# ```

# %%
penguins = sns.load_dataset('penguins')

# %%
penguins = penguins.dropna()  # NaN 값 제거

# %%
sns.displot(
    data=penguins,
    x='flipper_length_mm',
    binwidth=3,
    hue='species',
    stat='density'
)

# %% [markdown]
# ### Distplots
# >args
#   - kind: 어떤 타입을 출력할지 설정
#     - kde: 커널 분포 출력
#     - ecdf: 누적 분포 출력
#   - hue: 그룹 별 다른 색상으로 plot
#   - multiple: 다른 그룹을 어떻게 표현할지 설정
#     - stack: 합하여 출력
#     - dodge: 분리하여 출력
#   - fill: bool: 면적을 채울지 설정
#
# ```python
# sns.displot(penguins, x="flipper_length_mm", kind="kde")
# ```
# <br>
#
#
# **joint plot**
# ```python
# sns.jointplot(data=penguins, x="bill_length_mm", y="bill_depth_mm")
#
# sns.jointplot(
#     data=penguins,
#     x="bill_length_mm", y="bill_depth_mm", hue="species",
#     kind="kde"
# )
#
# ```

# %%
sns.displot(
    data=penguins,
    x='flipper_length_mm',
    hue='species',
    kind='kde'
)

# %%
sns.jointplot(
    data=penguins,
    x='flipper_length_mm',
    y='bill_depth_mm'
)

# %%
sns.displot(
    data=penguins,
    x='flipper_length_mm',
    y='bill_depth_mm',
    hue='species',
    kind='kde'
)

# %% [markdown]
# ### Heatmaps
# >
# args
# - cmap: colormap 설정
#   - Blues
#   - Reds
#   - YlGnBu
#
# ```python
# normal_data = np.random.randn(10, 12)
# ax = sns.heatmap(normal_data)
# ```

# %%
data = np.random.randn(10, 12)
sns.heatmap(
    data=data,
    cmap='YlGnBu'
)
# Out:
# <AxesSubplot:>

# %%
data = np.random.randn(10, 12)
sns.heatmap(
    data=data,
    cmap='PiYG_r'
)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Model
# >
# args
# - y_jitter: y값의 출력 옵션 설정
# - hue: 그룹 별 다른 색상으로 plot
# - markers: 어떤 모양으로 표현할지 설정
# - logistic: bool
#   - True: logistic regression plot
# - lowess
#   - True: nonparametric regression by lowess
# - col: 해당 컬럼의 값을 기준으로 분할하여 plot
# - row: 해당 컬럼의 값을 기준으로 분할하여 plot
#
# ```python
# tips = sns.load_dataset("tips")
# sns.lmplot(x="total_bill", y="tip", data=tips)
#
# tips["big_tip"] = (tips.tip / tips.total_bill) > .15
# sns.lmplot(x="total_bill", y="big_tip", data=tips, y_jitter=.03, logistic=True)
# ```
# <br>
#
# **joint plot**
# ```python
# sns.jointplot(x="total_bill", y="tip", data=tips, kind="reg");
# ```
#
# **pair plot**
# ```python
# sns.pairplot(tips, x_vars=["total_bill", "size"], y_vars=["tip"],
#              hue="smoker", height=5, kind="reg");
# ```

# %%
tips = sns.load_dataset('tips')
sns.lmplot(x='total_bill', y='tip', data=tips)

# %%
sns.jointplot(
    data=tips,
    x='total_bill',
    y='tip',
    kind='reg'
)

# %%
sns.pairplot(
    data=tips,
    x_vars=['total_bill', 'size'],
    y_vars=['tip'],
    hue='smoker',
    kind='reg',
    height=10
)
