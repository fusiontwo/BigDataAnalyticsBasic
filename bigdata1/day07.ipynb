# %% [markdown]
# # 5.Data Collection with API

# %%
import pandas as pd
import requests
import json
import xml.etree.ElementTree as ET
from tqdm import tqdm

# %% [markdown]
# ## 5.2 Dart
#
# url에 key와 value값을 추가하여 호출
#
# site: https://opendart.fss.or.kr/ <br>
# reference: https://opendart.fss.or.kr/guide/main.do?apiGrpCd=DS001 <br>

# %% [markdown]
# ### 공시정보
#
# ```python
# https://opendart.fss.or.kr/api/document.xml
# ```

# %%
info_url = 'https://opendart.fss.or.kr/api/list.xml?crtfc_key=86b1325201d61a7854696bcc35b6d88105cf88f2'
# 'https://opendart.fss.or.kr/api/list.xml?crtfc_key=86b1325201d61a7854696bcc35b6d88105cf88f2'
response = requests.get(info_url)
response.text
# Out:
# '<?xml version="1.0" encoding="UTF-8" standalone="yes"?><result><status>013</status><message>조회된 데이타가 없습니다.</message></result>'

# %%
tree = ET.parse(' /data/CORPCODE.xml')
root = tree.getroot()

corpcode = pd.DataFrame()
for i, child in enumerate(tqdm(root)):
    data = {
        child[0].tag: child[0].text,
        child[1].tag: child[1].text,
        child[2].tag: child[2].text,
        child[3].tag: child[3].text,
    }

    corpcode = corpcode.append(pd.DataFrame(data, index=[i]))

# %%
corpcode.loc[ccorpcode.stock_code != " "]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_11040\2288280585.py in <module>
# ----> 1 corpcode.loc[ccorpcode.stock_code != " "]
#
# NameError: name 'corpcode' is not defined

# %% [markdown]
# ### 기업개황
#
# ```python
# https://opendart.fss.or.kr/api/company.json?crtfc_key=xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx&corp_code=00126380
# ```

# %%
info_url = 'https://opendart.fss.or.kr/api/company.json?crtfc_key=86b1325201d61a7854696bcc35b6d88105cf88f2&corp_code=00126380'
response = requests.get(info_url)
response.text
# Out:
# '{"status":"000","message":"정상","corp_code":"00126380","corp_name":"삼성전자(주)","corp_name_eng":"SAMSUNG ELECTRONICS CO,.LTD","stock_name":"삼성전자","stock_code":"005930","ceo_nm":"한종희, 경계현","corp_cls":"Y","jurir_no":"1301110006246","bizr_no":"1248100998","adres":"경기도 수원시 영통구  삼성로 129 (매탄동)","hm_url":"www.sec.co.kr","ir_url":"","phn_no":"031-200-1114","fax_no":"031-200-7538","induty_code":"264","est_dt":"19690113","acc_mt":"12"}'

# %% [markdown]
# ### 공시검색
#
# ```
# https://opendart.fss.or.kr/api/list.json?crtfc_key=xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx&bgn_de=20200117&end_de=20200117&corp_cls=Y&page_no=1&page_count=10
# ```

# %% [markdown]
# ### 재무재표
#
# ```python
# https://opendart.fss.or.kr/api/fnlttSinglAcntAll.json?crtfc_key=xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx&corp_code=00126380&bsns_year=2018&reprt_code=11011&fs_div=OFS
# ```

# %%
API_KEY = '86b1325201d61a7854696bcc35b6d88105cf88f2'
financial_statement_url = f'https://opendart.fss.or.kr/api/fnlttSinglAcnt.json?crtfc_key={API_KEY}&corp_code=00126380&bsns_year=2018&reprt_code=11011'  # 기본 주소?crtfc_key={}&something=somthing 형식

response = requests.get(financial_statement_url)
response = json.loads(response.text)

# %%
response.get('list')[1]
# Out:
# {'rcept_no': '20190401004781',
#  'reprt_code': '11011',
#  'bsns_year': '2018',
#  'corp_code': '00126380',
#  'stock_code': '005930',
#  'fs_div': 'CFS',
#  'fs_nm': '연결재무제표',
#  'sj_div': 'BS',
#  'sj_nm': '재무상태표',
#  'account_nm': '비유동자산',
#  'thstrm_nm': '제 50 기',
#  'thstrm_dt': '2018.12.31 현재',
#  'thstrm_amount': '164,659,820,000,000',
#  'frmtrm_nm': '제 49 기',
#  'frmtrm_dt': '2017.12.31 현재',
#  'frmtrm_amount': '154,769,626,000,000',
#  'bfefrmtrm_nm': '제 48 기',
#  'bfefrmtrm_dt': '2016.12.31 현재',
#  'bfefrmtrm_amount': '120,744,620,000,000',
#  'ord': '3',
#  'currency': 'KRW'}

# %%
API_KEY = '86b1325201d61a7854696bcc35b6d88105cf88f2'

# %%
disclosure_url = f'https://opendart.fss.or.kr/api/list.json?crtfc_key={API_KEY}&bgn_de=20200117&end_de=20200117&corp_cls=Y&page_no=1&page_count=100'

# %%
response = requests.get(disclosure_url)

# %%
response.text
# Out:
# '{"status":"000","message":"정상","page_no":1,"page_count":100,"total_count":223,"total_page":3,"list":[{"corp_code":"00120182","corp_name":"NH투자증권","stock_code":"005940","corp_cls":"Y","report_nm":"[첨부추가]일괄신고추가서류(파생결합증권-주가연계증권)","rcept_no":"20200117000559","flr_nm":"NH투자증권","rcept_dt":"20200117","rm":""},{"corp_code":"00120182","corp_name":"NH투자증권","stock_code":"005940","corp_cls":"Y","report_nm":"[첨부추가]일괄신고추가서류(파생결합증권-주가연계증권)","rcept_no":"20200117000486","flr_nm":"NH투자증권","rcept_dt":"20200117","rm":""},{"corp_code":"00120182","corp_name":"NH투자증권","stock_code":"005940","corp_cls":"Y","report_nm":"[첨부추가]일괄신고추가서류(파생결합증권-주가연계증권)","rcept_no":"20200117000375","flr_nm":"NH투자증권","rcept_dt":"20200117","rm":""},{"corp_code":"00120182","corp_name":"NH투자증권","stock_code":"005940","corp_cls":"Y","report_nm":"[첨부추가]일괄신고추가서류(파생결합증권-주가연계증권)","rcept_no":"20200117000341","flr_nm":"NH투자증권","rcept_dt":"20200117","rm":""},{"corp_code":"00120182","corp_name":"NH투자증권","stock_code":"005940","corp_cls":"Y","report_nm":"[첨부추가]일괄신고추가서류(파생결합증권-주가연계증권)","rcept_no":"20200117000083","flr_nm":"NH투자증권","rcept_dt":"20200117","rm":""},{"corp_code":"00120182","corp_name":"NH투자증권","stock_code":"005940","corp_cls":"Y","report_nm":"[첨부추가]일괄신고추가서류(파생결합증권-주가연계증권)","rcept_no":"20200117000030","flr_nm":"NH투자증권","rcept_dt":"20200117","rm":""},{"corp_code":"00878915","corp_name":"DGB금융지주","stock_code":"139130","corp_cls":"Y","report_nm":"소송등의판결ㆍ결정(자회사의 주요경영사항)","rcept_no":"20200117800593","flr_nm":"DGB금융지주","rcept_dt":"20200117","rm":"유"},{"corp_code":"00120571","corp_name":"롯데칠성음료","stock_code":"005300","corp_cls":"Y","report_nm":"타법인주식및출자증권취득결정","rcept_no":"20200117800584","flr_nm":"롯데칠성음료","rcept_dt":"20200117","rm":"유정"},{"corp_code":"00161709","corp_name":"퍼시스","stock_code":"016800","corp_cls":"Y","report_nm":"주식등의대량보유상황보고서(약식)","rcept_no":"20200117000661","flr_nm":"피델리티매니지먼트앤리서치컴퍼니엘엘씨","rcept_dt":"20200117","rm":""},{"corp_code":"00188089","corp_name":"한섬","stock_code":"020000","corp_cls":"Y","report_nm":"주식등의대량보유상황보고서(약식)","rcept_no":"20200117000657","flr_nm":"피델리티매니지먼트앤리서치컴퍼니엘엘씨","rcept_dt":"20200117","rm":""},{"corp_code":"00111111","corp_name":"대양금속","stock_code":"009190","corp_cls":"Y","report_nm":"주식등의대량보유상황보고서(약식)","rcept_no":"20200117000656","flr_nm":"HB저축은행","rcept_dt":"20200117","rm":""},{"corp_code":"00344287","corp_name":"현대두산인프라코어","stock_code":"042670","corp_cls":"Y","report_nm":"[발행조건확정]증권신고서(채무증권)","rcept_no":"20200117000654","flr_nm":"현대두산인프라코어","rcept_dt":"20200117","rm":""},{"corp_code":"00111111","corp_name":"대양금속","stock_code":"009190","corp_cls":"Y","report_nm":"임원ㆍ주요주주특정증권등소유상황보고서","rcept_no":"20200117000651","flr_nm":"에프앤디조합","rcept_dt":"20200117","rm":""},{"corp_code":"00115977","corp_name":"아이에스동서","stock_code":"010780","corp_cls":"Y","report_nm":"타인에대한채무보증결정","rcept_no":"20200117800543","flr_nm":"아이에스동서","rcept_dt":"20200117","rm":"유"},{"corp_code":"00111111","corp_name":"대양금속","stock_code":"009190","corp_cls":"Y","report_nm":"최대주주등소유주식변동신고서","rcept_no":"20200117800563","flr_nm":"대양금속","rcept_dt":"20200117","rm":"유"},{"corp_code":"00160861","corp_name":"한농화성","stock_code":"011500","corp_cls":"Y","report_nm":"주식등의대량보유상황보고서(약식)","rcept_no":"20200117000650","flr_nm":"피델리티매니지먼트앤리서치컴퍼니엘엘씨","rcept_dt":"20200117","rm":""},{"corp_code":"00111111","corp_name":"대양금속","stock_code":"009190","corp_cls":"Y","report_nm":"주식등의대량보유상황보고서(일반)","rcept_no":"20200117000649","flr_nm":"에프앤디조합","rcept_dt":"20200117","rm":""},{"corp_code":"00180795","corp_name":"인팩","stock_code":"023810","corp_cls":"Y","report_nm":"주식등의대량보유상황보고서(약식)","rcept_no":"20200117000646","flr_nm":"피델리티매니지먼트앤리서치컴퍼니엘엘씨","rcept_dt":"20200117","rm":""},{"corp_code":"00113535","corp_name":"대한해운","stock_code":"005880","corp_cls":"Y","report_nm":"주식등의대량보유상황보고서(일반)","rcept_no":"20200117000645","flr_nm":"티케이케미칼","rcept_dt":"20200117","rm":""},{"corp_code":"00163716","corp_name":"한창","stock_code":"005110","corp_cls":"Y","report_nm":"[기재정정]주요사항보고서(전환사채권발행결정)","rcept_no":"20200117000634","flr_nm":"한창"," ...

# %%
response = json.loads(response.text)

# %%
response
# Out:
# {'status': '000',
#  'message': '정상',
#  'page_no': 1,
#  'page_count': 100,
#  'total_count': 223,
#  'total_page': 3,
#  'list': [{'corp_code': '00120182',
#    'corp_name': 'NH투자증권',
#    'stock_code': '005940',
#    'corp_cls': 'Y',
#    'report_nm': '[첨부추가]일괄신고추가서류(파생결합증권-주가연계증권)',
#    'rcept_no': '20200117000559',
#    'flr_nm': 'NH투자증권',
#    'rcept_dt': '20200117',
#    'rm': ''},
#   {'corp_code': '00120182',
#    'corp_name': 'NH투자증권',
#    'stock_code': '005940',
#    'corp_cls': 'Y',
#    'report_nm': '[첨부추가]일괄신고추가서류(파생결합증권-주가연계증권)',
#    'rcept_no': '20200117000486',
#    'flr_nm': 'NH투자증권',
#    'rcept_dt': '20200117',
#    'rm': ''},
#   {'corp_code': '00120182',
#    'corp_name': 'NH투자증권',
#    'stock_code': '005940',
#    'corp_cls': 'Y',
#    'report_nm': '[첨부추가]일괄신고추가서류(파생결합증권-주가연계증권)',
#    'rcept_no': '20200117000375',
#    'flr_nm': 'NH투자증권',
#    'rcept_dt': '20200117',
#    'rm': ''},
#   {'corp_code': '00120182',
#    'corp_name': 'NH투자증권',
#    'stock_code': '005940',
#    'corp_cls': 'Y',
#    'report_nm': '[첨부추가]일괄신고추가서류(파생결합증권-주가연계증권)',
#    'rcept_no': '20200117000341',
#    'flr_nm': 'NH투자증권',
#    'rcept_dt': '20200117',
#    'rm': ''},
#   {'corp_code': '00120182',
#    'corp_name': 'NH투자증권',
#    'stock_code': '005940',
#    'corp_cls': 'Y',
#    'report_nm': '[첨부추가]일괄신고추가서류(파생결합증권-주가연계증권)',
#    'rcept_no': '20200117000083',
#    'flr_nm': 'NH투자증권',
#    'rcept_dt': '20200117',
#    'rm': ''},
#   {'corp_code': '00120182',
#    'corp_name': 'NH투자증권',
#    'stock_code': '005940',
#    'corp_cls': 'Y',
#    'report_nm': '[첨부추가]일괄신고추가서류(파생결합증권-주가연계증권)',
#    'rcept_no': '20200117000030',
#    'flr_nm': 'NH투자증권',
#    'rcept_dt': '20200117',
#    'rm': ''},
#   {'corp_code': '00878915',
#    'corp_name': 'DGB금융지주',
#    'stock_code': '139130',
#    'corp_cls': 'Y',
#    'report_nm': '소송등의판결ㆍ결정(자회사의 주요경영사항)',
#    'rcept_no': '20200117800593',
#    'flr_nm': 'DGB금융지주',
#    'rcept_dt': '20200117',
#    'rm': '유'},
#   {'corp_code': '00120571',
#    'corp_name': '롯데칠성음료',
#    'stock_code': '005300',
#    'corp_cls': 'Y',
#    'report_nm': '타법인주식및출자증권취득결정',
#    'rcept_no': '20200117800584',
#    'flr_nm': '롯데칠성음료',
#    'rcept_dt': '20200117',
#    'rm': '유정'},
#   {'corp_code': '00161709',
#    'corp_name': '퍼시스',
#    'stock_code': '016800',
#    'corp_cls': 'Y',
#    'report_nm': '주식등의대량보유상황보고서(약식)',
#    'rcept_no': '20200117000661',
#    'flr_nm': '피델리티매니지먼트앤리서치컴퍼니엘엘씨',
#    'rcept_dt': '20200117',
#    'rm': ''},
#   {'corp_code': '00188089',
#    'corp_name': '한섬',
#    'stock_code': '020000',
#    'corp_cls': 'Y',
#    'report_nm': '주식등의대량보유상황보고서(약식)',
#    'rcept_no': '20200117000657',
#    'flr_nm': '피델리티매니지먼트앤리서치컴퍼니엘엘씨',
#    'rcept_dt': '20200117',
#    'rm': ''},
#   {'corp_code': '00111111',
#    'corp_name': '대양금속',
#    'stock_code': '009190',
#    'corp_cls': 'Y',
#    'report_nm': '주식등의대량보유상황보고서(약식)',
#    'rcept_no': '20200117000656',
#    'flr_nm': 'HB저축은행',
#    'rcept_dt': '20200117',
#    'rm': ''},
#   {'corp_code': '00344287',
#    'corp_name': '현대두산인프라코어',
#    'stock_code': '042670',
#    'corp_cls': 'Y',
#    'report_nm': '[발행조건확정]증권신고서(채무증권)',
#    'rcept_no': '20200117000654',
#    'flr_nm': '현대두산인프라코어',
#    'rcept_dt': '20200117',
#    'rm': ''},
#   {'corp_code': '00111111',
#    'corp_name': '대양금속',
#    'stock_code': '009190',
#    'corp_cls': 'Y',
#    'report_nm': '임원ㆍ주요주주특정증권등소유상황보고서',
#    'rcept_no': '20200117000651',
#    'flr_nm': '에프앤디조합',
#    'rcept_dt': '20200117',
#    'rm': ''},
#   {'corp_code': '00115977',
#    'corp_name': '아이에스동서',
#    'stock_code': '010780',
#    'corp_cls': 'Y',
#    'report_nm': '타인에대한채무보증결정',
#    'rcept_no': '20200117800543',
#    'flr_nm': '아이에스동서',
#    'rcept_dt': '20200117',
#    'rm': '유'},
#   {'corp_code': '00111111',
#    'corp_name': '대양금속',
#    'stock_code': '009190',
#    'corp_cls': 'Y',
#    'report_nm': '최대주주등소유주식변동신고서',
#    'rcept_no': '20200117800563',
#    'flr_nm': '대양금속',
#    'rcept_dt': '20200117',
#    'rm': '유'},
#   {'corp_code': '00160861',
#    'corp_name': '한농화성',
#    'stock_code': '011500',
#    'corp_cls': 'Y',
#    'report_nm': '주식등의대량보유상황보고서(약식)',
#    'rcept_no': '20200117000650',
#    'flr_nm': '피델리티매니지먼트앤리서치컴퍼니엘엘씨',
#    'rcept_dt': '20200117',
#    'rm': ''},
#   {'corp_code': '00111111',
#    'corp_name': '대양금속',
#    'stock_code': '009190',
#    'corp_cls': 'Y',
#    'report_nm': '주식등의대량보유상황보고서(일반)',
#    'rcept_no': '20200117000649',
#    'flr_nm': '에프앤디조합',
#    'rcept_dt': '20200117',
#    'rm': ''},
#   {'corp_code': '00180795',
#    'corp_name': '인팩',
#    'stock_code': '023810',
#    'corp_cls': 'Y',
#    'report_nm': '주식등의대량보유상황보고서(약식)',
#    'rcept_no': '20200117000646',
#    'flr_nm': '피델리티매니지먼트앤리서치컴퍼니엘엘씨',
#    'rcept_dt': '20200117',
#    'rm': ''},
#   {'corp_code': '00113535',
#    'corp_name': '대한해운',
#    'stock_code': '005880',
#    'corp_cls': 'Y',
#    'report_nm': '주식등의대량보유상황보고서(일반)',
#    'rcept_no': '20200117000645',
#    'flr_nm': '티케이케미칼',
#    'rcept_dt': '20200117',
#    'rm': ''},
#   {'corp_code': '00163716',
#    'corp_name': '한창',
#    'stock_code': '005110',
#    'corp_cls': 'Y',
#    'report_nm': '[기재정정]주요사항보고서(전환사채권발행결정)',
#    'rcept_no': '20200117000634',
#    'flr_nm': '한창',
#    'rcept_dt': '20200117',
#    'rm': '정'},
#   {'corp_code': '00403632',
#    'corp_name': '현대퓨처넷',
#    'stock_code': '126560',
#    'corp_cls': 'Y',
#    'report_nm': '주식등의대량보유상황보고서(약식)',
#    'rcept_no': '20200117000639',
#    'flr_nm': '피델리티매니지먼트앤리서치컴퍼니엘엘씨',
#    'rcept_dt': '20200117',
#    'rm': ''},
#   {'corp_code': '00111111',
#    'corp_name': '대양금속',
#    'stock_code': '009190',
#    'corp_cls': 'Y',
#    'report_nm': '[기재정정]주식등의대량보유상황보고서(일반)',
#    'rcept_no': '20200117000637',
#    'flr_nm': '에프앤디조합',
#    'rcept_dt': '20200117',
#    'rm': ''},
#   {'corp_code': '00106623',
#    'corp_name': '현대위아',
#    'stock_code': '011210',
#    'corp_cls': 'Y',
#    'report_nm': '기업설명회(IR)개최(안내공시)',
#    'rcept_no': '20200117800532',
#    'flr_nm': '현대위아',
#    'rcept_dt': '20200117',
#    'rm': '유'},
#   {'corp_code': '00164742',
#    'corp_name': '현대자동차',
#    'stock_code': '005380',
#    'corp_cls': 'Y',
#    'report_nm': '특수관계인으로부터기타유가증권매수',
#    'rcept_no': '20200117000625',
#    'flr_nm': '현대자동차',
#    'rcept_dt': '20200117',
#    'rm': '공'},
#   {'corp_code': '00118026',
#    'corp_name': '동원산업',
#    'stock_code': '006040',
#    'corp_cls': 'Y',
#    'report_nm': '[발행조건확정]증권신고서(채무증권)',
#    'rcept_no': '20200117000621',
#    'flr_nm': '동원산업',
#    'rcept_dt': '20200117',
#    'rm': '정'},
#   {'corp_code': '00136721',
#    'corp_name': '신영증권',
#    'stock_code': '001720',
#    'corp_cls': 'Y',
#    'report_nm': '증권발행실적보고서',
#    'rcept_no': '20200117000616',
#    'flr_nm': '신영증권',
#    'rcept_dt': '20200117',
#    'rm': ''},
#   {'corp_code': '00118026',
#    'corp_name': '동원산업',
#    'stock_code': '006040',
#    'corp_cls': 'Y',
#    'report_nm': '[기재정정]증권신고서(채무증권)',
#    'rcept_no': '20200117000615',
#    'flr_nm': '동원산업',
#    'rcept_dt': '20200117',
#    'rm': '정'},
#   {'corp_code': '00136721',
#    'corp_name': '신영증권',
#    'stock_code': '001720',
#    'corp_cls': 'Y',
#    'report_nm': '증권발행실적보고서',
#    'rcept_no': '20200117000607',
#    'flr_nm': '신영증권',
#    'rcept_dt': '20200117',
#    'rm': '정'},
#   {'corp_code': '00115694',
#    'corp_name': 'DB금융투자',
#    'stock_code': '016610',
#    'corp_cls': 'Y',
#    'report_nm': '증권발행실적보고서',
#    'rcept_no': '20200117000600',
#    'flr_nm': 'DB금융투자',
#    'rcept_dt': '20200117',
#    'rm': ''},
#   {'corp_code': '00136776',
#    'corp_name': '제이준코스메틱',
#    'stock_code': '025620',
#    'corp_cls': 'Y',
#    'report_nm': '주식등의대량보유상황보고서(일반)',
#    'rcept_no': '20200117000599',
#    'flr_nm': '에프앤리퍼블릭',
#    'rcept_dt': '20200117',
#    'rm': ''},
#   {'corp_code': '00162993',
#    'corp_name': '한일홀딩스',
#    'stock_code': '003300',
#    'corp_cls': 'Y',
#    'report_nm': '주식등의대량보유상황보고서(일반)',
#    'rcept_no': '20200117000596',
#    'flr_nm': '허기호',
#    'rcept_dt': '20200117',
#    'rm': ''},
#   {'corp_code': '00162461',
#    'corp_name': '한화솔루션',
#    'stock_code': '009830',
#    'corp_cls': 'Y',
#    'report_nm': '임원ㆍ주요주주특정증권등소유상황보고서',
#    'rcept_no': '20200117000592',
#    'flr_nm': '김상훈',
#    'rcept_dt': '20200117',
#    'rm': ''},
#   {'corp_code': '00169048',
#    'corp_name': 'HLB글로벌',
#    'stock_code': '003580',
#    'corp_cls': 'Y',
#    'report_nm': '사외이사의선임ㆍ해임또는중도퇴임에관한신고',
#    'rcept_no': '20200117000590',
#    'flr_nm': 'HLB글로벌',
#    'rcept_dt': '20200117',
#    'rm': ''},
#   {'corp_code': '00241005',
#    'corp_name': '코오롱플라스틱',
#    'stock_code': '138490',
#    'corp_cls': 'Y',
#    'report_nm': '최대주주등소유주식변동신고서',
#    'rcept_no': '20200117800491',
#    'flr_nm': '코오롱플라스틱',
#    'rcept_dt': '20200117',
#    'rm': '유'},
#   {'corp_code': '00136721',
#    'corp_name': '신영증권',
#    'stock_code': '001720',
#    'corp_cls': 'Y',
#    'report_nm': '증권발행실적보고서',
#    'rcept_no': '20200117000588',
#    'flr_nm': '신영증권',
#    'rcept_dt': '20200117',
#    'rm': ''},
#   {'corp_code': '00165413',
#    'corp_name': '롯데케미칼',
#    'stock_code': '011170',
#    'corp_cls': 'Y',
#    'report_nm': '기업설명회(IR)개최(안내공시)',
#    'rcept_no': '20200117800488',
#    'flr_nm': '롯데케미칼',
#    'rcept_dt': '20200117',
#    'rm': '유'},
#   {'corp_code': '00222532',
#    'corp_name': 'LG헬로비전',
#    'stock_code': '037560',
#    'corp_cls': 'Y',
#    'report_nm': '증권발행실적보고서',
#    'rcept_no': '20200117000575',
#    'flr_nm': 'LG헬로비전',
#    'rcept_dt': '20200117',
#    'rm': ''},
#   {'corp_code': '00296290',
#    'corp_name': '키움증권',
#    'stock_code': '039490',
#    'corp_cls': 'Y',
#    'report_nm': '투자설명서(일괄신고)',
#    'rcept_no': '20200117000573',
#    'flr_nm': '키움증권',
#    'rcept_dt': '20200117',
#    'rm': ''},
#   {'corp_code': '00120182',
#    'corp_name': 'NH투자증권',
#    'stock_code': '005940',
#    'corp_cls': 'Y',
#    'report_nm': '투자설명서(일괄신고)',
#    'rcept_no': '20200117000564',
#    'flr_nm': 'NH투자증권',
#    'rcept_dt': '20200117',
#    'rm': ''},
#   {'corp_code': '00152686',
#    'corp_name': '코리아써키트',
#    'stock_code': '007810',
#    'corp_cls': 'Y',
#    'report_nm': '최대주주등소유주식변동신고서',
#    'rcept_no': '20200117800467',
#    'flr_nm': '코리아써키트',
#    'rcept_dt': '20200117',
#    'rm': '유'},
#   {'corp_code': '00120182',
#    'corp_name': 'NH투자증권',
#    'stock_code': '005940',
#    'corp_cls': 'Y',
#    'report_nm': '증권발행실적보고서',
#    'rcept_no': '20200117000558',
#    'flr_nm': 'NH투자증권',
#    'rcept_dt': '20200117',
#    'rm': ''},
#   {'corp_code': '00296290',
#    'corp_name': '키움증권',
#    'stock_code': '039490',
#    'corp_cls': 'Y',
#    'report_nm': '일괄신고추가서류(파생결합사채-주가연계파생결합사채)',
#    'rcept_no': '20200117000555',
#    'flr_nm': '키움증권',
#    'rcept_dt': '20200117',
#    'rm': ''},
#   {'corp_code': '00151863',
#    'corp_name': '센트럴인사이트',
#    'stock_code': '012600',
#    'corp_cls': 'Y',
#    'report_nm': '투자판단관련주요경영사항',
#    'rcept_no': '20200117800421',
#    'flr_nm': '센트럴인사이트',
#    'rcept_dt': '20200117',
#    'rm': '유'},
#   {'corp_code': '00173102',
#    'corp_name': '모나리자',
#    'stock_code': '012690',
#    'corp_cls': 'Y',
#    'report_nm': '주요사항보고서(타법인주식및출자증권양수결정)',
#    'rcept_no': '20200117000518',
#    'flr_nm': '모나리자',
#    'rcept_dt': '20200117',
#    'rm': ''},
#   {'corp_code': '00163682',
#    'corp_name': '메리츠증권',
#    'stock_code': '008560',
#    'corp_cls': 'Y',
#    'report_nm': '증권발행실적보고서',
#    'rcept_no': '20200117000535',
#    'flr_nm': '메리츠증권',
#    'rcept_dt': '20200117',
#    'rm': ''},
#   {'corp_code': '00163682',
#    'corp_name': '메리츠증권',
#    'stock_code': '008560',
#    'corp_cls': 'Y',
#    'report_nm': '증권발행실적보고서',
#    'rcept_no': '20200117000531',
#    'flr_nm': '메리츠증권',
#    'rcept_dt': '20200117',
#    'rm': ''},
#   {'corp_code': '00126201',
#    'corp_name': '삼성공조',
#    'stock_code': '006660',
#    'corp_cls': 'Y',
#    'report_nm': '최대주주등소유주식변동신고서',
#    'rcept_no': '20200117800438',
#    'flr_nm': '삼성공조',
#    'rcept_dt': '20200117',
#    'rm': '유'},
#   {'corp_code': '00124197',
#    'corp_name': '세아제강지주',
#    'stock_code': '003030',
#    'corp_cls': 'Y',
#    'report_nm': '임원ㆍ주요주주특정증권등소유상황보고서',
#    'rcept_no': '20200117000529',
#    'flr_nm': '이주성',
#    'rcept_dt': '20200117',
#    'rm': ''},
#   {'corp_code': '00163682',
#    'corp_name': '메리츠증권',
#    'stock_code': '008560',
#    'corp_cls': 'Y',
#    'report_nm': '증권발행실적보고서',
#    'rcept_no': '20200117000528',
#    'flr_nm': '메리츠증권',
#    'rcept_dt': '20200117',
#    'rm': ''},
#   {'corp_code': '00124197',
#    'corp_name': '세아제강지주',
#    'stock_code': '003030',
#    'corp_cls': 'Y',
#    'report_nm': '최대주주등소유주식변동신고서',
#    'rcept_no': '20200117800419',
#    'flr_nm': '세아제강지주',
#    'rcept_dt': '20200117',
#    'rm': '유'},
#   {'corp_code': '00120182',
#    'corp_name': 'NH투자증권',
#    'stock_code': '005940',
#    'corp_cls': 'Y',
#    'report_nm': '투자설명서(일괄신고)',
#    'rcept_no': '20200117000520',
#    'flr_nm': 'NH투자증권',
#    'rcept_dt': '20200117',
#    'rm': ''},
#   {'corp_code': '00344287',
#    'corp_name': '현대두산인프라코어',
#    'stock_code': '042670',
#    'corp_cls': 'Y',
#    'report_nm': '최대주주등소유주식변동신고서',
#    'rcept_no': '20200117800412',
#    'flr_nm': '현대두산인프라코어',
#    'rcept_dt': '20200117',
#    'rm': '유'},
#   {'corp_code': '00117601',
#    'corp_name': '유안타증권',
#    'stock_code': '003470',
#    'corp_cls': 'Y',
#    'report_nm': '최대주주등소유주식변동신고서',
#    'rcept_no': '20200117800408',
#    'flr_nm': '유안타증권',
#    'rcept_dt': '20200117',
#    'rm': '유'},
#   {'corp_code': '00557508',
#    'corp_name': 'GKL',
#    'stock_code': '114090',
#    'corp_cls': 'Y',
#    'report_nm': '주주총회소집결의',
#    'rcept_no': '20200117800396',
#    'flr_nm': 'GKL',
#    'rcept_dt': '20200117',
#    'rm': '유'},
#   {'corp_code': '00117601',
#    'corp_name': '유안타증권',
#    'stock_code': '003470',
#    'corp_cls': 'Y',
#    'report_nm': '투자설명서(일괄신고)',
#    'rcept_no': '20200117000515',
#    'flr_nm': '유안타증권',
#    'rcept_dt': '20200117',
#    'rm': ''},
#   {'corp_code': '00103130',
#    'corp_name': '플레이그램',
#    'stock_code': '009810',
#    'corp_cls': 'Y',
#    'report_nm': '조회공시요구(현저한시황변동)에대한답변(미확정)',
#    'rcept_no': '20200117800367',
#    'flr_nm': '플레이그램',
#    'rcept_dt': '20200117',
#    'rm': '유'},
#   {'corp_code': '00111704',
#    'corp_name': '대우조선해양',
#    'stock_code': '042660',
#    'corp_cls': 'Y',
#    'report_nm': '영업실적등에대한전망(공정공시)',
#    'rcept_no': '20200117800373',
#    'flr_nm': '대우조선해양',
#    'rcept_dt': '20200117',
#    'rm': '유'},
#   {'corp_code': '00155124',
#    'corp_name': '평화홀딩스',
#    'stock_code': '010770',
#    'corp_cls': 'Y',
#    'report_nm': '금전대여결정',
#    'rcept_no': '20200117800401',
#    'flr_nm': '평화홀딩스',
#    'rcept_dt': '20200117',
#    'rm': '유'},
#   {'corp_code': '00110893',
#    'corp_name': '대신증권',
#    'stock_code': '003540',
#    'corp_cls': 'Y',
#    'report_nm': '투자설명서(일괄신고)',
#    'rcept_no': '20200117000514',
#    'flr_nm': '대신증권',
#    'rcept_dt': '20200117',
#    'rm': ''},
#   {'corp_code': '00111722',
#    'corp_name': '미래에셋증권',
#    'stock_code': '006800',
#    'corp_cls': 'Y',
#    'report_nm': '증권발행실적보고서',
#    'rcept_no': '20200117000509',
#    'flr_nm': '미래에셋증권',
#    'rcept_dt': '20200117',
#    'rm': ''},
#   {'corp_code': '00106623',
#    'corp_name': '현대위아',
#    'stock_code': '011210',
#    'corp_cls': 'Y',
#    'report_nm': '특수관계인으로부터기타유가증권매수',
#    'rcept_no': '20200117000507',
#    'flr_nm': '현대위아',
#    'rcept_dt': '20200117',
#    'rm': '공'},
#   {'corp_code': '00111722',
#    'corp_name': '미래에셋증권',
#    'stock_code': '006800',
#    'corp_cls': 'Y',
#    'report_nm': '증권발행실적보고서',
#    'rcept_no': '20200117000506',
#    'flr_nm': '미래에셋증권',
#    'rcept_dt': '20200117',
#    'rm': ''},
#   {'corp_code': '00136721',
#    'corp_name': '신영증권',
#    'stock_code': '001720',
#    'corp_cls': 'Y',
#    'report_nm': '투자설명서(일괄신고)',
#    'rcept_no': '20200117000505',
#    'flr_nm': '신영증권',
#    'rcept_dt': '20200117',
#    'rm': ''},
#   {'corp_code': '00129387',
#    'corp_name': '삼화페인트공업',
#    'stock_code': '000390',
#    'corp_cls': 'Y',
#    'report_nm': '결산실적공시예고(안내공시)',
#    'rcept_no': '20200117800383',
#    'flr_nm': '삼화페인트공업',
#    'rcept_dt': '20200117',
#    'rm': '유'},
#   {'corp_code': '00219574',
#    'corp_name': '코스맥스비티아이',
#    'stock_code': '044820',
#    'corp_cls': 'Y',
#    'report_nm': '주요사항보고서(자기주식처분결정)(자회사의 주요경영사항)',
#    'rcept_no': '20200117800377',
#    'flr_nm': '코스맥스비티아이',
#    'rcept_dt': '20200117',
#    'rm': '유'},
#   {'corp_code': '00151368',
#    'corp_name': '인터지스',
#    'stock_code': '129260',
#    'corp_cls': 'Y',
#    'report_nm': '대표이사(대표집행임원)변경(안내공시)',
#    'rcept_no': '20200117800379',
#    'flr_nm': '인터지스',
#    'rcept_dt': '20200117',
#    'rm': '유'},
#   {'corp_code': '00219574',
#    'corp_name': '코스맥스비티아이',
#    'stock_code': '044820',
#    'corp_cls': 'Y',
#    'report_nm': '주요사항보고서(자기주식처분결정)',
#    'rcept_no': '20200117000482',
#    'flr_nm': '코스맥스비티아이',
#    'rcept_dt': '20200117',
#    'rm': ''},
#   {'corp_code': '01009789',
#    'corp_name': '코스맥스',
#    'stock_code': '192820',
#    'corp_cls': 'Y',
#    'report_nm': '주요사항보고서(자기주식처분결정)',
#    'rcept_no': '20200117000496',
#    'flr_nm': '코스맥스',
#    'rcept_dt': '20200117',
#    'rm': ''},
#   {'corp_code': '00117337',
#    'corp_name': '동양',
#    'stock_code': '001520',
#    'corp_cls': 'Y',
#    'report_nm': '특수관계인과의수익증권거래',
#    'rcept_no': '20200117000501',
#    'flr_nm': '동양',
#    'rcept_dt': '20200117',
#    'rm': '공'},
#   {'corp_code': '00151368',
#    'corp_name': '인터지스',
#    'stock_code': '129260',
#    'corp_cls': 'Y',
#    'report_nm': '임시주주총회결과',
#    'rcept_no': '20200117800345',
#    'flr_nm': '인터지스',
#    'rcept_dt': '20200117',
#    'rm': '유'},
#   {'corp_code': '00258801',
#    'corp_name': '카카오',
#    'stock_code': '035720',
#    'corp_cls': 'Y',
#    'report_nm': '특수관계인과의내부거래',
#    'rcept_no': '20200117000500',
#    'flr_nm': '카카오',
#    'rcept_dt': '20200117',
#    'rm': '공정'},
#   {'corp_code': '00111722',
#    'corp_name': '미래에셋증권',
#    'stock_code': '006800',
#    'corp_cls': 'Y',
#    'report_nm': '증권발행실적보고서',
#    'rcept_no': '20200117000492',
#    'flr_nm': '미래에셋증권',
#    'rcept_dt': '20200117',
#    'rm': ''},
#   {'corp_code': '00104856',
#    'corp_name': '삼성증권',
#    'stock_code': '016360',
#    'corp_cls': 'Y',
#    'report_nm': '증권발행실적보고서',
#    'rcept_no': '20200117000490',
#    'flr_nm': '삼성증권',
#    'rcept_dt': '20200117',
#    'rm': ''},
#   {'corp_code': '00136721',
#    'corp_name': '신영증권',
#    'stock_code': '001720',
#    'corp_cls': 'Y',
#    'report_nm': '일괄신고추가서류(파생결합증권-주식워런트증권)',
#    'rcept_no': '20200117000489',
#    'flr_nm': '신영증권',
#    'rcept_dt': '20200117',
#    'rm': ''},
#   {'corp_code': '00117601',
#    'corp_name': '유안타증권',
#    'stock_code': '003470',
#    'corp_cls': 'Y',
#    'report_nm': '일괄신고추가서류(파생결합증권-주가연계증권)',
#    'rcept_no': '20200117000480',
#    'flr_nm': '유안타증권',
#    'rcept_dt': '20200117',
#    'rm': ''},
#   {'corp_code': '00983271',
#    'corp_name': '엔에이치엔',
#    'stock_code': '181710',
#    'corp_cls': 'Y',
#    'report_nm': '주식등의대량보유상황보고서(일반)',
#    'rcept_no': '20200117000476',
#    'flr_nm': '이준호',
#    'rcept_dt': '20200117',
#    'rm': ''},
#   {'corp_code': '00795135',
#    'corp_name': '코오롱인더',
#    'stock_code': '120110',
#    'corp_cls': 'Y',
#    'report_nm': '최대주주등소유주식변동신고서',
#    'rcept_no': '20200117800337',
#    'flr_nm': '코오롱인더',
#    'rcept_dt': '20200117',
#    'rm': '유'},
#   {'corp_code': '00111722',
#    'corp_name': '미래에셋증권',
#    'stock_code': '006800',
#    'corp_cls': 'Y',
#    'report_nm': '증권발행실적보고서',
#    'rcept_no': '20200117000474',
#    'flr_nm': '미래에셋증권',
#    'rcept_dt': '20200117',
#    'rm': ''},
#   {'corp_code': '00148610',
#    'corp_name': '한화투자증권',
#    'stock_code': '003530',
#    'corp_cls': 'Y',
#    'report_nm': '증권발행실적보고서',
#    'rcept_no': '20200117000471',
#    'flr_nm': '한화투자증권',
#    'rcept_dt': '20200117',
#    'rm': ''},
#   {'corp_code': '00111722',
#    'corp_name': '미래에셋증권',
#    'stock_code': '006800',
#    'corp_cls': 'Y',
#    'report_nm': '증권발행실적보고서',
#    'rcept_no': '20200117000469',
#    'flr_nm': '미래에셋증권',
#    'rcept_dt': '20200117',
#    'rm': ''},
#   {'corp_code': '00164830',
#    'corp_name': '한국조선해양',
#    'stock_code': '009540',
#    'corp_cls': 'Y',
#    'report_nm': '영업(잠정)실적(공정공시)(자회사의 주요경영사항)',
#    'rcept_no': '20200117800316',
#    'flr_nm': '한국조선해양',
#    'rcept_dt': '20200117',
#    'rm': '유'},
#   {'corp_code': '00104856',
#    'corp_name': '삼성증권',
#    'stock_code': '016360',
#    'corp_cls': 'Y',
#    'report_nm': '증권발행실적보고서',
#    'rcept_no': '20200117000464',
#    'flr_nm': '삼성증권',
#    'rcept_dt': '20200117',
#    'rm': ''},
#   {'corp_code': '00164830',
#    'corp_name': '한국조선해양',
#    'stock_code': '009540',
#    'corp_cls': 'Y',
#    'report_nm': '영업(잠정)실적(공정공시)(자회사의 주요경영사항)',
#    'rcept_no': '20200117800310',
#    'flr_nm': '한국조선해양',
#    'rcept_dt': '20200117',
#    'rm': '유'},
#   {'corp_code': '00148610',
#    'corp_name': '한화투자증권',
#    'stock_code': '003530',
#    'corp_cls': 'Y',
#    'report_nm': '증권발행실적보고서',
#    'rcept_no': '20200117000462',
#    'flr_nm': '한화투자증권',
#    'rcept_dt': '20200117',
#    'rm': ''},
#   {'corp_code': '00148610',
#    'corp_name': '한화투자증권',
#    'stock_code': '003530',
#    'corp_cls': 'Y',
#    'report_nm': '투자설명서(일괄신고)',
#    'rcept_no': '20200117000460',
#    'flr_nm': '한화투자증권',
#    'rcept_dt': '20200117',
#    'rm': ''},
#   {'corp_code': '00148610',
#    'corp_name': '한화투자증권',
#    'stock_code': '003530',
#    'corp_cls': 'Y',
#    'report_nm': '투자설명서(일괄신고)',
#    'rcept_no': '20200117000457',
#    'flr_nm': '한화투자증권',
#    'rcept_dt': '20200117',
#    'rm': ''},
#   {'corp_code': '00148610',
#    'corp_name': '한화투자증권',
#    'stock_code': '003530',
#    'corp_cls': 'Y',
#    'report_nm': '일괄신고추가서류(기타파생결합증권)',
#    'rcept_no': '20200117000454',
#    'flr_nm': '한화투자증권',
#    'rcept_dt': '20200117',
#    'rm': ''},
#   {'corp_code': '00164609',
#    'corp_name': '현대미포조선',
#    'stock_code': '010620',
#    'corp_cls': 'Y',
#    'report_nm': '영업(잠정)실적(공정공시)',
#    'rcept_no': '20200117800302',
#    'flr_nm': '현대미포조선',
#    'rcept_dt': '20200117',
#    'rm': '유'},
#   {'corp_code': '00193009',
#    'corp_name': 'KH 필룩스',
#    'stock_code': '033180',
#    'corp_cls': 'Y',
#    'report_nm': '유상증자또는주식관련사채등의발행결과(자율공시)',
#    'rcept_no': '20200117800308',
#    'flr_nm': 'KH 필룩스',
#    'rcept_dt': '20200117',
#    'rm': '유'},
#   {'corp_code': '00148610',
#    'corp_name': '한화투자증권',
#    'stock_code': '003530',
#    'corp_cls': 'Y',
#    'report_nm': '일괄신고추가서류(파생결합증권-주가연계증권)',
#    'rcept_no': '20200117000449',
#    'flr_nm': '한화투자증권',
#    'rcept_dt': '20200117',
#    'rm': ''},
#   {'corp_code': '00344287',
#    'corp_name': '현대두산인프라코어',
#    'stock_code': '042670',
#    'corp_cls': 'Y',
#    'report_nm': '임원ㆍ주요주주특정증권등소유상황보고서',
#    'rcept_no': '20200117000448',
#    'flr_nm': '고석범',
#    'rcept_dt': '20200117',
#    'rm': ''},
#   {'corp_code': '00110893',
#    'corp_name': '대신증권',
#    'stock_code': '003540',
#    'corp_cls': 'Y',
#    'report_nm': '일괄신고추가서류(파생결합증권-주가연계증권)',
#    'rcept_no': '20200117000445',
#    'flr_nm': '대신증권',
#    'rcept_dt': '20200117',
#    'rm': ''},
#   {'corp_code': '00139214',
#    'corp_name': '삼성화재해상보험',
#    'stock_code': '000810',
#    'corp_cls': 'Y',
#    'report_nm': '임원ㆍ주요주주특정증권등소유상황보고서',
#    'rcept_no': '20200117000426',
#    'flr_nm': '삼성생명',
#    'rcept_dt': '20200117',
#    'rm': ''},
#   {'corp_code': '00126292',
#    'corp_name': '삼성카드',
#    'stock_code': '029780',
#    'corp_cls': 'Y',
#    'report_nm': '임원ㆍ주요주주특정증권등소유상황보고서',
#    'rcept_no': '20200117000422',
#    'flr_nm': '삼성생명',
#    'rcept_dt': '20200117',
#    'rm': ''},
#   {'corp_code': '00148276',
#    'corp_name': '제일기획',
#    'stock_code': '030000',
#    'corp_cls': 'Y',
#    'report_nm': '최대주주등소유주식변동신고서',
#    'rcept_no': '20200117800286',
#    'flr_nm': '제일기획',
#    'rcept_dt': '20200117',
#    'rm': '유'},
#   {'corp_code': '00115694',
#    'corp_name': 'DB금융투자',
#    'stock_code': '016610',
#    'corp_cls': 'Y',
#    'report_nm': '증권발행실적보고서',
#    'rcept_no': '20200117000420',
#    'flr_nm': 'DB금융투자',
#    'rcept_dt': '20200117',
#    'rm': ''},
#   {'corp_code': '00104856',
#    'corp_name': '삼성증권',
#    'stock_code': '016360',
#    'corp_cls': 'Y',
#    'report_nm': '임원ㆍ주요주주특정증권등소유상황보고서',
#    'rcept_no': '20200117000416',
#    'flr_nm': '삼성생명',
#    'rcept_dt': '20200117',
#    'rm': ''},
#   {'corp_code': '00115694',
#    'corp_name': 'DB금융투자',
#    'stock_code': '016610',
#    'corp_cls': 'Y',
#    'report_nm': '증권발행실적보고서',
#    'rcept_no': '20200117000412',
#    'flr_nm': 'DB금융투자',
#    'rcept_dt': '20200117',
#    'rm': ''},
#   {'corp_code': '00120182',
#    'corp_name': 'NH투자증권',
#    'stock_code': '005940',
#    'corp_cls': 'Y',
#    'report_nm': '증권발행실적보고서',
#    'rcept_no': '20200117000407',
#    'flr_nm': 'NH투자증권',
#    'rcept_dt': '20200117',
#    'rm': ''},
#   {'corp_code': '00110893',
#    'corp_name': '대신증권',
#    'stock_code': '003540',
#    'corp_cls': 'Y',
#    'report_nm': '증권발행실적보고서',
#    'rcept_no': '20200117000405',
#    'flr_nm': '대신증권',
#    'rcept_dt': '20200117',
#    'rm': ''}]}

# %%
response.keys()  # 키 확인
# Out:
# dict_keys(['status', 'message', 'page_no', 'page_count', 'total_count', 'total_page', 'list'])

# %%
response.get('list')
# Out:
# [{'corp_code': '00120182',
#   'corp_name': 'NH투자증권',
#   'stock_code': '005940',
#   'corp_cls': 'Y',
#   'report_nm': '[첨부추가]일괄신고추가서류(파생결합증권-주가연계증권)',
#   'rcept_no': '20200117000559',
#   'flr_nm': 'NH투자증권',
#   'rcept_dt': '20200117',
#   'rm': ''},
#  {'corp_code': '00120182',
#   'corp_name': 'NH투자증권',
#   'stock_code': '005940',
#   'corp_cls': 'Y',
#   'report_nm': '[첨부추가]일괄신고추가서류(파생결합증권-주가연계증권)',
#   'rcept_no': '20200117000486',
#   'flr_nm': 'NH투자증권',
#   'rcept_dt': '20200117',
#   'rm': ''},
#  {'corp_code': '00120182',
#   'corp_name': 'NH투자증권',
#   'stock_code': '005940',
#   'corp_cls': 'Y',
#   'report_nm': '[첨부추가]일괄신고추가서류(파생결합증권-주가연계증권)',
#   'rcept_no': '20200117000375',
#   'flr_nm': 'NH투자증권',
#   'rcept_dt': '20200117',
#   'rm': ''},
#  {'corp_code': '00120182',
#   'corp_name': 'NH투자증권',
#   'stock_code': '005940',
#   'corp_cls': 'Y',
#   'report_nm': '[첨부추가]일괄신고추가서류(파생결합증권-주가연계증권)',
#   'rcept_no': '20200117000341',
#   'flr_nm': 'NH투자증권',
#   'rcept_dt': '20200117',
#   'rm': ''},
#  {'corp_code': '00120182',
#   'corp_name': 'NH투자증권',
#   'stock_code': '005940',
#   'corp_cls': 'Y',
#   'report_nm': '[첨부추가]일괄신고추가서류(파생결합증권-주가연계증권)',
#   'rcept_no': '20200117000083',
#   'flr_nm': 'NH투자증권',
#   'rcept_dt': '20200117',
#   'rm': ''},
#  {'corp_code': '00120182',
#   'corp_name': 'NH투자증권',
#   'stock_code': '005940',
#   'corp_cls': 'Y',
#   'report_nm': '[첨부추가]일괄신고추가서류(파생결합증권-주가연계증권)',
#   'rcept_no': '20200117000030',
#   'flr_nm': 'NH투자증권',
#   'rcept_dt': '20200117',
#   'rm': ''},
#  {'corp_code': '00878915',
#   'corp_name': 'DGB금융지주',
#   'stock_code': '139130',
#   'corp_cls': 'Y',
#   'report_nm': '소송등의판결ㆍ결정(자회사의 주요경영사항)',
#   'rcept_no': '20200117800593',
#   'flr_nm': 'DGB금융지주',
#   'rcept_dt': '20200117',
#   'rm': '유'},
#  {'corp_code': '00120571',
#   'corp_name': '롯데칠성음료',
#   'stock_code': '005300',
#   'corp_cls': 'Y',
#   'report_nm': '타법인주식및출자증권취득결정',
#   'rcept_no': '20200117800584',
#   'flr_nm': '롯데칠성음료',
#   'rcept_dt': '20200117',
#   'rm': '유정'},
#  {'corp_code': '00161709',
#   'corp_name': '퍼시스',
#   'stock_code': '016800',
#   'corp_cls': 'Y',
#   'report_nm': '주식등의대량보유상황보고서(약식)',
#   'rcept_no': '20200117000661',
#   'flr_nm': '피델리티매니지먼트앤리서치컴퍼니엘엘씨',
#   'rcept_dt': '20200117',
#   'rm': ''},
#  {'corp_code': '00188089',
#   'corp_name': '한섬',
#   'stock_code': '020000',
#   'corp_cls': 'Y',
#   'report_nm': '주식등의대량보유상황보고서(약식)',
#   'rcept_no': '20200117000657',
#   'flr_nm': '피델리티매니지먼트앤리서치컴퍼니엘엘씨',
#   'rcept_dt': '20200117',
#   'rm': ''},
#  {'corp_code': '00111111',
#   'corp_name': '대양금속',
#   'stock_code': '009190',
#   'corp_cls': 'Y',
#   'report_nm': '주식등의대량보유상황보고서(약식)',
#   'rcept_no': '20200117000656',
#   'flr_nm': 'HB저축은행',
#   'rcept_dt': '20200117',
#   'rm': ''},
#  {'corp_code': '00344287',
#   'corp_name': '현대두산인프라코어',
#   'stock_code': '042670',
#   'corp_cls': 'Y',
#   'report_nm': '[발행조건확정]증권신고서(채무증권)',
#   'rcept_no': '20200117000654',
#   'flr_nm': '현대두산인프라코어',
#   'rcept_dt': '20200117',
#   'rm': ''},
#  {'corp_code': '00111111',
#   'corp_name': '대양금속',
#   'stock_code': '009190',
#   'corp_cls': 'Y',
#   'report_nm': '임원ㆍ주요주주특정증권등소유상황보고서',
#   'rcept_no': '20200117000651',
#   'flr_nm': '에프앤디조합',
#   'rcept_dt': '20200117',
#   'rm': ''},
#  {'corp_code': '00115977',
#   'corp_name': '아이에스동서',
#   'stock_code': '010780',
#   'corp_cls': 'Y',
#   'report_nm': '타인에대한채무보증결정',
#   'rcept_no': '20200117800543',
#   'flr_nm': '아이에스동서',
#   'rcept_dt': '20200117',
#   'rm': '유'},
#  {'corp_code': '00111111',
#   'corp_name': '대양금속',
#   'stock_code': '009190',
#   'corp_cls': 'Y',
#   'report_nm': '최대주주등소유주식변동신고서',
#   'rcept_no': '20200117800563',
#   'flr_nm': '대양금속',
#   'rcept_dt': '20200117',
#   'rm': '유'},
#  {'corp_code': '00160861',
#   'corp_name': '한농화성',
#   'stock_code': '011500',
#   'corp_cls': 'Y',
#   'report_nm': '주식등의대량보유상황보고서(약식)',
#   'rcept_no': '20200117000650',
#   'flr_nm': '피델리티매니지먼트앤리서치컴퍼니엘엘씨',
#   'rcept_dt': '20200117',
#   'rm': ''},
#  {'corp_code': '00111111',
#   'corp_name': '대양금속',
#   'stock_code': '009190',
#   'corp_cls': 'Y',
#   'report_nm': '주식등의대량보유상황보고서(일반)',
#   'rcept_no': '20200117000649',
#   'flr_nm': '에프앤디조합',
#   'rcept_dt': '20200117',
#   'rm': ''},
#  {'corp_code': '00180795',
#   'corp_name': '인팩',
#   'stock_code': '023810',
#   'corp_cls': 'Y',
#   'report_nm': '주식등의대량보유상황보고서(약식)',
#   'rcept_no': '20200117000646',
#   'flr_nm': '피델리티매니지먼트앤리서치컴퍼니엘엘씨',
#   'rcept_dt': '20200117',
#   'rm': ''},
#  {'corp_code': '00113535',
#   'corp_name': '대한해운',
#   'stock_code': '005880',
#   'corp_cls': 'Y',
#   'report_nm': '주식등의대량보유상황보고서(일반)',
#   'rcept_no': '20200117000645',
#   'flr_nm': '티케이케미칼',
#   'rcept_dt': '20200117',
#   'rm': ''},
#  {'corp_code': '00163716',
#   'corp_name': '한창',
#   'stock_code': '005110',
#   'corp_cls': 'Y',
#   'report_nm': '[기재정정]주요사항보고서(전환사채권발행결정)',
#   'rcept_no': '20200117000634',
#   'flr_nm': '한창',
#   'rcept_dt': '20200117',
#   'rm': '정'},
#  {'corp_code': '00403632',
#   'corp_name': '현대퓨처넷',
#   'stock_code': '126560',
#   'corp_cls': 'Y',
#   'report_nm': '주식등의대량보유상황보고서(약식)',
#   'rcept_no': '20200117000639',
#   'flr_nm': '피델리티매니지먼트앤리서치컴퍼니엘엘씨',
#   'rcept_dt': '20200117',
#   'rm': ''},
#  {'corp_code': '00111111',
#   'corp_name': '대양금속',
#   'stock_code': '009190',
#   'corp_cls': 'Y',
#   'report_nm': '[기재정정]주식등의대량보유상황보고서(일반)',
#   'rcept_no': '20200117000637',
#   'flr_nm': '에프앤디조합',
#   'rcept_dt': '20200117',
#   'rm': ''},
#  {'corp_code': '00106623',
#   'corp_name': '현대위아',
#   'stock_code': '011210',
#   'corp_cls': 'Y',
#   'report_nm': '기업설명회(IR)개최(안내공시)',
#   'rcept_no': '20200117800532',
#   'flr_nm': '현대위아',
#   'rcept_dt': '20200117',
#   'rm': '유'},
#  {'corp_code': '00164742',
#   'corp_name': '현대자동차',
#   'stock_code': '005380',
#   'corp_cls': 'Y',
#   'report_nm': '특수관계인으로부터기타유가증권매수',
#   'rcept_no': '20200117000625',
#   'flr_nm': '현대자동차',
#   'rcept_dt': '20200117',
#   'rm': '공'},
#  {'corp_code': '00118026',
#   'corp_name': '동원산업',
#   'stock_code': '006040',
#   'corp_cls': 'Y',
#   'report_nm': '[발행조건확정]증권신고서(채무증권)',
#   'rcept_no': '20200117000621',
#   'flr_nm': '동원산업',
#   'rcept_dt': '20200117',
#   'rm': '정'},
#  {'corp_code': '00136721',
#   'corp_name': '신영증권',
#   'stock_code': '001720',
#   'corp_cls': 'Y',
#   'report_nm': '증권발행실적보고서',
#   'rcept_no': '20200117000616',
#   'flr_nm': '신영증권',
#   'rcept_dt': '20200117',
#   'rm': ''},
#  {'corp_code': '00118026',
#   'corp_name': '동원산업',
#   'stock_code': '006040',
#   'corp_cls': 'Y',
#   'report_nm': '[기재정정]증권신고서(채무증권)',
#   'rcept_no': '20200117000615',
#   'flr_nm': '동원산업',
#   'rcept_dt': '20200117',
#   'rm': '정'},
#  {'corp_code': '00136721',
#   'corp_name': '신영증권',
#   'stock_code': '001720',
#   'corp_cls': 'Y',
#   'report_nm': '증권발행실적보고서',
#   'rcept_no': '20200117000607',
#   'flr_nm': '신영증권',
#   'rcept_dt': '20200117',
#   'rm': '정'},
#  {'corp_code': '00115694',
#   'corp_name': 'DB금융투자',
#   'stock_code': '016610',
#   'corp_cls': 'Y',
#   'report_nm': '증권발행실적보고서',
#   'rcept_no': '20200117000600',
#   'flr_nm': 'DB금융투자',
#   'rcept_dt': '20200117',
#   'rm': ''},
#  {'corp_code': '00136776',
#   'corp_name': '제이준코스메틱',
#   'stock_code': '025620',
#   'corp_cls': 'Y',
#   'report_nm': '주식등의대량보유상황보고서(일반)',
#   'rcept_no': '20200117000599',
#   'flr_nm': '에프앤리퍼블릭',
#   'rcept_dt': '20200117',
#   'rm': ''},
#  {'corp_code': '00162993',
#   'corp_name': '한일홀딩스',
#   'stock_code': '003300',
#   'corp_cls': 'Y',
#   'report_nm': '주식등의대량보유상황보고서(일반)',
#   'rcept_no': '20200117000596',
#   'flr_nm': '허기호',
#   'rcept_dt': '20200117',
#   'rm': ''},
#  {'corp_code': '00162461',
#   'corp_name': '한화솔루션',
#   'stock_code': '009830',
#   'corp_cls': 'Y',
#   'report_nm': '임원ㆍ주요주주특정증권등소유상황보고서',
#   'rcept_no': '20200117000592',
#   'flr_nm': '김상훈',
#   'rcept_dt': '20200117',
#   'rm': ''},
#  {'corp_code': '00169048',
#   'corp_name': 'HLB글로벌',
#   'stock_code': '003580',
#   'corp_cls': 'Y',
#   'report_nm': '사외이사의선임ㆍ해임또는중도퇴임에관한신고',
#   'rcept_no': '20200117000590',
#   'flr_nm': 'HLB글로벌',
#   'rcept_dt': '20200117',
#   'rm': ''},
#  {'corp_code': '00241005',
#   'corp_name': '코오롱플라스틱',
#   'stock_code': '138490',
#   'corp_cls': 'Y',
#   'report_nm': '최대주주등소유주식변동신고서',
#   'rcept_no': '20200117800491',
#   'flr_nm': '코오롱플라스틱',
#   'rcept_dt': '20200117',
#   'rm': '유'},
#  {'corp_code': '00136721',
#   'corp_name': '신영증권',
#   'stock_code': '001720',
#   'corp_cls': 'Y',
#   'report_nm': '증권발행실적보고서',
#   'rcept_no': '20200117000588',
#   'flr_nm': '신영증권',
#   'rcept_dt': '20200117',
#   'rm': ''},
#  {'corp_code': '00165413',
#   'corp_name': '롯데케미칼',
#   'stock_code': '011170',
#   'corp_cls': 'Y',
#   'report_nm': '기업설명회(IR)개최(안내공시)',
#   'rcept_no': '20200117800488',
#   'flr_nm': '롯데케미칼',
#   'rcept_dt': '20200117',
#   'rm': '유'},
#  {'corp_code': '00222532',
#   'corp_name': 'LG헬로비전',
#   'stock_code': '037560',
#   'corp_cls': 'Y',
#   'report_nm': '증권발행실적보고서',
#   'rcept_no': '20200117000575',
#   'flr_nm': 'LG헬로비전',
#   'rcept_dt': '20200117',
#   'rm': ''},
#  {'corp_code': '00296290',
#   'corp_name': '키움증권',
#   'stock_code': '039490',
#   'corp_cls': 'Y',
#   'report_nm': '투자설명서(일괄신고)',
#   'rcept_no': '20200117000573',
#   'flr_nm': '키움증권',
#   'rcept_dt': '20200117',
#   'rm': ''},
#  {'corp_code': '00120182',
#   'corp_name': 'NH투자증권',
#   'stock_code': '005940',
#   'corp_cls': 'Y',
#   'report_nm': '투자설명서(일괄신고)',
#   'rcept_no': '20200117000564',
#   'flr_nm': 'NH투자증권',
#   'rcept_dt': '20200117',
#   'rm': ''},
#  {'corp_code': '00152686',
#   'corp_name': '코리아써키트',
#   'stock_code': '007810',
#   'corp_cls': 'Y',
#   'report_nm': '최대주주등소유주식변동신고서',
#   'rcept_no': '20200117800467',
#   'flr_nm': '코리아써키트',
#   'rcept_dt': '20200117',
#   'rm': '유'},
#  {'corp_code': '00120182',
#   'corp_name': 'NH투자증권',
#   'stock_code': '005940',
#   'corp_cls': 'Y',
#   'report_nm': '증권발행실적보고서',
#   'rcept_no': '20200117000558',
#   'flr_nm': 'NH투자증권',
#   'rcept_dt': '20200117',
#   'rm': ''},
#  {'corp_code': '00296290',
#   'corp_name': '키움증권',
#   'stock_code': '039490',
#   'corp_cls': 'Y',
#   'report_nm': '일괄신고추가서류(파생결합사채-주가연계파생결합사채)',
#   'rcept_no': '20200117000555',
#   'flr_nm': '키움증권',
#   'rcept_dt': '20200117',
#   'rm': ''},
#  {'corp_code': '00151863',
#   'corp_name': '센트럴인사이트',
#   'stock_code': '012600',
#   'corp_cls': 'Y',
#   'report_nm': '투자판단관련주요경영사항',
#   'rcept_no': '20200117800421',
#   'flr_nm': '센트럴인사이트',
#   'rcept_dt': '20200117',
#   'rm': '유'},
#  {'corp_code': '00173102',
#   'corp_name': '모나리자',
#   'stock_code': '012690',
#   'corp_cls': 'Y',
#   'report_nm': '주요사항보고서(타법인주식및출자증권양수결정)',
#   'rcept_no': '20200117000518',
#   'flr_nm': '모나리자',
#   'rcept_dt': '20200117',
#   'rm': ''},
#  {'corp_code': '00163682',
#   'corp_name': '메리츠증권',
#   'stock_code': '008560',
#   'corp_cls': 'Y',
#   'report_nm': '증권발행실적보고서',
#   'rcept_no': '20200117000535',
#   'flr_nm': '메리츠증권',
#   'rcept_dt': '20200117',
#   'rm': ''},
#  {'corp_code': '00163682',
#   'corp_name': '메리츠증권',
#   'stock_code': '008560',
#   'corp_cls': 'Y',
#   'report_nm': '증권발행실적보고서',
#   'rcept_no': '20200117000531',
#   'flr_nm': '메리츠증권',
#   'rcept_dt': '20200117',
#   'rm': ''},
#  {'corp_code': '00126201',
#   'corp_name': '삼성공조',
#   'stock_code': '006660',
#   'corp_cls': 'Y',
#   'report_nm': '최대주주등소유주식변동신고서',
#   'rcept_no': '20200117800438',
#   'flr_nm': '삼성공조',
#   'rcept_dt': '20200117',
#   'rm': '유'},
#  {'corp_code': '00124197',
#   'corp_name': '세아제강지주',
#   'stock_code': '003030',
#   'corp_cls': 'Y',
#   'report_nm': '임원ㆍ주요주주특정증권등소유상황보고서',
#   'rcept_no': '20200117000529',
#   'flr_nm': '이주성',
#   'rcept_dt': '20200117',
#   'rm': ''},
#  {'corp_code': '00163682',
#   'corp_name': '메리츠증권',
#   'stock_code': '008560',
#   'corp_cls': 'Y',
#   'report_nm': '증권발행실적보고서',
#   'rcept_no': '20200117000528',
#   'flr_nm': '메리츠증권',
#   'rcept_dt': '20200117',
#   'rm': ''},
#  {'corp_code': '00124197',
#   'corp_name': '세아제강지주',
#   'stock_code': '003030',
#   'corp_cls': 'Y',
#   'report_nm': '최대주주등소유주식변동신고서',
#   'rcept_no': '20200117800419',
#   'flr_nm': '세아제강지주',
#   'rcept_dt': '20200117',
#   'rm': '유'},
#  {'corp_code': '00120182',
#   'corp_name': 'NH투자증권',
#   'stock_code': '005940',
#   'corp_cls': 'Y',
#   'report_nm': '투자설명서(일괄신고)',
#   'rcept_no': '20200117000520',
#   'flr_nm': 'NH투자증권',
#   'rcept_dt': '20200117',
#   'rm': ''},
#  {'corp_code': '00344287',
#   'corp_name': '현대두산인프라코어',
#   'stock_code': '042670',
#   'corp_cls': 'Y',
#   'report_nm': '최대주주등소유주식변동신고서',
#   'rcept_no': '20200117800412',
#   'flr_nm': '현대두산인프라코어',
#   'rcept_dt': '20200117',
#   'rm': '유'},
#  {'corp_code': '00117601',
#   'corp_name': '유안타증권',
#   'stock_code': '003470',
#   'corp_cls': 'Y',
#   'report_nm': '최대주주등소유주식변동신고서',
#   'rcept_no': '20200117800408',
#   'flr_nm': '유안타증권',
#   'rcept_dt': '20200117',
#   'rm': '유'},
#  {'corp_code': '00557508',
#   'corp_name': 'GKL',
#   'stock_code': '114090',
#   'corp_cls': 'Y',
#   'report_nm': '주주총회소집결의',
#   'rcept_no': '20200117800396',
#   'flr_nm': 'GKL',
#   'rcept_dt': '20200117',
#   'rm': '유'},
#  {'corp_code': '00117601',
#   'corp_name': '유안타증권',
#   'stock_code': '003470',
#   'corp_cls': 'Y',
#   'report_nm': '투자설명서(일괄신고)',
#   'rcept_no': '20200117000515',
#   'flr_nm': '유안타증권',
#   'rcept_dt': '20200117',
#   'rm': ''},
#  {'corp_code': '00103130',
#   'corp_name': '플레이그램',
#   'stock_code': '009810',
#   'corp_cls': 'Y',
#   'report_nm': '조회공시요구(현저한시황변동)에대한답변(미확정)',
#   'rcept_no': '20200117800367',
#   'flr_nm': '플레이그램',
#   'rcept_dt': '20200117',
#   'rm': '유'},
#  {'corp_code': '00111704',
#   'corp_name': '대우조선해양',
#   'stock_code': '042660',
#   'corp_cls': 'Y',
#   'report_nm': '영업실적등에대한전망(공정공시)',
#   'rcept_no': '20200117800373',
#   'flr_nm': '대우조선해양',
#   'rcept_dt': '20200117',
#   'rm': '유'},
#  {'corp_code': '00155124',
#   'corp_name': '평화홀딩스',
#   'stock_code': '010770',
#   'corp_cls': 'Y',
#   'report_nm': '금전대여결정',
#   'rcept_no': '20200117800401',
#   'flr_nm': '평화홀딩스',
#   'rcept_dt': '20200117',
#   'rm': '유'},
#  {'corp_code': '00110893',
#   'corp_name': '대신증권',
#   'stock_code': '003540',
#   'corp_cls': 'Y',
#   'report_nm': '투자설명서(일괄신고)',
#   'rcept_no': '20200117000514',
#   'flr_nm': '대신증권',
#   'rcept_dt': '20200117',
#   'rm': ''},
#  {'corp_code': '00111722',
#   'corp_name': '미래에셋증권',
#   'stock_code': '006800',
#   'corp_cls': 'Y',
#   'report_nm': '증권발행실적보고서',
#   'rcept_no': '20200117000509',
#   'flr_nm': '미래에셋증권',
#   'rcept_dt': '20200117',
#   'rm': ''},
#  {'corp_code': '00106623',
#   'corp_name': '현대위아',
#   'stock_code': '011210',
#   'corp_cls': 'Y',
#   'report_nm': '특수관계인으로부터기타유가증권매수',
#   'rcept_no': '20200117000507',
#   'flr_nm': '현대위아',
#   'rcept_dt': '20200117',
#   'rm': '공'},
#  {'corp_code': '00111722',
#   'corp_name': '미래에셋증권',
#   'stock_code': '006800',
#   'corp_cls': 'Y',
#   'report_nm': '증권발행실적보고서',
#   'rcept_no': '20200117000506',
#   'flr_nm': '미래에셋증권',
#   'rcept_dt': '20200117',
#   'rm': ''},
#  {'corp_code': '00136721',
#   'corp_name': '신영증권',
#   'stock_code': '001720',
#   'corp_cls': 'Y',
#   'report_nm': '투자설명서(일괄신고)',
#   'rcept_no': '20200117000505',
#   'flr_nm': '신영증권',
#   'rcept_dt': '20200117',
#   'rm': ''},
#  {'corp_code': '00129387',
#   'corp_name': '삼화페인트공업',
#   'stock_code': '000390',
#   'corp_cls': 'Y',
#   'report_nm': '결산실적공시예고(안내공시)',
#   'rcept_no': '20200117800383',
#   'flr_nm': '삼화페인트공업',
#   'rcept_dt': '20200117',
#   'rm': '유'},
#  {'corp_code': '00219574',
#   'corp_name': '코스맥스비티아이',
#   'stock_code': '044820',
#   'corp_cls': 'Y',
#   'report_nm': '주요사항보고서(자기주식처분결정)(자회사의 주요경영사항)',
#   'rcept_no': '20200117800377',
#   'flr_nm': '코스맥스비티아이',
#   'rcept_dt': '20200117',
#   'rm': '유'},
#  {'corp_code': '00151368',
#   'corp_name': '인터지스',
#   'stock_code': '129260',
#   'corp_cls': 'Y',
#   'report_nm': '대표이사(대표집행임원)변경(안내공시)',
#   'rcept_no': '20200117800379',
#   'flr_nm': '인터지스',
#   'rcept_dt': '20200117',
#   'rm': '유'},
#  {'corp_code': '00219574',
#   'corp_name': '코스맥스비티아이',
#   'stock_code': '044820',
#   'corp_cls': 'Y',
#   'report_nm': '주요사항보고서(자기주식처분결정)',
#   'rcept_no': '20200117000482',
#   'flr_nm': '코스맥스비티아이',
#   'rcept_dt': '20200117',
#   'rm': ''},
#  {'corp_code': '01009789',
#   'corp_name': '코스맥스',
#   'stock_code': '192820',
#   'corp_cls': 'Y',
#   'report_nm': '주요사항보고서(자기주식처분결정)',
#   'rcept_no': '20200117000496',
#   'flr_nm': '코스맥스',
#   'rcept_dt': '20200117',
#   'rm': ''},
#  {'corp_code': '00117337',
#   'corp_name': '동양',
#   'stock_code': '001520',
#   'corp_cls': 'Y',
#   'report_nm': '특수관계인과의수익증권거래',
#   'rcept_no': '20200117000501',
#   'flr_nm': '동양',
#   'rcept_dt': '20200117',
#   'rm': '공'},
#  {'corp_code': '00151368',
#   'corp_name': '인터지스',
#   'stock_code': '129260',
#   'corp_cls': 'Y',
#   'report_nm': '임시주주총회결과',
#   'rcept_no': '20200117800345',
#   'flr_nm': '인터지스',
#   'rcept_dt': '20200117',
#   'rm': '유'},
#  {'corp_code': '00258801',
#   'corp_name': '카카오',
#   'stock_code': '035720',
#   'corp_cls': 'Y',
#   'report_nm': '특수관계인과의내부거래',
#   'rcept_no': '20200117000500',
#   'flr_nm': '카카오',
#   'rcept_dt': '20200117',
#   'rm': '공정'},
#  {'corp_code': '00111722',
#   'corp_name': '미래에셋증권',
#   'stock_code': '006800',
#   'corp_cls': 'Y',
#   'report_nm': '증권발행실적보고서',
#   'rcept_no': '20200117000492',
#   'flr_nm': '미래에셋증권',
#   'rcept_dt': '20200117',
#   'rm': ''},
#  {'corp_code': '00104856',
#   'corp_name': '삼성증권',
#   'stock_code': '016360',
#   'corp_cls': 'Y',
#   'report_nm': '증권발행실적보고서',
#   'rcept_no': '20200117000490',
#   'flr_nm': '삼성증권',
#   'rcept_dt': '20200117',
#   'rm': ''},
#  {'corp_code': '00136721',
#   'corp_name': '신영증권',
#   'stock_code': '001720',
#   'corp_cls': 'Y',
#   'report_nm': '일괄신고추가서류(파생결합증권-주식워런트증권)',
#   'rcept_no': '20200117000489',
#   'flr_nm': '신영증권',
#   'rcept_dt': '20200117',
#   'rm': ''},
#  {'corp_code': '00117601',
#   'corp_name': '유안타증권',
#   'stock_code': '003470',
#   'corp_cls': 'Y',
#   'report_nm': '일괄신고추가서류(파생결합증권-주가연계증권)',
#   'rcept_no': '20200117000480',
#   'flr_nm': '유안타증권',
#   'rcept_dt': '20200117',
#   'rm': ''},
#  {'corp_code': '00983271',
#   'corp_name': '엔에이치엔',
#   'stock_code': '181710',
#   'corp_cls': 'Y',
#   'report_nm': '주식등의대량보유상황보고서(일반)',
#   'rcept_no': '20200117000476',
#   'flr_nm': '이준호',
#   'rcept_dt': '20200117',
#   'rm': ''},
#  {'corp_code': '00795135',
#   'corp_name': '코오롱인더',
#   'stock_code': '120110',
#   'corp_cls': 'Y',
#   'report_nm': '최대주주등소유주식변동신고서',
#   'rcept_no': '20200117800337',
#   'flr_nm': '코오롱인더',
#   'rcept_dt': '20200117',
#   'rm': '유'},
#  {'corp_code': '00111722',
#   'corp_name': '미래에셋증권',
#   'stock_code': '006800',
#   'corp_cls': 'Y',
#   'report_nm': '증권발행실적보고서',
#   'rcept_no': '20200117000474',
#   'flr_nm': '미래에셋증권',
#   'rcept_dt': '20200117',
#   'rm': ''},
#  {'corp_code': '00148610',
#   'corp_name': '한화투자증권',
#   'stock_code': '003530',
#   'corp_cls': 'Y',
#   'report_nm': '증권발행실적보고서',
#   'rcept_no': '20200117000471',
#   'flr_nm': '한화투자증권',
#   'rcept_dt': '20200117',
#   'rm': ''},
#  {'corp_code': '00111722',
#   'corp_name': '미래에셋증권',
#   'stock_code': '006800',
#   'corp_cls': 'Y',
#   'report_nm': '증권발행실적보고서',
#   'rcept_no': '20200117000469',
#   'flr_nm': '미래에셋증권',
#   'rcept_dt': '20200117',
#   'rm': ''},
#  {'corp_code': '00164830',
#   'corp_name': '한국조선해양',
#   'stock_code': '009540',
#   'corp_cls': 'Y',
#   'report_nm': '영업(잠정)실적(공정공시)(자회사의 주요경영사항)',
#   'rcept_no': '20200117800316',
#   'flr_nm': '한국조선해양',
#   'rcept_dt': '20200117',
#   'rm': '유'},
#  {'corp_code': '00104856',
#   'corp_name': '삼성증권',
#   'stock_code': '016360',
#   'corp_cls': 'Y',
#   'report_nm': '증권발행실적보고서',
#   'rcept_no': '20200117000464',
#   'flr_nm': '삼성증권',
#   'rcept_dt': '20200117',
#   'rm': ''},
#  {'corp_code': '00164830',
#   'corp_name': '한국조선해양',
#   'stock_code': '009540',
#   'corp_cls': 'Y',
#   'report_nm': '영업(잠정)실적(공정공시)(자회사의 주요경영사항)',
#   'rcept_no': '20200117800310',
#   'flr_nm': '한국조선해양',
#   'rcept_dt': '20200117',
#   'rm': '유'},
#  {'corp_code': '00148610',
#   'corp_name': '한화투자증권',
#   'stock_code': '003530',
#   'corp_cls': 'Y',
#   'report_nm': '증권발행실적보고서',
#   'rcept_no': '20200117000462',
#   'flr_nm': '한화투자증권',
#   'rcept_dt': '20200117',
#   'rm': ''},
#  {'corp_code': '00148610',
#   'corp_name': '한화투자증권',
#   'stock_code': '003530',
#   'corp_cls': 'Y',
#   'report_nm': '투자설명서(일괄신고)',
#   'rcept_no': '20200117000460',
#   'flr_nm': '한화투자증권',
#   'rcept_dt': '20200117',
#   'rm': ''},
#  {'corp_code': '00148610',
#   'corp_name': '한화투자증권',
#   'stock_code': '003530',
#   'corp_cls': 'Y',
#   'report_nm': '투자설명서(일괄신고)',
#   'rcept_no': '20200117000457',
#   'flr_nm': '한화투자증권',
#   'rcept_dt': '20200117',
#   'rm': ''},
#  {'corp_code': '00148610',
#   'corp_name': '한화투자증권',
#   'stock_code': '003530',
#   'corp_cls': 'Y',
#   'report_nm': '일괄신고추가서류(기타파생결합증권)',
#   'rcept_no': '20200117000454',
#   'flr_nm': '한화투자증권',
#   'rcept_dt': '20200117',
#   'rm': ''},
#  {'corp_code': '00164609',
#   'corp_name': '현대미포조선',
#   'stock_code': '010620',
#   'corp_cls': 'Y',
#   'report_nm': '영업(잠정)실적(공정공시)',
#   'rcept_no': '20200117800302',
#   'flr_nm': '현대미포조선',
#   'rcept_dt': '20200117',
#   'rm': '유'},
#  {'corp_code': '00193009',
#   'corp_name': 'KH 필룩스',
#   'stock_code': '033180',
#   'corp_cls': 'Y',
#   'report_nm': '유상증자또는주식관련사채등의발행결과(자율공시)',
#   'rcept_no': '20200117800308',
#   'flr_nm': 'KH 필룩스',
#   'rcept_dt': '20200117',
#   'rm': '유'},
#  {'corp_code': '00148610',
#   'corp_name': '한화투자증권',
#   'stock_code': '003530',
#   'corp_cls': 'Y',
#   'report_nm': '일괄신고추가서류(파생결합증권-주가연계증권)',
#   'rcept_no': '20200117000449',
#   'flr_nm': '한화투자증권',
#   'rcept_dt': '20200117',
#   'rm': ''},
#  {'corp_code': '00344287',
#   'corp_name': '현대두산인프라코어',
#   'stock_code': '042670',
#   'corp_cls': 'Y',
#   'report_nm': '임원ㆍ주요주주특정증권등소유상황보고서',
#   'rcept_no': '20200117000448',
#   'flr_nm': '고석범',
#   'rcept_dt': '20200117',
#   'rm': ''},
#  {'corp_code': '00110893',
#   'corp_name': '대신증권',
#   'stock_code': '003540',
#   'corp_cls': 'Y',
#   'report_nm': '일괄신고추가서류(파생결합증권-주가연계증권)',
#   'rcept_no': '20200117000445',
#   'flr_nm': '대신증권',
#   'rcept_dt': '20200117',
#   'rm': ''},
#  {'corp_code': '00139214',
#   'corp_name': '삼성화재해상보험',
#   'stock_code': '000810',
#   'corp_cls': 'Y',
#   'report_nm': '임원ㆍ주요주주특정증권등소유상황보고서',
#   'rcept_no': '20200117000426',
#   'flr_nm': '삼성생명',
#   'rcept_dt': '20200117',
#   'rm': ''},
#  {'corp_code': '00126292',
#   'corp_name': '삼성카드',
#   'stock_code': '029780',
#   'corp_cls': 'Y',
#   'report_nm': '임원ㆍ주요주주특정증권등소유상황보고서',
#   'rcept_no': '20200117000422',
#   'flr_nm': '삼성생명',
#   'rcept_dt': '20200117',
#   'rm': ''},
#  {'corp_code': '00148276',
#   'corp_name': '제일기획',
#   'stock_code': '030000',
#   'corp_cls': 'Y',
#   'report_nm': '최대주주등소유주식변동신고서',
#   'rcept_no': '20200117800286',
#   'flr_nm': '제일기획',
#   'rcept_dt': '20200117',
#   'rm': '유'},
#  {'corp_code': '00115694',
#   'corp_name': 'DB금융투자',
#   'stock_code': '016610',
#   'corp_cls': 'Y',
#   'report_nm': '증권발행실적보고서',
#   'rcept_no': '20200117000420',
#   'flr_nm': 'DB금융투자',
#   'rcept_dt': '20200117',
#   'rm': ''},
#  {'corp_code': '00104856',
#   'corp_name': '삼성증권',
#   'stock_code': '016360',
#   'corp_cls': 'Y',
#   'report_nm': '임원ㆍ주요주주특정증권등소유상황보고서',
#   'rcept_no': '20200117000416',
#   'flr_nm': '삼성생명',
#   'rcept_dt': '20200117',
#   'rm': ''},
#  {'corp_code': '00115694',
#   'corp_name': 'DB금융투자',
#   'stock_code': '016610',
#   'corp_cls': 'Y',
#   'report_nm': '증권발행실적보고서',
#   'rcept_no': '20200117000412',
#   'flr_nm': 'DB금융투자',
#   'rcept_dt': '20200117',
#   'rm': ''},
#  {'corp_code': '00120182',
#   'corp_name': 'NH투자증권',
#   'stock_code': '005940',
#   'corp_cls': 'Y',
#   'report_nm': '증권발행실적보고서',
#   'rcept_no': '20200117000407',
#   'flr_nm': 'NH투자증권',
#   'rcept_dt': '20200117',
#   'rm': ''},
#  {'corp_code': '00110893',
#   'corp_name': '대신증권',
#   'stock_code': '003540',
#   'corp_cls': 'Y',
#   'report_nm': '증권발행실적보고서',
#   'rcept_no': '20200117000405',
#   'flr_nm': '대신증권',
#   'rcept_dt': '20200117',
#   'rm': ''}]

# %%
len(response.get('list'))
# Out:
# 100

# %%
pd.DataFrame(response.get('list'))
# Out:
#    corp_code corp_name stock_code corp_cls                      report_nm  \
# 0   00120182    NH투자증권     005940        Y  [첨부추가]일괄신고추가서류(파생결합증권-주가연계증권)
# 1   00120182    NH투자증권     005940        Y  [첨부추가]일괄신고추가서류(파생결합증권-주가연계증권)
# 2   00120182    NH투자증권     005940        Y  [첨부추가]일괄신고추가서류(파생결합증권-주가연계증권)
# 3   00120182    NH투자증권     005940        Y  [첨부추가]일괄신고추가서류(파생결합증권-주가연계증권)
# 4   00120182    NH투자증권     005940        Y  [첨부추가]일괄신고추가서류(파생결합증권-주가연계증권)
# ..       ...       ...        ...      ...                            ...
# 95  00115694    DB금융투자     016610        Y                      증권발행실적보고서
# 96  00104856      삼성증권     016360        Y            임원ㆍ주요주주특정증권등소유상황보고서
# 97  00115694    DB금융투자     016610        Y                      증권발행실적보고서
# 98  00120182    NH투자증권     005940        Y                      증권발행실적보고서
# 99  00110893      대신증권     003540        Y                      증권발행실적보고서
#
#           rcept_no  flr_nm  rcept_dt rm
# 0   20200117000559  NH투자증권  20200117
# 1   20200117000486  NH투자증권  20200117
# 2   20200117000375  NH투자증권  20200117
# 3   20200117000341  NH투자증권  20200117
# 4   20200117000083  NH투자증권  20200117
# ..             ...     ...       ... ..
# 95  20200117000420  DB금융투자  20200117
# 96  20200117000416    삼성생명  20200117
# 97  20200117000412  DB금융투자  20200117
# 98  20200117000407  NH투자증권  20200117
# 99  20200117000405    대신증권  20200117
#
# [100 rows x 9 columns]

# %%
disclosures
# Out:
#    corp_code corp_name stock_code corp_cls                      report_nm  \
# 0   00120182    NH투자증권     005940        Y  [첨부추가]일괄신고추가서류(파생결합증권-주가연계증권)
# 1   00120182    NH투자증권     005940        Y  [첨부추가]일괄신고추가서류(파생결합증권-주가연계증권)
# 2   00120182    NH투자증권     005940        Y  [첨부추가]일괄신고추가서류(파생결합증권-주가연계증권)
# 3   00120182    NH투자증권     005940        Y  [첨부추가]일괄신고추가서류(파생결합증권-주가연계증권)
# 4   00120182    NH투자증권     005940        Y  [첨부추가]일괄신고추가서류(파생결합증권-주가연계증권)
# ..       ...       ...        ...      ...                            ...
# 18  00113492     깨끗한나라     004540        Y                 최대주주등소유주식변동신고서
# 19  00113492     깨끗한나라     004540        Y            임원ㆍ주요주주특정증권등소유상황보고서
# 20  00113492     깨끗한나라     004540        Y              주식등의대량보유상황보고서(일반)
# 21  00413046      셀트리온     068270        Y       조회공시요구(풍문또는보도)에대한답변(미확정)
# 22  00144395        동서     026960        Y                 결산실적공시예고(안내공시)
#
#           rcept_no  flr_nm  rcept_dt rm
# 0   20200117000559  NH투자증권  20200117
# 1   20200117000486  NH투자증권  20200117
# 2   20200117000375  NH투자증권  20200117
# 3   20200117000341  NH투자증권  20200117
# 4   20200117000083  NH투자증권  20200117
# ..             ...     ...       ... ..
# 18  20200117800038   깨끗한나라  20200117  유
# 19  20200117000009     최병민  20200117
# 20  20200117000008     최병민  20200117
# 21  20200117800030    셀트리온  20200117  유
# 22  20200117800026      동서  20200117  유
#
# [223 rows x 9 columns]

# %%
# 날짜 지정
API_KEY = '86b1325201d61a7854696bcc35b6d88105cf88f2'
disclosure_url = f'https://opendart.fss.or.kr/api/list.json?crtfc_key={API_KEY}&bgn_de=20200117&end_de=20200117&corp_cls=Y&page_no=1&page_count=100'
response = requests.get(disclosure_url)
response = json.loads(response.text)

# get last page num
last_page_num = response.get('total_page')

disclosures = pd.DataFrame()
for date in tqdm(pd.date_range('20221001', '20221209')):
    date = date.strftime("%Y%m%d")
    for page in tqdm(range(1, last_page_num + 1)):
        disclosure_url = f'https://opendart.fss.or.kr/api/list.json?crtfc_key={API_KEY}&bgn_de={date}&end_de={date}&corp_cls=Y&page_no={page}&page_count=100'
        response = requests.get(disclosure_url)
        response = json.loads(response.text)

        temp = pd.DataFrame(response.get('list'))

        disclosures = disclosures.append(temp)
# Out:
#   0%|          | 0/70 [00:00<?, ?it/s]C:\Users\user\AppData\Local\Temp\ipykernel_11040\2094823171.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disclosures = disclosures.append(temp)
# C:\Users\user\AppData\Local\Temp\ipykernel_11040\2094823171.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disclosures = disclosures.append(temp)
# C:\Users\user\AppData\Local\Temp\ipykernel_11040\2094823171.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disclosures = disclosures.append(temp)
# 100%|██████████| 3/3 [00:00<00:00, 13.11it/s]
#   1%|▏         | 1/70 [00:00<00:15,  4.33it/s]C:\Users\user\AppData\Local\Temp\ipykernel_11040\2094823171.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disclosures = disclosures.append(temp)
# C:\Users\user\AppData\Local\Temp\ipykernel_11040\2094823171.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disclosures = disclosures.append(temp)
# C:\Users\user\AppData\Local\Temp\ipykernel_11040\2094823171.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disclosures = disclosures.append(temp)
# 100%|██████████| 3/3 [00:00<00:00, 11.91it/s]
#   3%|▎         | 2/70 [00:00<00:16,  4.07it/s]C:\Users\user\AppData\Local\Temp\ipykernel_11040\2094823171.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disclosures = disclosures.append(temp)
# C:\Users\user\AppData\Local\Temp\ipykernel_11040\2094823171.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disclosures = disclosures.append(temp)
# C:\Users\user\AppData\Local\Temp\ipykernel_11040\2094823171.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disclosures = disclosures.append(temp)
# 100%|██████████| 3/3 [00:00<00:00, 12.40it/s]
#   4%|▍         | 3/70 [00:00<00:16,  4.08it/s]C:\Users\user\AppData\Local\Temp\ipykernel_11040\2094823171.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disclosures = disclosures.append(temp)
# C:\Users\user\AppData\Local\Temp\ipykernel_11040\2094823171.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disclosures = disclosures.append(temp)
# C:\Users\user\AppData\Local\Temp\ipykernel_11040\2094823171.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disclosures = disclosures.append(temp)
# 100%|██████████| 3/3 [00:00<00:00, 10.42it/s]
#   6%|▌         | 4/70 [00:01<00:17,  3.79it/s]C:\Users\user\AppData\Local\Temp\ipykernel_11040\2094823171.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disclosures = disclosures.append(temp)
# C:\Users\user\AppData\Local\Temp\ipykernel_11040\2094823171.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disclosures = disclosures.append(temp)
# C:\Users\user\AppData\Local\Temp\ipykernel_11040\2094823171.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disclosures = disclosures.append(temp)
# 100%|██████████| 3/3 [00:00<00:00,  9.61it/s]
#   7%|▋         | 5/70 [00:01<00:18,  3.55it/s]C:\Users\user\AppData\Local\Temp\ipykernel_11040\2094823171.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disclosures = disclosures.append(temp)
# C:\Users\user\AppData\Local\Temp\ipykernel_11040\2094823171.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disclosures = disclosures.append(temp)
# C:\Users\user\AppData\Local\Temp\ipykernel_11040\2094823171.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disclosures = disclosures.append(temp)
# 100%|██████████| 3/3 [00:00<00:00,  9.62it/s]
#   9%|▊         | 6/70 [00:01<00:18,  3.41it/s]C:\Users\user\AppData\Local\Temp\ipykernel_11040\2094823171.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disclosures = disclosures.append(temp)
# C:\Users\user\AppData\Local\Temp\ipykernel_11040\2094823171.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disclosures = disclosures.append(temp)
# C:\Users\user\AppData\Local\Temp\ipykernel_11040\2094823171.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disclosures = disclosures.append(temp)
# 100%|██████████| 3/3 [00:00<00:00, 10.50it/s]
#  10%|█         | 7/70 [00:01<00:18,  3.42it/s]C:\Users\user\AppData\Local\Temp\ipykernel_11040\2094823171.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disclosures = disclosures.append(temp)
# C:\Users\user\AppData\Local\Temp\ipykernel_11040\2094823171.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disclosures = disclosures.append(temp)
# C:\Users\user\AppData\Local\Temp\ipykernel_11040\2094823171.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disclosures = disclosures.append(temp)
# 100%|██████████| 3/3 [00:00<00:00, 11.94it/s]
#  11%|█▏        | 8/70 [00:02<00:17,  3.57it/s]C:\Users\user\AppData\Local\Temp\ipykernel_11040\2094823171.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disclosures = disclosures.append(temp)
# C:\Users\user\AppData\Local\Temp\ipykernel_11040\2094823171.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disclosures = disclosures.append(temp)
# C:\Users\user\AppData\Local\Temp\ipykernel_11040\2094823171.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disclosures = disclosures.append(temp)
# 100%|██████████| 3/3 [00:00<00:00, 11.52it/s]
#  13%|█▎        | 9/70 [00:02<00:16,  3.63it/s]C:\Users\user\AppData\Local\Temp\ipykernel_11040\2094823171.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disclosures = disclosures.append(temp)
# C:\Users\user\AppData\Local\Temp\ipykernel_11040\2094823171.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disclosures = disclosures.append(temp)
# C:\Users\user\AppData\Local\Temp\ipykernel_11040\2094823171.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disclosures = disclosures.append(temp)
# 100%|██████████| 3/3 [00:00<00:00, 12.89it/s]
#  14%|█▍        | 10/70 [00:02<00:15,  3.80it/s]C:\Users\user\AppData\Local\Temp\ipykernel_11040\2094823171.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disclosures = disclosures.append(temp)
# C:\Users\user\AppData\Local\Temp\ipykernel_11040\2094823171.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disclosures = disclosures.append(temp)
# C:\Users\user\AppData\Local\Temp\ipykernel_11040\2094823171.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disclosures = disclosures.append(temp)
# 100%|██████████| 3/3 [00:00<00:00,  9.68it/s]
#  16%|█▌        | 11/70 [00:03<00:16,  3.58it/s]C:\Users\user\AppData\Local\Temp\ipykernel_11040\2094823171.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disclosures = disclosures.append(temp)
# C:\Users\user\AppData\Local\Temp\ipykernel_11040\2094823171.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disclosures = disclosures.append(temp)
# C:\Users\user\AppData\Local\Temp\ipykernel_11040\2094823171.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disclosures = disclosures.append(temp)
# 100%|██████████| 3/3 [00:00<00:00, 10.65it/s]
#  17%|█▋        | 12/70 [00:03<00:16,  3.56it/s]C:\Users\user\AppData\Local\Temp\ipykernel_11040\2094823171.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disclosures = disclosures.append(temp)
# C:\Users\user\AppData\Local\Temp\ipykernel_11040\2094823171.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disclosures = disclosures.append(temp)
# C:\Users\user\AppData\Local\Temp\ipykernel_11040\2094823171.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disclosures = disclosures.append(temp)
# 100%|██████████| 3/3 [00:00<00:00, 10.99it/s]
#  19%|█▊        | 13/70 [00:03<00:15,  3.57it/s]C:\Users\user\AppData\Local\Temp\ipykernel_11040\2094823171.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disclosures = disclosures.append(temp)
# C:\Users\user\AppData\Local\Temp\ipykernel_11040\2094823171.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disclosures = disclosures.append(temp)
# C:\Users\user\AppData\Local\Temp\ipykernel_11040\2094823171.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disclosures = disclosures.append(temp)
# 100%|██████████| 3/3 [00:00<00:00, 10.08it/s]
#  20%|██        | 14/70 [00:03<00:16,  3.49it/s]C:\Users\user\AppData\Local\Temp\ipykernel_11040\2094823171.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disclosures = disclosures.append(temp)
# C:\Users\user\AppData\Local\Temp\ipykernel_11040\2094823171.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disclosures = disclosures.append(temp)
# C:\Users\user\AppData\Local\Temp\ipykernel_11040\2094823171.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disclosures = disclosures.append(temp)
# 100%|██████████| 3/3 [00:00<00:00, 11.60it/s]
#  21%|██▏       | 15/70 [00:04<00:15,  3.58it/s]C:\Users\user\AppData\Local\Temp\ipykernel_11040\2094823171.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disclosures = disclosures.append(temp)
# C:\Users\user\AppData\Local\Temp\ipykernel_11040\2094823171.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disclosures = disclosures.append(temp)
# C:\Users\user\AppData\Local\Temp\ipykernel_11040\2094823171.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disclosures = disclosures.append(temp)
# 100%|██████████| 3/3 [00:00<00:00, 12.99it/s]
#  23%|██▎       | 16/70 [00:04<00:14,  3.77it/s]C:\Users\user\AppData\Local\Temp\ipykernel_11040\2094823171.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disclosures = disclosures.append(temp)
# C:\Users\user\AppData\Local\Temp\ipykernel_11040\2094823171.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disclosures = disclosures.append(temp)
# C:\Users\user\AppData\Local\Temp\ipykernel_11040\2094823171.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disclosures = disclosures.append(temp)
# 100%|██████████| 3/3 [00:00<00:00, 10.52it/s]
#  24%|██▍       | 17/70 [00:04<00:14,  3.67it/s]C:\Users\user\AppData\Local\Temp\ipykernel_11040\2094823171.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disclosures = disclosures.append(temp)
# C:\Users\user\AppData\Local\Temp\ipykernel_11040\2094823171.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disclosures = disclosures.append(temp)
# C:\Users\user\AppData\Local\Temp\ipykernel_11040\2094823171.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disclosures = disclosures.append(temp)
# 100%|██████████| 3/3 [00:00<00:00,  9.53it/s]
#  26%|██▌       | 18/70 [00:04<00:14,  3.50it/s]C:\Users\user\AppData\Local\Temp\ipykernel_11040\2094823171.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disclosures = disclosures.append(temp)
# C:\Users\user\AppData\Local\Temp\ipykernel_11040\2094823171.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disclosures = disclosures.append(temp)
# C:\Users\user\AppData\Local\Temp\ipykernel_11040\2094823171.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disclosures = disclosures.append(temp)
# 100%|██████████| 3/3 [00:00<00:00, 10.17it/s]
#  27%|██▋       | 19/70 [00:05<00:14,  3.44it/s]C:\Users\user\AppData\Local\Temp\ipykernel_11040\2094823171.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disclosures = disclosures.append(temp)
# C:\Users\user\AppData\Local\Temp\ipykernel_11040\2094823171.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disclosures = disclosures.append(temp)
# C:\Users\user\AppData\Local\Temp\ipykernel_11040\2094823171.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disclosures = disclosures.append(temp)
# 100%|██████████| 3/3 [00:00<00:00, 10.34it/s]
#  29%|██▊       | 20/70 [00:05<00:14,  3.43it/s]C:\Users\user\AppData\Local\Temp\ipykernel_11040\2094823171.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disclosures = disclosures.append(temp)
# C:\Users\user\AppData\Local\Temp\ipykernel_11040\2094823171.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disclosures = disclosures.append(temp)
# C:\Users\user\AppData\Local\Temp\ipykernel_11040\2094823171.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disclosures = disclosures.append(temp)
# 100%|██████████| 3/3 [00:00<00:00,  9.42it/s]
#  30%|███       | 21/70 [00:05<00:14,  3.33it/s]C:\Users\user\AppData\Local\Temp\ipykernel_11040\2094823171.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disclosures = disclosures.append(temp)
# C:\Users\user\AppData\Local\Temp\ipykernel_11040\2094823171.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disclosures = disclosures.append(temp)
# C:\Users\user\AppData\Local\Temp\ipykernel_11040\2094823171.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disclosures = disclosures.append(temp)
# 100%|██████████| 3/3 [00:00<00:00, 12.94it/s]
#  31%|███▏      | 22/70 [00:06<00:13,  3.56it/s]C:\Users\user\AppData\Local\Temp\ipykernel_11040\2094823171.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disclosures = disclosures.append(temp)
# C:\Users\user\AppData\Local\Temp\ipykernel_11040\2094823171.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disclosures = disclosures.append(temp)
# C:\Users\user\AppData\Local\Temp\ipykernel_11040\2094823171.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disclosures = disclosures.append(temp)
# 100%|██████████| 3/3 [00:00<00:00, 13.01it/s]
#  33%|███▎      | 23/70 [00:06<00:12,  3.75it/s]C:\Users\user\AppData\Local\Temp\ipykernel_11040\2094823171.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disclosures = disclosures.append(temp)
# C:\Users\user\AppData\Local\Temp\ipykernel_11040\2094823171.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disclosures = disclosures.append(temp)
# C:\Users\user\AppData\Local\Temp\ipykernel_11040\2094823171.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disclosures = disclosures.append(temp)
# 100%|██████████| 3/3 [00:00<00:00, 11.25it/s]
#  34%|███▍      | 24/70 [00:06<00:12,  3.73it/s]C:\Users\user\AppData\Local\Temp\ipykernel_11040\2094823171.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disclosures = disclosures.append(temp)
# C:\Users\user\AppData\Local\Temp\ipykernel_11040\2094823171.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disclosures = disclosures.append(temp)
# C:\Users\user\AppData\Local\Temp\ipykernel_11040\2094823171.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disclosures = disclosures.append(temp)
# 100%|██████████| 3/3 [00:00<00:00,  9.58it/s]
#  36%|███▌      | 25/70 [00:06<00:12,  3.53it/s]C:\Users\user\AppData\Local\Temp\ipykernel_11040\2094823171.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disclosures = disclosures.append(temp)
# C:\Users\user\AppData\Local\Temp\ipykernel_11040\2094823171.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disclosures = disclosures.append(temp)
# C:\Users\user\AppData\Local\Temp\ipykernel_11040\2094823171.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disclosures = disclosures.append(temp)
# 100%|██████████| 3/3 [00:00<00:00, 10.45it/s]
#  37%|███▋      | 26/70 [00:07<00:12,  3.51it/s]C:\Users\user\AppData\Local\Temp\ipykernel_11040\2094823171.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disclosures = disclosures.append(temp)
# C:\Users\user\AppData\Local\Temp\ipykernel_11040\2094823171.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disclosures = disclosures.append(temp)
# C:\Users\user\AppData\Local\Temp\ipykernel_11040\2094823171.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disclosures = disclosures.append(temp)
# 100%|██████████| 3/3 [00:00<00:00, 10.38it/s]
#  39%|███▊      | 27/70 [00:07<00:12,  3.47it/s]C:\Users\user\AppData\Local\Temp\ipykernel_11040\2094823171.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disclosures = disclosures.append(temp)
# C:\Users\user\AppData\Local\Temp\ipykernel_11040\2094823171.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disclosures = disclosures.append(temp)
# C:\Users\user\AppData\Local\Temp\ipykernel_11040\2094823171.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disclosures = disclosures.append(temp)
# 100%|██████████| 3/3 [00:00<00:00,  9.66it/s]
#  40%|████      | 28/70 [00:07<00:12,  3.38it/s]C:\Users\user\AppData\Local\Temp\ipykernel_11040\2094823171.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disclosures = disclosures.append(temp)
# C:\Users\user\AppData\Local\Temp\ipykernel_11040\2094823171.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disclosures = disclosures.append(temp)
# C:\Users\user\AppData\Local\Temp\ipykernel_11040\2094823171.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disclosures = disclosures.append(temp)
# 100%|██████████| 3/3 [00:00<00:00, 12.66it/s]
#  41%|████▏     | 29/70 [00:08<00:11,  3.58it/s]C:\Users\user\AppData\Local\Temp\ipykernel_11040\2094823171.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disclosures = disclosures.append(temp)
# C:\Users\user\AppData\Local\Temp\ipykernel_11040\2094823171.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disclosures = disclosures.append(temp)
# C:\Users\user\AppData\Local\Temp\ipykernel_11040\2094823171.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disclosures = disclosures.append(temp)
# 100%|██████████| 3/3 [00:00<00:00, 12.10it/s]
#  43%|████▎     | 30/70 [00:08<00:10,  3.69it/s]C:\Users\user\AppData\Local\Temp\ipykernel_11040\2094823171.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disclosures = disclosures.append(temp)
# C:\Users\user\AppData\Local\Temp\ipykernel_11040\2094823171.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disclosures = disclosures.append(temp)
# C:\Users\user\AppData\Local\Temp\ipykernel_11040\2094823171.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disclosures = disclosures.append(temp)
# 100%|██████████| 3/3 [00:00<00:00,  9.92it/s]
#  44%|████▍     | 31/70 [00:08<00:10,  3.55it/s]C:\Users\user\AppData\Local\Temp\ipykernel_11040\2094823171.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disclosures = disclosures.append(temp)
# C:\Users\user\AppData\Local\Temp\ipykernel_11040\2094823171.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disclosures = disclosures.append(temp)
# C:\Users\user\AppData\Local\Temp\ipykernel_11040\2094823171.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disclosures = disclosures.append(temp)
# 100%|██████████| 3/3 [00:00<00:00, 11.10it/s]
#  46%|████▌     | 32/70 [00:08<00:10,  3.59it/s]C:\Users\user\AppData\Local\Temp\ipykernel_11040\2094823171.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disclosures = disclosures.append(temp)
# C:\Users\user\AppData\Local\Temp\ipykernel_11040\2094823171.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disclosures = disclosures.append(temp)
# C:\Users\user\AppData\Local\Temp\ipykernel_11040\2094823171.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disclosures = disclosures.append(temp)
# 100%|██████████| 3/3 [00:00<00:00,  9.49it/s]
#  47%|████▋     | 33/70 [00:09<00:10,  3.44it/s]C:\Users\user\AppData\Local\Temp\ipykernel_11040\2094823171.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disclosures = disclosures.append(temp)
# C:\Users\user\AppData\Local\Temp\ipykernel_11040\2094823171.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disclosures = disclosures.append(temp)
# C:\Users\user\AppData\Local\Temp\ipykernel_11040\2094823171.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disclosures = disclosures.append(temp)
# 100%|██████████| 3/3 [00:00<00:00, 10.92it/s]
#  49%|████▊     | 34/70 [00:09<00:10,  3.48it/s]C:\Users\user\AppData\Local\Temp\ipykernel_11040\2094823171.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disclosures = disclosures.append(temp)
# C:\Users\user\AppData\Local\Temp\ipykernel_11040\2094823171.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disclosures = disclosures.append(temp)
# C:\Users\user\AppData\Local\Temp\ipykernel_11040\2094823171.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disclosures = disclosures.append(temp)
# 100%|██████████| 3/3 [00:00<00:00, 10.48it/s]
#  50%|█████     | 35/70 [00:09<00:10,  3.47it/s]C:\Users\user\AppData\Local\Temp\ipykernel_11040\2094823171.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disclosures = disclosures.append(temp)
# C:\Users\user\AppData\Local\Temp\ipykernel_11040\2094823171.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disclosures = disclosures.append(temp)
# C:\Users\user\AppData\Local\Temp\ipykernel_11040\2094823171.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disclosures = disclosures.append(temp)
# 100%|██████████| 3/3 [00:00<00:00, 11.10it/s]
#  51%|█████▏    | 36/70 [00:10<00:09,  3.53it/s]C:\Users\user\AppData\Local\Temp\ipykernel_11040\2094823171.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disclosures = disclosures.append(temp)
# C:\Users\user\AppData\Local\Temp\ipykernel_11040\2094823171.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disclosures = disclosures.append(temp)
# C:\Users\user\AppData\Local\Temp\ipykernel_11040\2094823171.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disclosures = disclosures.append(temp)
# 100%|██████████| 3/3 [00:00<00:00, 13.09it/s]
#  53%|█████▎    | 37/70 [00:10<00:08,  3.73it/s]C:\Users\user\AppData\Local\Temp\ipykernel_11040\2094823171.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disclosures = disclosures.append(temp)
# C:\Users\user\AppData\Local\Temp\ipykernel_11040\2094823171.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disclosures = disclosures.append(temp)
# C:\Users\user\AppData\Local\Temp\ipykernel_11040\2094823171.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disclosures = disclosures.append(temp)
# 100%|██████████| 3/3 [00:00<00:00,  9.71it/s]
#  54%|█████▍    | 38/70 [00:10<00:09,  3.55it/s]C:\Users\user\AppData\Local\Temp\ipykernel_11040\2094823171.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disclosures = disclosures.append(temp)
# C:\Users\user\AppData\Local\Temp\ipykernel_11040\2094823171.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disclosures = disclosures.append(temp)
# C:\Users\user\AppData\Local\Temp\ipykernel_11040\2094823171.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disclosures = disclosures.append(temp)
# 100%|██████████| 3/3 [00:00<00:00,  9.52it/s]
#  56%|█████▌    | 39/70 [00:10<00:09,  3.42it/s]C:\Users\user\AppData\Local\Temp\ipykernel_11040\2094823171.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disclosures = disclosures.append(temp)
# C:\Users\user\AppData\Local\Temp\ipykernel_11040\2094823171.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disclosures = disclosures.append(temp)
# C:\Users\user\AppData\Local\Temp\ipykernel_11040\2094823171.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disclosures = disclosures.append(temp)
# 100%|██████████| 3/3 [00:00<00:00,  9.34it/s]
#  57%|█████▋    | 40/70 [00:11<00:09,  3.31it/s]C:\Users\user\AppData\Local\Temp\ipykernel_11040\2094823171.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disclosures = disclosures.append(temp)
# C:\Users\user\AppData\Local\Temp\ipykernel_11040\2094823171.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disclosures = disclosures.append(temp)
# C:\Users\user\AppData\Local\Temp\ipykernel_11040\2094823171.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disclosures = disclosures.append(temp)
# 100%|██████████| 3/3 [00:00<00:00,  9.63it/s]
#  59%|█████▊    | 41/70 [00:11<00:08,  3.26it/s]C:\Users\user\AppData\Local\Temp\ipykernel_11040\2094823171.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disclosures = disclosures.append(temp)
# C:\Users\user\AppData\Local\Temp\ipykernel_11040\2094823171.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disclosures = disclosures.append(temp)
# C:\Users\user\AppData\Local\Temp\ipykernel_11040\2094823171.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disclosures = disclosures.append(temp)
# 100%|██████████| 3/3 [00:00<00:00,  8.49it/s]
#  60%|██████    | 42/70 [00:11<00:09,  3.11it/s]C:\Users\user\AppData\Local\Temp\ipykernel_11040\2094823171.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disclosures = disclosures.append(temp)
# C:\Users\user\AppData\Local\Temp\ipykernel_11040\2094823171.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disclosures = disclosures.append(temp)
# C:\Users\user\AppData\Local\Temp\ipykernel_11040\2094823171.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disclosures = disclosures.append(temp)
# 100%|██████████| 3/3 [00:00<00:00, 12.43it/s]
#  61%|██████▏   | 43/70 [00:12<00:08,  3.35it/s]C:\Users\user\AppData\Local\Temp\ipykernel_11040\2094823171.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disclosures = disclosures.append(temp)
# C:\Users\user\AppData\Local\Temp\ipykernel_11040\2094823171.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disclosures = disclosures.append(temp)
# C:\Users\user\AppData\Local\Temp\ipykernel_11040\2094823171.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disclosures = disclosures.append(temp)
# 100%|██████████| 3/3 [00:00<00:00, 12.92it/s]
#  63%|██████▎   | 44/70 [00:12<00:07,  3.56it/s]C:\Users\user\AppData\Local\Temp\ipykernel_11040\2094823171.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disclosures = disclosures.append(temp)
# C:\Users\user\AppData\Local\Temp\ipykernel_11040\2094823171.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disclosures = disclosures.append(temp)
# C:\Users\user\AppData\Local\Temp\ipykernel_11040\2094823171.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disclosures = disclosures.append(temp)
# 100%|██████████| 3/3 [00:00<00:00,  6.91it/s]
#  64%|██████▍   | 45/70 [00:12<00:08,  3.05it/s]C:\Users\user\AppData\Local\Temp\ipykernel_11040\2094823171.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disclosures = disclosures.append(temp)
# C:\Users\user\AppData\Local\Temp\ipykernel_11040\2094823171.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disclosures = disclosures.append(temp)
# C:\Users\user\AppData\Local\Temp\ipykernel_11040\2094823171.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disclosures = disclosures.append(temp)
# 100%|██████████| 3/3 [00:00<00:00, 11.35it/s]
#  66%|██████▌   | 46/70 [00:13<00:07,  3.23it/s]C:\Users\user\AppData\Local\Temp\ipykernel_11040\2094823171.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disclosures = disclosures.append(temp)
# C:\Users\user\AppData\Local\Temp\ipykernel_11040\2094823171.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disclosures = disclosures.append(temp)
# C:\Users\user\AppData\Local\Temp\ipykernel_11040\2094823171.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disclosures = disclosures.append(temp)
# 100%|██████████| 3/3 [00:00<00:00, 10.79it/s]
#  67%|██████▋   | 47/70 [00:13<00:06,  3.32it/s]C:\Users\user\AppData\Local\Temp\ipykernel_11040\2094823171.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disclosures = disclosures.append(temp)
# C:\Users\user\AppData\Local\Temp\ipykernel_11040\2094823171.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disclosures = disclosures.append(temp)
# C:\Users\user\AppData\Local\Temp\ipykernel_11040\2094823171.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disclosures = disclosures.append(temp)
# 100%|██████████| 3/3 [00:00<00:00, 11.10it/s]
#  69%|██████▊   | 48/70 [00:13<00:06,  3.41it/s]C:\Users\user\AppData\Local\Temp\ipykernel_11040\2094823171.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disclosures = disclosures.append(temp)
# C:\Users\user\AppData\Local\Temp\ipykernel_11040\2094823171.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disclosures = disclosures.append(temp)
# C:\Users\user\AppData\Local\Temp\ipykernel_11040\2094823171.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disclosures = disclosures.append(temp)
# 100%|██████████| 3/3 [00:00<00:00,  9.71it/s]
#  70%|███████   | 49/70 [00:14<00:06,  3.35it/s]C:\Users\user\AppData\Local\Temp\ipykernel_11040\2094823171.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disclosures = disclosures.append(temp)
# C:\Users\user\AppData\Local\Temp\ipykernel_11040\2094823171.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disclosures = disclosures.append(temp)
# C:\Users\user\AppData\Local\Temp\ipykernel_11040\2094823171.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disclosures = disclosures.append(temp)
# 100%|██████████| 3/3 [00:00<00:00, 12.38it/s]
#  71%|███████▏  | 50/70 [00:14<00:05,  3.53it/s]C:\Users\user\AppData\Local\Temp\ipykernel_11040\2094823171.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disclosures = disclosures.append(temp)
# C:\Users\user\AppData\Local\Temp\ipykernel_11040\2094823171.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disclosures = disclosures.append(temp)
# C:\Users\user\AppData\Local\Temp\ipykernel_11040\2094823171.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disclosures = disclosures.append(temp)
# 100%|██████████| 3/3 [00:00<00:00, 12.30it/s]
#  73%|███████▎  | 51/70 [00:14<00:05,  3.67it/s]C:\Users\user\AppData\Local\Temp\ipykernel_11040\2094823171.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disclosures = disclosures.append(temp)
# C:\Users\user\AppData\Local\Temp\ipykernel_11040\2094823171.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disclosures = disclosures.append(temp)
# C:\Users\user\AppData\Local\Temp\ipykernel_11040\2094823171.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disclosures = disclosures.append(temp)
# 100%|██████████| 3/3 [00:00<00:00, 11.09it/s]
#  74%|███████▍  | 52/70 [00:14<00:04,  3.67it/s]C:\Users\user\AppData\Local\Temp\ipykernel_11040\2094823171.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disclosures = disclosures.append(temp)
# C:\Users\user\AppData\Local\Temp\ipykernel_11040\2094823171.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disclosures = disclosures.append(temp)
# C:\Users\user\AppData\Local\Temp\ipykernel_11040\2094823171.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disclosures = disclosures.append(temp)
# 100%|██████████| 3/3 [00:00<00:00, 10.80it/s]
#  76%|███████▌  | 53/70 [00:15<00:04,  3.63it/s]C:\Users\user\AppData\Local\Temp\ipykernel_11040\2094823171.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disclosures = disclosures.append(temp)
# C:\Users\user\AppData\Local\Temp\ipykernel_11040\2094823171.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disclosures = disclosures.append(temp)
# C:\Users\user\AppData\Local\Temp\ipykernel_11040\2094823171.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disclosures = disclosures.append(temp)
# 100%|██████████| 3/3 [00:00<00:00, 10.59it/s]
#  77%|███████▋  | 54/70 [00:15<00:04,  3.59it/s]C:\Users\user\AppData\Local\Temp\ipykernel_11040\2094823171.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disclosures = disclosures.append(temp)
# C:\Users\user\AppData\Local\Temp\ipykernel_11040\2094823171.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disclosures = disclosures.append(temp)
# C:\Users\user\AppData\Local\Temp\ipykernel_11040\2094823171.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disclosures = disclosures.append(temp)
# 100%|██████████| 3/3 [00:00<00:00, 10.92it/s]
#  79%|███████▊  | 55/70 [00:15<00:04,  3.58it/s]C:\Users\user\AppData\Local\Temp\ipykernel_11040\2094823171.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disclosures = disclosures.append(temp)
# C:\Users\user\AppData\Local\Temp\ipykernel_11040\2094823171.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disclosures = disclosures.append(temp)
# C:\Users\user\AppData\Local\Temp\ipykernel_11040\2094823171.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disclosures = disclosures.append(temp)
# 100%|██████████| 3/3 [00:00<00:00, 10.03it/s]
#  80%|████████  | 56/70 [00:15<00:04,  3.49it/s]C:\Users\user\AppData\Local\Temp\ipykernel_11040\2094823171.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disclosures = disclosures.append(temp)
# C:\Users\user\AppData\Local\Temp\ipykernel_11040\2094823171.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disclosures = disclosures.append(temp)
# C:\Users\user\AppData\Local\Temp\ipykernel_11040\2094823171.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disclosures = disclosures.append(temp)
# 100%|██████████| 3/3 [00:00<00:00, 11.61it/s]
#  81%|████████▏ | 57/70 [00:16<00:03,  3.58it/s]C:\Users\user\AppData\Local\Temp\ipykernel_11040\2094823171.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disclosures = disclosures.append(temp)
# C:\Users\user\AppData\Local\Temp\ipykernel_11040\2094823171.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disclosures = disclosures.append(temp)
# C:\Users\user\AppData\Local\Temp\ipykernel_11040\2094823171.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disclosures = disclosures.append(temp)
# 100%|██████████| 3/3 [00:00<00:00, 12.81it/s]
#  83%|████████▎ | 58/70 [00:16<00:03,  3.75it/s]C:\Users\user\AppData\Local\Temp\ipykernel_11040\2094823171.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disclosures = disclosures.append(temp)
# C:\Users\user\AppData\Local\Temp\ipykernel_11040\2094823171.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disclosures = disclosures.append(temp)
# C:\Users\user\AppData\Local\Temp\ipykernel_11040\2094823171.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disclosures = disclosures.append(temp)
# 100%|██████████| 3/3 [00:00<00:00,  9.56it/s]
#  84%|████████▍ | 59/70 [00:16<00:03,  3.55it/s]C:\Users\user\AppData\Local\Temp\ipykernel_11040\2094823171.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disclosures = disclosures.append(temp)
# C:\Users\user\AppData\Local\Temp\ipykernel_11040\2094823171.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disclosures = disclosures.append(temp)
# C:\Users\user\AppData\Local\Temp\ipykernel_11040\2094823171.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disclosures = disclosures.append(temp)
# 100%|██████████| 3/3 [00:00<00:00,  8.60it/s]
#  86%|████████▌ | 60/70 [00:17<00:03,  3.30it/s]C:\Users\user\AppData\Local\Temp\ipykernel_11040\2094823171.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disclosures = disclosures.append(temp)
# C:\Users\user\AppData\Local\Temp\ipykernel_11040\2094823171.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disclosures = disclosures.append(temp)
# C:\Users\user\AppData\Local\Temp\ipykernel_11040\2094823171.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disclosures = disclosures.append(temp)
# 100%|██████████| 3/3 [00:00<00:00,  7.53it/s]
#  87%|████████▋ | 61/70 [00:17<00:02,  3.00it/s]C:\Users\user\AppData\Local\Temp\ipykernel_11040\2094823171.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disclosures = disclosures.append(temp)
# C:\Users\user\AppData\Local\Temp\ipykernel_11040\2094823171.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disclosures = disclosures.append(temp)
# C:\Users\user\AppData\Local\Temp\ipykernel_11040\2094823171.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disclosures = disclosures.append(temp)
# 100%|██████████| 3/3 [00:00<00:00, 10.54it/s]
#  89%|████████▊ | 62/70 [00:17<00:02,  3.12it/s]C:\Users\user\AppData\Local\Temp\ipykernel_11040\2094823171.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disclosures = disclosures.append(temp)
# C:\Users\user\AppData\Local\Temp\ipykernel_11040\2094823171.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disclosures = disclosures.append(temp)
# C:\Users\user\AppData\Local\Temp\ipykernel_11040\2094823171.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disclosures = disclosures.append(temp)
# 100%|██████████| 3/3 [00:00<00:00,  8.61it/s]
#  90%|█████████ | 63/70 [00:18<00:02,  3.03it/s]C:\Users\user\AppData\Local\Temp\ipykernel_11040\2094823171.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disclosures = disclosures.append(temp)
# C:\Users\user\AppData\Local\Temp\ipykernel_11040\2094823171.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disclosures = disclosures.append(temp)
# C:\Users\user\AppData\Local\Temp\ipykernel_11040\2094823171.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disclosures = disclosures.append(temp)
# 100%|██████████| 3/3 [00:00<00:00, 11.60it/s]
#  91%|█████████▏| 64/70 [00:18<00:01,  3.24it/s]C:\Users\user\AppData\Local\Temp\ipykernel_11040\2094823171.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disclosures = disclosures.append(temp)
# C:\Users\user\AppData\Local\Temp\ipykernel_11040\2094823171.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disclosures = disclosures.append(temp)
# C:\Users\user\AppData\Local\Temp\ipykernel_11040\2094823171.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disclosures = disclosures.append(temp)
# 100%|██████████| 3/3 [00:00<00:00, 12.43it/s]
#  93%|█████████▎| 65/70 [00:18<00:01,  3.44it/s]C:\Users\user\AppData\Local\Temp\ipykernel_11040\2094823171.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disclosures = disclosures.append(temp)
# C:\Users\user\AppData\Local\Temp\ipykernel_11040\2094823171.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disclosures = disclosures.append(temp)
# C:\Users\user\AppData\Local\Temp\ipykernel_11040\2094823171.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disclosures = disclosures.append(temp)
# 100%|██████████| 3/3 [00:00<00:00, 10.65it/s]
#  94%|█████████▍| 66/70 [00:18<00:01,  3.46it/s]C:\Users\user\AppData\Local\Temp\ipykernel_11040\2094823171.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disclosures = disclosures.append(temp)
# C:\Users\user\AppData\Local\Temp\ipykernel_11040\2094823171.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disclosures = disclosures.append(temp)
# C:\Users\user\AppData\Local\Temp\ipykernel_11040\2094823171.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disclosures = disclosures.append(temp)
# 100%|██████████| 3/3 [00:00<00:00,  9.79it/s]
#  96%|█████████▌| 67/70 [00:19<00:00,  3.38it/s]C:\Users\user\AppData\Local\Temp\ipykernel_11040\2094823171.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disclosures = disclosures.append(temp)
# C:\Users\user\AppData\Local\Temp\ipykernel_11040\2094823171.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disclosures = disclosures.append(temp)
# C:\Users\user\AppData\Local\Temp\ipykernel_11040\2094823171.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disclosures = disclosures.append(temp)
# 100%|██████████| 3/3 [00:00<00:00, 10.69it/s]
#  97%|█████████▋| 68/70 [00:19<00:00,  3.42it/s]C:\Users\user\AppData\Local\Temp\ipykernel_11040\2094823171.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disclosures = disclosures.append(temp)
# C:\Users\user\AppData\Local\Temp\ipykernel_11040\2094823171.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disclosures = disclosures.append(temp)
# C:\Users\user\AppData\Local\Temp\ipykernel_11040\2094823171.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disclosures = disclosures.append(temp)
# 100%|██████████| 3/3 [00:00<00:00, 10.44it/s]
#  99%|█████████▊| 69/70 [00:19<00:00,  3.43it/s]C:\Users\user\AppData\Local\Temp\ipykernel_11040\2094823171.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disclosures = disclosures.append(temp)
# C:\Users\user\AppData\Local\Temp\ipykernel_11040\2094823171.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disclosures = disclosures.append(temp)
# C:\Users\user\AppData\Local\Temp\ipykernel_11040\2094823171.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disclosures = disclosures.append(temp)
# 100%|██████████| 3/3 [00:00<00:00,  9.65it/s]
# 100%|██████████| 70/70 [00:20<00:00,  3.48it/s]

# %%
disclosures
# Out:
#    corp_code corp_name stock_code corp_cls                 report_nm  \
# 0   00416654       유엔젤     072130        Y              투자판단관련주요경영사항
# 1   00983271     엔에이치엔     181710        Y      [기재정정]주식매수선택권부여에관한신고
# 2   00117188        효성     004800        Y  단일판매ㆍ공급계약체결(자회사의 주요경영사항)
# 3   00153621    참엔지니어링     009310        Y      [기재정정]타법인주식및출자증권처분결정
# 4   00372873      KTis     058860        Y            신탁계약에의한취득상황보고서
# ..       ...       ...        ...      ...                       ...
# 76  00117601     유안타증권     003470        Y                 증권발행실적보고서
# 77  00126380      삼성전자     005930        Y       임원ㆍ주요주주특정증권등소유상황보고서
# 78  00469799     이엔플러스     074610        Y         주식등의대량보유상황보고서(약식)
# 79  00469799     이엔플러스     074610        Y         주식등의대량보유상황보고서(약식)
# 80  00453488   다이나믹디자인     145210        Y         주식등의대량보유상황보고서(약식)
#
#           rcept_no   flr_nm  rcept_dt  rm
# 0   20221004800634      유엔젤  20221004  유정
# 1   20221004000388    엔에이치엔  20221004
# 2   20221004800623       효성  20221004   유
# 3   20221004800620   참엔지니어링  20221004   유
# 4   20221004000386     KTis  20221004
# ..             ...      ...       ...  ..
# 76  20221209000006    유안타증권  20221209
# 77  20221209000003      안희영  20221209
# 78  20221209000002      임권일  20221209
# 79  20221209000001      임권일  20221209
# 80  20221208000507  케이라인홀딩스  20221209
#
# [10938 rows x 9 columns]

# %%
# 날짜 지정

start_date = '20221001'
end_date = '20221209'

API_KEY = '86b1325201d61a7854696bcc35b6d88105cf88f2'
disclosure_url = f'https://opendart.fss.or.kr/api/list.json?crtfc_key={API_KEY}&bgn_de={start_date}&end_de={end_date}&corp_cls=Y&page_no=1&page_count=100'
response = requests.get(disclosure_url)
response = json.loads(response.text)

# get last page num
last_page_num = response.get('total_page')

disclosures = pd.DataFrame()
for page in tqdm(range(1, last_page_num + 1)):
    disclosure_url = f'https://opendart.fss.or.kr/api/list.json?crtfc_key={API_KEY}&bgn_de={start_date}&end_de={end_date}&corp_cls=Y&page_no={page}&page_count=100'
    response = requests.get(disclosure_url)
    response = json.loads(response.text)

    temp = pd.DataFrame(response.get('list'))

    disclosures = disclosures.append(temp)
# Out:
#   0%|          | 0/94 [00:00<?, ?it/s]C:\Users\user\AppData\Local\Temp\ipykernel_11040\2407375984.py:22: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disclosures = disclosures.append(temp)
#   1%|          | 1/94 [00:00<00:50,  1.83it/s]C:\Users\user\AppData\Local\Temp\ipykernel_11040\2407375984.py:22: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disclosures = disclosures.append(temp)
#   2%|▏         | 2/94 [00:01<00:48,  1.91it/s]C:\Users\user\AppData\Local\Temp\ipykernel_11040\2407375984.py:22: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disclosures = disclosures.append(temp)
#   3%|▎         | 3/94 [00:01<00:47,  1.90it/s]C:\Users\user\AppData\Local\Temp\ipykernel_11040\2407375984.py:22: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disclosures = disclosures.append(temp)
#   4%|▍         | 4/94 [00:02<00:47,  1.90it/s]C:\Users\user\AppData\Local\Temp\ipykernel_11040\2407375984.py:22: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disclosures = disclosures.append(temp)
#   5%|▌         | 5/94 [00:02<00:46,  1.91it/s]C:\Users\user\AppData\Local\Temp\ipykernel_11040\2407375984.py:22: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disclosures = disclosures.append(temp)
#   6%|▋         | 6/94 [00:03<00:47,  1.84it/s]C:\Users\user\AppData\Local\Temp\ipykernel_11040\2407375984.py:22: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disclosures = disclosures.append(temp)
#   7%|▋         | 7/94 [00:03<00:47,  1.84it/s]C:\Users\user\AppData\Local\Temp\ipykernel_11040\2407375984.py:22: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disclosures = disclosures.append(temp)
#   9%|▊         | 8/94 [00:04<00:46,  1.85it/s]C:\Users\user\AppData\Local\Temp\ipykernel_11040\2407375984.py:22: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disclosures = disclosures.append(temp)
#  10%|▉         | 9/94 [00:04<00:46,  1.84it/s]C:\Users\user\AppData\Local\Temp\ipykernel_11040\2407375984.py:22: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disclosures = disclosures.append(temp)
#  11%|█         | 10/94 [00:05<00:45,  1.83it/s]C:\Users\user\AppData\Local\Temp\ipykernel_11040\2407375984.py:22: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disclosures = disclosures.append(temp)
#  12%|█▏        | 11/94 [00:05<00:45,  1.83it/s]C:\Users\user\AppData\Local\Temp\ipykernel_11040\2407375984.py:22: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disclosures = disclosures.append(temp)
#  13%|█▎        | 12/94 [00:06<00:45,  1.82it/s]C:\Users\user\AppData\Local\Temp\ipykernel_11040\2407375984.py:22: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disclosures = disclosures.append(temp)
#  14%|█▍        | 13/94 [00:07<00:45,  1.79it/s]C:\Users\user\AppData\Local\Temp\ipykernel_11040\2407375984.py:22: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disclosures = disclosures.append(temp)
#  15%|█▍        | 14/94 [00:07<00:44,  1.78it/s]C:\Users\user\AppData\Local\Temp\ipykernel_11040\2407375984.py:22: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disclosures = disclosures.append(temp)
#  16%|█▌        | 15/94 [00:08<00:43,  1.82it/s]C:\Users\user\AppData\Local\Temp\ipykernel_11040\2407375984.py:22: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disclosures = disclosures.append(temp)
#  17%|█▋        | 16/94 [00:08<00:42,  1.84it/s]C:\Users\user\AppData\Local\Temp\ipykernel_11040\2407375984.py:22: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disclosures = disclosures.append(temp)
#  18%|█▊        | 17/94 [00:09<00:41,  1.87it/s]C:\Users\user\AppData\Local\Temp\ipykernel_11040\2407375984.py:22: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disclosures = disclosures.append(temp)
#  19%|█▉        | 18/94 [00:09<00:40,  1.88it/s]C:\Users\user\AppData\Local\Temp\ipykernel_11040\2407375984.py:22: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disclosures = disclosures.append(temp)
#  20%|██        | 19/94 [00:10<00:39,  1.88it/s]C:\Users\user\AppData\Local\Temp\ipykernel_11040\2407375984.py:22: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disclosures = disclosures.append(temp)
#  21%|██▏       | 20/94 [00:10<00:39,  1.89it/s]C:\Users\user\AppData\Local\Temp\ipykernel_11040\2407375984.py:22: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disclosures = disclosures.append(temp)
#  22%|██▏       | 21/94 [00:11<00:37,  1.92it/s]C:\Users\user\AppData\Local\Temp\ipykernel_11040\2407375984.py:22: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disclosures = disclosures.append(temp)
#  23%|██▎       | 22/94 [00:11<00:37,  1.93it/s]C:\Users\user\AppData\Local\Temp\ipykernel_11040\2407375984.py:22: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disclosures = disclosures.append(temp)
#  24%|██▍       | 23/94 [00:12<00:36,  1.93it/s]C:\Users\user\AppData\Local\Temp\ipykernel_11040\2407375984.py:22: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disclosures = disclosures.append(temp)
#  26%|██▌       | 24/94 [00:12<00:36,  1.94it/s]C:\Users\user\AppData\Local\Temp\ipykernel_11040\2407375984.py:22: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disclosures = disclosures.append(temp)
#  27%|██▋       | 25/94 [00:13<00:35,  1.94it/s]C:\Users\user\AppData\Local\Temp\ipykernel_11040\2407375984.py:22: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disclosures = disclosures.append(temp)
#  28%|██▊       | 26/94 [00:13<00:35,  1.94it/s]C:\Users\user\AppData\Local\Temp\ipykernel_11040\2407375984.py:22: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disclosures = disclosures.append(temp)
#  29%|██▊       | 27/94 [00:14<00:34,  1.94it/s]C:\Users\user\AppData\Local\Temp\ipykernel_11040\2407375984.py:22: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disclosures = disclosures.append(temp)
#  30%|██▉       | 28/94 [00:14<00:34,  1.94it/s]C:\Users\user\AppData\Local\Temp\ipykernel_11040\2407375984.py:22: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disclosures = disclosures.append(temp)
#  31%|███       | 29/94 [00:15<00:33,  1.93it/s]C:\Users\user\AppData\Local\Temp\ipykernel_11040\2407375984.py:22: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disclosures = disclosures.append(temp)
#  32%|███▏      | 30/94 [00:15<00:33,  1.93it/s]C:\Users\user\AppData\Local\Temp\ipykernel_11040\2407375984.py:22: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disclosures = disclosures.append(temp)
#  33%|███▎      | 31/94 [00:16<00:32,  1.94it/s]C:\Users\user\AppData\Local\Temp\ipykernel_11040\2407375984.py:22: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disclosures = disclosures.append(temp)
#  34%|███▍      | 32/94 [00:16<00:32,  1.93it/s]C:\Users\user\AppData\Local\Temp\ipykernel_11040\2407375984.py:22: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disclosures = disclosures.append(temp)
#  35%|███▌      | 33/94 [00:17<00:31,  1.93it/s]C:\Users\user\AppData\Local\Temp\ipykernel_11040\2407375984.py:22: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disclosures = disclosures.append(temp)
#  36%|███▌      | 34/94 [00:18<00:30,  1.94it/s]C:\Users\user\AppData\Local\Temp\ipykernel_11040\2407375984.py:22: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disclosures = disclosures.append(temp)
#  37%|███▋      | 35/94 [00:18<00:30,  1.94it/s]C:\Users\user\AppData\Local\Temp\ipykernel_11040\2407375984.py:22: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disclosures = disclosures.append(temp)
#  38%|███▊      | 36/94 [00:19<00:30,  1.93it/s]C:\Users\user\AppData\Local\Temp\ipykernel_11040\2407375984.py:22: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disclosures = disclosures.append(temp)
#  39%|███▉      | 37/94 [00:19<00:29,  1.93it/s]C:\Users\user\AppData\Local\Temp\ipykernel_11040\2407375984.py:22: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disclosures = disclosures.append(temp)
#  40%|████      | 38/94 [00:20<00:28,  1.95it/s]C:\Users\user\AppData\Local\Temp\ipykernel_11040\2407375984.py:22: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disclosures = disclosures.append(temp)
#  41%|████▏     | 39/94 [00:20<00:28,  1.94it/s]C:\Users\user\AppData\Local\Temp\ipykernel_11040\2407375984.py:22: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disclosures = disclosures.append(temp)
#  43%|████▎     | 40/94 [00:21<00:27,  1.93it/s]C:\Users\user\AppData\Local\Temp\ipykernel_11040\2407375984.py:22: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disclosures = disclosures.append(temp)
#  44%|████▎     | 41/94 [00:21<00:27,  1.94it/s]C:\Users\user\AppData\Local\Temp\ipykernel_11040\2407375984.py:22: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disclosures = disclosures.append(temp)
#  45%|████▍     | 42/94 [00:22<00:26,  1.94it/s]C:\Users\user\AppData\Local\Temp\ipykernel_11040\2407375984.py:22: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disclosures = disclosures.append(temp)
#  46%|████▌     | 43/94 [00:22<00:26,  1.93it/s]C:\Users\user\AppData\Local\Temp\ipykernel_11040\2407375984.py:22: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disclosures = disclosures.append(temp)
#  47%|████▋     | 44/94 [00:23<00:26,  1.92it/s]C:\Users\user\AppData\Local\Temp\ipykernel_11040\2407375984.py:22: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disclosures = disclosures.append(temp)
#  48%|████▊     | 45/94 [00:23<00:25,  1.91it/s]C:\Users\user\AppData\Local\Temp\ipykernel_11040\2407375984.py:22: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disclosures = disclosures.append(temp)
#  49%|████▉     | 46/94 [00:24<00:24,  1.92it/s]C:\Users\user\AppData\Local\Temp\ipykernel_11040\2407375984.py:22: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disclosures = disclosures.append(temp)
#  50%|█████     | 47/94 [00:24<00:24,  1.95it/s]C:\Users\user\AppData\Local\Temp\ipykernel_11040\2407375984.py:22: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disclosures = disclosures.append(temp)
#  51%|█████     | 48/94 [00:25<00:23,  1.93it/s]C:\Users\user\AppData\Local\Temp\ipykernel_11040\2407375984.py:22: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disclosures = disclosures.append(temp)
#  52%|█████▏    | 49/94 [00:25<00:23,  1.92it/s]C:\Users\user\AppData\Local\Temp\ipykernel_11040\2407375984.py:22: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disclosures = disclosures.append(temp)
#  53%|█████▎    | 50/94 [00:26<00:23,  1.90it/s]C:\Users\user\AppData\Local\Temp\ipykernel_11040\2407375984.py:22: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disclosures = disclosures.append(temp)
#  54%|█████▍    | 51/94 [00:26<00:22,  1.90it/s]C:\Users\user\AppData\Local\Temp\ipykernel_11040\2407375984.py:22: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disclosures = disclosures.append(temp)
#  55%|█████▌    | 52/94 [00:27<00:22,  1.90it/s]C:\Users\user\AppData\Local\Temp\ipykernel_11040\2407375984.py:22: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disclosures = disclosures.append(temp)
#  56%|█████▋    | 53/94 [00:27<00:21,  1.89it/s]C:\Users\user\AppData\Local\Temp\ipykernel_11040\2407375984.py:22: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disclosures = disclosures.append(temp)
#  57%|█████▋    | 54/94 [00:28<00:21,  1.89it/s]C:\Users\user\AppData\Local\Temp\ipykernel_11040\2407375984.py:22: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disclosures = disclosures.append(temp)
#  59%|█████▊    | 55/94 [00:28<00:20,  1.90it/s]C:\Users\user\AppData\Local\Temp\ipykernel_11040\2407375984.py:22: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disclosures = disclosures.append(temp)
#  60%|█████▉    | 56/94 [00:29<00:19,  1.91it/s]C:\Users\user\AppData\Local\Temp\ipykernel_11040\2407375984.py:22: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disclosures = disclosures.append(temp)
#  61%|██████    | 57/94 [00:29<00:19,  1.91it/s]C:\Users\user\AppData\Local\Temp\ipykernel_11040\2407375984.py:22: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disclosures = disclosures.append(temp)
#  62%|██████▏   | 58/94 [00:30<00:18,  1.91it/s]C:\Users\user\AppData\Local\Temp\ipykernel_11040\2407375984.py:22: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disclosures = disclosures.append(temp)
#  63%|██████▎   | 59/94 [00:31<00:18,  1.91it/s]C:\Users\user\AppData\Local\Temp\ipykernel_11040\2407375984.py:22: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disclosures = disclosures.append(temp)
#  64%|██████▍   | 60/94 [00:31<00:17,  1.91it/s]C:\Users\user\AppData\Local\Temp\ipykernel_11040\2407375984.py:22: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disclosures = disclosures.append(temp)
#  65%|██████▍   | 61/94 [00:32<00:17,  1.90it/s]C:\Users\user\AppData\Local\Temp\ipykernel_11040\2407375984.py:22: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disclosures = disclosures.append(temp)
#  66%|██████▌   | 62/94 [00:32<00:16,  1.91it/s]C:\Users\user\AppData\Local\Temp\ipykernel_11040\2407375984.py:22: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disclosures = disclosures.append(temp)
#  67%|██████▋   | 63/94 [00:33<00:16,  1.92it/s]C:\Users\user\AppData\Local\Temp\ipykernel_11040\2407375984.py:22: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disclosures = disclosures.append(temp)
#  68%|██████▊   | 64/94 [00:33<00:15,  1.91it/s]C:\Users\user\AppData\Local\Temp\ipykernel_11040\2407375984.py:22: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disclosures = disclosures.append(temp)
#  69%|██████▉   | 65/94 [00:34<00:15,  1.90it/s]C:\Users\user\AppData\Local\Temp\ipykernel_11040\2407375984.py:22: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disclosures = disclosures.append(temp)
#  70%|███████   | 66/94 [00:34<00:14,  1.89it/s]C:\Users\user\AppData\Local\Temp\ipykernel_11040\2407375984.py:22: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disclosures = disclosures.append(temp)
#  71%|███████▏  | 67/94 [00:35<00:14,  1.89it/s]C:\Users\user\AppData\Local\Temp\ipykernel_11040\2407375984.py:22: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disclosures = disclosures.append(temp)
#  72%|███████▏  | 68/94 [00:35<00:13,  1.90it/s]C:\Users\user\AppData\Local\Temp\ipykernel_11040\2407375984.py:22: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disclosures = disclosures.append(temp)
#  73%|███████▎  | 69/94 [00:36<00:13,  1.89it/s]C:\Users\user\AppData\Local\Temp\ipykernel_11040\2407375984.py:22: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disclosures = disclosures.append(temp)
#  74%|███████▍  | 70/94 [00:36<00:12,  1.90it/s]C:\Users\user\AppData\Local\Temp\ipykernel_11040\2407375984.py:22: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disclosures = disclosures.append(temp)
#  76%|███████▌  | 71/94 [00:37<00:12,  1.90it/s]C:\Users\user\AppData\Local\Temp\ipykernel_11040\2407375984.py:22: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disclosures = disclosures.append(temp)
#  77%|███████▋  | 72/94 [00:37<00:11,  1.89it/s]C:\Users\user\AppData\Local\Temp\ipykernel_11040\2407375984.py:22: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disclosures = disclosures.append(temp)
#  78%|███████▊  | 73/94 [00:38<00:10,  1.92it/s]C:\Users\user\AppData\Local\Temp\ipykernel_11040\2407375984.py:22: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disclosures = disclosures.append(temp)
#  79%|███████▊  | 74/94 [00:38<00:10,  1.93it/s]C:\Users\user\AppData\Local\Temp\ipykernel_11040\2407375984.py:22: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disclosures = disclosures.append(temp)
#  80%|███████▉  | 75/94 [00:39<00:09,  1.93it/s]C:\Users\user\AppData\Local\Temp\ipykernel_11040\2407375984.py:22: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disclosures = disclosures.append(temp)
#  81%|████████  | 76/94 [00:39<00:09,  1.91it/s]C:\Users\user\AppData\Local\Temp\ipykernel_11040\2407375984.py:22: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disclosures = disclosures.append(temp)
#  82%|████████▏ | 77/94 [00:40<00:08,  1.90it/s]C:\Users\user\AppData\Local\Temp\ipykernel_11040\2407375984.py:22: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disclosures = disclosures.append(temp)
#  83%|████████▎ | 78/94 [00:41<00:08,  1.90it/s]C:\Users\user\AppData\Local\Temp\ipykernel_11040\2407375984.py:22: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disclosures = disclosures.append(temp)
#  84%|████████▍ | 79/94 [00:41<00:07,  1.90it/s]C:\Users\user\AppData\Local\Temp\ipykernel_11040\2407375984.py:22: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disclosures = disclosures.append(temp)
#  85%|████████▌ | 80/94 [00:42<00:07,  1.91it/s]C:\Users\user\AppData\Local\Temp\ipykernel_11040\2407375984.py:22: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disclosures = disclosures.append(temp)
#  86%|████████▌ | 81/94 [00:42<00:06,  1.90it/s]C:\Users\user\AppData\Local\Temp\ipykernel_11040\2407375984.py:22: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disclosures = disclosures.append(temp)
#  87%|████████▋ | 82/94 [00:43<00:06,  1.90it/s]C:\Users\user\AppData\Local\Temp\ipykernel_11040\2407375984.py:22: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disclosures = disclosures.append(temp)
#  88%|████████▊ | 83/94 [00:43<00:05,  1.90it/s]C:\Users\user\AppData\Local\Temp\ipykernel_11040\2407375984.py:22: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disclosures = disclosures.append(temp)
#  89%|████████▉ | 84/94 [00:44<00:05,  1.91it/s]C:\Users\user\AppData\Local\Temp\ipykernel_11040\2407375984.py:22: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disclosures = disclosures.append(temp)
#  90%|█████████ | 85/94 [00:44<00:04,  1.91it/s]C:\Users\user\AppData\Local\Temp\ipykernel_11040\2407375984.py:22: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disclosures = disclosures.append(temp)
#  91%|█████████▏| 86/94 [00:45<00:04,  1.92it/s]C:\Users\user\AppData\Local\Temp\ipykernel_11040\2407375984.py:22: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disclosures = disclosures.append(temp)
#  93%|█████████▎| 87/94 [00:45<00:03,  1.91it/s]C:\Users\user\AppData\Local\Temp\ipykernel_11040\2407375984.py:22: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disclosures = disclosures.append(temp)
#  94%|█████████▎| 88/94 [00:46<00:03,  1.91it/s]C:\Users\user\AppData\Local\Temp\ipykernel_11040\2407375984.py:22: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disclosures = disclosures.append(temp)
#  95%|█████████▍| 89/94 [00:46<00:02,  1.91it/s]C:\Users\user\AppData\Local\Temp\ipykernel_11040\2407375984.py:22: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disclosures = disclosures.append(temp)
#  96%|█████████▌| 90/94 [00:47<00:02,  1.90it/s]C:\Users\user\AppData\Local\Temp\ipykernel_11040\2407375984.py:22: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disclosures = disclosures.append(temp)
#  97%|█████████▋| 91/94 [00:47<00:01,  1.91it/s]C:\Users\user\AppData\Local\Temp\ipykernel_11040\2407375984.py:22: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disclosures = disclosures.append(temp)
#  98%|█████████▊| 92/94 [00:48<00:01,  1.89it/s]C:\Users\user\AppData\Local\Temp\ipykernel_11040\2407375984.py:22: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disclosures = disclosures.append(temp)
#  99%|█████████▉| 93/94 [00:48<00:00,  1.90it/s]C:\Users\user\AppData\Local\Temp\ipykernel_11040\2407375984.py:22: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disclosures = disclosures.append(temp)
# 100%|██████████| 94/94 [00:49<00:00,  1.90it/s]

# %%
disclosures
# Out:
#    corp_code corp_name stock_code corp_cls  \
# 0   00136721      신영증권     001720        Y
# 1   00136721      신영증권     001720        Y
# 2   00106395      금호전기     001210        Y
# 3   00126380      삼성전자     005930        Y
# 4   00164830    한국조선해양     009540        Y
# ..       ...       ...        ...      ...
# 90  00266961     NAVER     035420        Y
# 91  00413046      셀트리온     068270        Y
# 92  00266961     NAVER     035420        Y
# 93  00117577    오리온홀딩스     001800        Y
# 94  00136721      신영증권     001720        Y
#
#                                             report_nm        rcept_no  flr_nm  \
# 0                                         투자설명서(일괄신고)  20221209000749    신영증권
# 1                         일괄신고추가서류(파생결합사채-주가연계파생결합사채)  20221209000745    신영증권
# 2                                   주식등의대량보유상황보고서(약식)  20221209000738   메리츠증권
# 3                                 임원ㆍ주요주주특정증권등소유상황보고서  20221209000736     오영기
# 4                현금ㆍ현물배당을위한주주명부폐쇄(기준일)결정(자회사의 주요경영사항)  20221209800669  한국조선해양
# ..                                                ...             ...     ...
# 90                                        타인에대한채무보증결정  20221004800008   NAVER
# 91  투자판단관련주요경영사항(유플라이마(CT-P17, 휴미라 바이오시밀러) 유럽 상호교환...  20221004800005    셀트리온
# 92                                     타법인주식및출자증권취득결정  20221004800002   NAVER
# 93                          [기재정정]유상증자결정(종속회사의주요경영사항)  20221004800007  오리온홀딩스
# 94                                        투자설명서(일괄신고)  20220930000729    신영증권
#
#     rcept_dt rm
# 0   20221209
# 1   20221209
# 2   20221209
# 3   20221209
# 4   20221209  유
# ..       ... ..
# 90  20221004  유
# 91  20221004  유
# 92  20221004  유
# 93  20221004  유
# 94  20221004
#
# [9395 rows x 9 columns]

# %%
for date in pd.date_range('20220101','20221231', freq='3M'):
    print(date)
print()
for date in pd.date_range('20220101','20221231', freq=pd.offsets.MonthBegin(3)):
    print(date)
# Out:
# 2022-01-31 00:00:00
# 2022-04-30 00:00:00
# 2022-07-31 00:00:00
# 2022-10-31 00:00:00
#
# 2022-01-01 00:00:00
# 2022-04-01 00:00:00
# 2022-07-01 00:00:00
# 2022-10-01 00:00:00

# %%
print([date for date in pd.date_range('20220101','20221231', freq=pd.offsets.MonthBegin(3))])
print([date for date in pd.date_range('20220301','20221231', freq=pd.offsets.MonthEnd(3))])
# Out:
# [Timestamp('2022-01-01 00:00:00', freq='3MS'), Timestamp('2022-04-01 00:00:00', freq='3MS'), Timestamp('2022-07-01 00:00:00', freq='3MS'), Timestamp('2022-10-01 00:00:00', freq='3MS')]
# [Timestamp('2022-03-31 00:00:00', freq='3M'), Timestamp('2022-06-30 00:00:00', freq='3M'), Timestamp('2022-09-30 00:00:00', freq='3M'), Timestamp('2022-12-31 00:00:00', freq='3M')]

# %%
start_dates = [date for date in pd.date_range('20220101','20221231', freq=pd.offsets.MonthBegin(3))]
end_dates = [date for date in pd.date_range('20220301','20221231', freq=pd.offsets.MonthEnd(3))]
dates = zip(start_dates, end_dates)

# %%
# 수정해야함
for start_date, end_date in tqdm(dates):
    f'https://opendart.fss.or.kr/api/list.json?crtfc_key={API_KEY}&bgn_de={start_date}&end_de={end_date}&corp_cls=Y&page_no={page}&page_count=100'

    disclosure_url = f'https://opendart.fss.or.kr/api/list.json?crtfc_key={API_KEY}&bgn_de={start_date}&end_de={end_date}&corp_cls=Y&page_no=1&page_count=100'
    response = requests.get(disclosure_url)
    response = json.loads(response.text)

    # get last page num
    last_page_num = response.get('total_page')

    disclosures = pd.DataFrame()
    for page in tqdm(range(1, last_page_num + 1)):
        disclosure_url = f'https://opendart.fss.or.kr/api/list.json?crtfc_key={API_KEY}&bgn_de={start_date}&end_de={end_date}&corp_cls=Y&page_no={page}&page_count=100'
        response = requests.get(disclosure_url)
        response = json.loads(response.text)

        temp = pd.DataFrame(response.get('list'))

        disclosures = disclosures.append(temp)

# %% [markdown]
# # 6.Various Data Sources
#
# 공공데이터포털: https://www.data.go.kr/ <br>
# 서울열린데이터광장: http://data.seoul.go.kr/ <br>
# 경제통계: https://ecos.bok.or.kr/ <br>
# 보건의료빅데이터개방시스템: https://opendata.hira.or.kr/home.do <br>
# 문화공공데이터광장: https://www.culture.go.kr/data/main/main.do <br>
# VWORLD: https://www.vworld.kr/dev/v4api.do <br>
# 네이버 API: https://developers.naver.com/products/service-api/datalab/datalab.md <br>
# 카카오 API: https://developers.kakao.com/ <br>
# 대신증권 API: https://money2.daishin.com/E5/WTS/Customer/GuideTrading/DW_CybosPlus_Page.aspx?m=9508&p=8812&v=8632 <br>
# 미국공공데이터: https://www.data.gov/ <br>

# %% [markdown]
# # 7.DataBase
#
#
#
# > DB(DataBase): 구조화된 정보 또는 데이터의 조직화된 모음
# DBMS(DataBase Management System): 사용자와 데이터베이스 사이에서 사용자의 요구에 따라 정보를 생성해 주고 데이터베이스를 관리해 주는 소프트웨어
# RDBMS(Relational DataBase Management System): 테이블과 다른 테이블이 관계를 맺고 모여있는 집합체
# SQL(Structured Query Language): 관계형 데이터베이스에서 사용되는 언어로 데이터를 쿼리, 조작 및 정의하고 액세스 제어를 제공

# %% [markdown]
# ## 7.1 PostgreSQL
#
# 오픈소스 RMDBS의 한 종류

# %% [markdown]
# ## 7.2 기본 커맨드
# 접속
# ```
# psql -U postgres
# ```
# <br>
#
# 종료
# ```
# \q
# ```
# <br>
#
# DB 조회
# ```
# \l or \list
# ```
# <br>
#
# 유저 조회
# ```
# \du
# ```
# <br>
#
# 테이블 조회
# ```
# \dt(+)
# ```
# <br>
#
# 테이블 정보 조회
# ```
# \d *table_name*
# ```
# <br>
#
# 테이블 접근
#  ```
#  \c *table_name*
#  ```

# %% [markdown]
# ## 7.3 테이블 커맨드
#
# 생성
# ```
# CREATE TABLE *table_name*
# (
#   id SERIAL PRIMARY KEY,
#   press_name VARCHAR(10) UNIQUE NOT NULL
# );
# ```
# <br>
#
# 삭제
# ```
# DROP TABLE *table_name*;
# ```
# <br>
#
# 컬럼 추가
# ```
# ALTER TABLE *table_name* ADD COLUMN *column* varchar(10);
# ```
# <br>
#
# 컬럼 삭제
# ```
# ALTER TABLE *table_name* DROP COLUMN *column*;
# ```
# <br>
#
# 컬럼 이름 변경
# ```
# ALTER TABLE *table_name* RENAME COLUMN *current_column* TO *new_column*;
# ```
# <br>
#
# 컬럼 타입 변경
# ```
# ALTER TABLE *table_name* ALTER COLUMN *column* TYPE *data_type*;
# ```

# %% [markdown]
# ## 7.4 CRUD
#
# Create<br>
# 테이블 전체 컬럼 순서대로 데이터 입력
# ```
# INSERT INTO *table_name*
# VALUES (
#   *value1*,
#   *value2*,
#   ...
# )
# ```
# <br>
#
# 테이블 특정 컬럼 데이터 입력
# ```
# INSERT INTO *table_name*
# (
#   *column1*,
#   *column2*
# )
# VALUES
# (
#   *value1*,
#   *value2*
# );
# ```
# <br>
#
# Read
# ```
# SELECT * FROM *table_name* # 모든 컬럼 조회
# SELECT *column_name1, column_name2, ...* FROM *table_name* # 특정 컬럼 조회
# ```
# <br>
#
# Update<br>
# 일반적으로는 where절과 같이 사용
# ```
# UPDATE *table_name* SET *column_name* = *value*
# ```
# <br>
#
# Delete<br>
# 일반적으로는 where절과 같이 사용
# ```
# DROP FROM *table_name* # 전체 테이블 내용 삭제
# ```
# <br>

# %% [markdown]
# ## 7.5 EDA

# %% [markdown]
# ### 새로운 컬럼 만들기
#
# ```
# SELECT DISTINCT *column*, (*column2* + *column3*)/2 as avg
# FROM *table_name*;
# ```

# %% [markdown]
# ### 중복 제거
# ```
# SELECT DISTINCT *column*
# FROM *table_name*;
# ```

# %% [markdown]
# ### 조건식

# %% [markdown]
# #### WHERE
# 단순 조건식
# ```
# SELECT *
# FROM
#   *table_name*
# WHERE
#   column != -1;
# ```
# <br>
#
# 여러 조건식
# ```
# SELECT *
# FROM
#   *table_name*
# WHERE
#   *column1* != -1 and *column2* >= 10 or *column3* < 100;
# ```
# <br>
#
# 조건식 범위 지정 방법
# ```
# WHERE
#   *column* BETWEEN 0 AND 10;
# WHERE
#   *column* NOT BETWEEN 0 AND 10;
#
# WHERE
#   *column* IN (0, 1, 10);
# WHERE
#   *column* NOT IN (0, 1, 10);
# ```
# <br>
#
# 문자열 검색
# _: 몇 글자인지 정해줌 <br>
# %: 몇 글자인지 정해주지 않음 <br>
# ```
# WHERE
#   *column* LIKE *pattern*;
# WHERE
#   *column* NOT LIKE *pattern;
# ```
# <br>
#
# 패턴의 종류는 아래와 같음
#
# ```
# LIKE '200%': 200으로 시작하는 값
# LIKE '%200': 200으로 끝나는 값
# LIKE '%200%': 200이 포함되는 값
# LIKE '_0_': 가운데가 0이 들어가는 3자리 값
# LIKE '_1': x1로 끝나는 값
# LIKE '_200%': 200 앞에는 어떠한 문자도 상관 없으며 200이 포함된 문자열
#
# ```

# %% [markdown]
# #### CASE WHEN
# 조건에 따라 다른 값을 보여줄 때 사용
# ```
# CASE
#   WHEN
#     condition_1 THEN result_1
#   WHEN
#     condition_2 THEN result_2
#   ...
#   END AS *new_column name*
#
# ```

# %% [markdown]
# ### 집계함수
#
# count: row의 개수 반환
# ```
# SELECT count(*) FROM *table_name*;
# ```
# <br>
#
# sum: 합계 반환
# ```
# SELECT sum(*column*) FROM *table_name*;
# ```
# <br>
#
# avg: 평균 반환
# ```
# SELECT avg(*column*) FROM *table_name*;
# ```
# <br>
#
# max: 최댓값 반환
# ```
# SELECT max(*column*) FROM *table_name*;
# ```
# <br>
#
# min: 최솟값 반환
# ```
# SELECT min(*column*) FROM *table_name*;
# ```
#
# <br>
# <br>
# <br>
#
# 주의: 집계함수는 where 절에 나올 수 없음
# ```
# SELECT id FROM news WHERE news_count = max(news_count);
# ```
# <br>
#
# 위의 쿼리는 아래와 같이 수정해야 함
# ```
# SELECT id FROM news
# WHERE news_count = (SELECT max(news_count) FROM news);
# ```

# %% [markdown]
# ### 정렬
#
# 컬럼을 기준으로 오름차순 혹은 내림차순으로 정렬
#
# 오름차순
# ```
# SELECT
#   *column*
# FROM
#   *table_name*
# ORDER BY
#   *column*;
# ```
# <br>
#
# 내림차순
# ```
# SELECT
#   *column*
# FROM
#   *table_name*
# ORDER BY
#   *column* DESC;
# ```
# <br>
# <br>
#
# GROUP BY 뒤에는 집계 함수도 들어갈 수 있음
# ```
# SELECT
#   *column*
# FROM
#   *table_name*
# ORDER BY
#   sum(*column*) DESC;
# ```

# %% [markdown]
# ### GROUP BY
# 행을 특정 그룹으로 묶음
#
# ```
# SELECT
#   *column*
# FROM
#   *table_name*
# GROUP BY
# 	*column*;
# ```

# %% [markdown]
# ### RANK
#
# RANK: 전체 순위를 집계
# ```
# SELECT id, press_name, news_count,
#        RANK() OVER (PARTITION BY press_name ORDER BY news_count DESC)
# FROM news;
# ```
# <br>
#
# DENSE_RANK: 집합 내 순위를 집계 <br>
# 중복 발생 시 다음 순위를 생략하지 않음 <br>
# (1, 1, 2)
# ```
# SELECT id, press_name, news_count,
#        DENSE_RANK() OVER (PARTITION BY press_name ORDER BY news_count DESC)
# FROM news;
# ```

# %% [markdown]
# ### JOIN
#
# (INNER)JOIN<br>
# 같은 값이 있는 행만 반환
# ```
# SELECT *column1*, *column2*
# FROM press_ids as p
# JOIN news as n
# ON *p.column1* = *n.column1*';
# ```
#
# LEFT JOIN<br>
# 왼쪽 테이블에 오른쪽 테이블을 매칭, 값이 없으면 NULL 삽입
# ```
# SELECT *column1*, *column2*
# FROM press_ids as p
# LEFT JOIN news as n
# ON *p.column1* = *n.column1*';
# ```
# <br>
#
# RIGHT JOIN<br>
# 오른쪽 테이블에 오른쪽 테이블을 매칭, 값이 없으면 NULL 삽입
# ```
# SELECT *column1*, *column2*
# FROM press_ids as p
# RIGHT JOIN news as n
# ON *p.column1* = *n.column1*';
# ```
# <br>
#
# FULL JOIN
# 오른쪽 테이블과 왼쪽 테이블 매칭
# ```
# SELECT *column1*, *column2*
# FROM press_ids as p
# RIGHT JOIN news as n
# ON *p.column1* = *n.column1*';
# ```
# <br>
#
# CROSS JOIN: Table1과 Table2의 모든 행을 JOIN (별도의 키를 지정하지 않음)
# ```
# SELECT *column1*, *column2*
# FROM press_ids as p
# CROSS JOIN news as n;
# ```
